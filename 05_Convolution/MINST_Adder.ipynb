# %% [markdown]
# # 作业：手写数字加法机
#
# 本文件是与集智AI学园出品的系列课程“火炬上的深度学习”配套的作业notebook。本作业要求学员构造一个卷积神经网，输入两张手写数字图片，输出这两个数字的和。
#
# 本文件提供了一个完成做的大框架，学员需要自行修改、添加代码，从而完成任务
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第III课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# 定义需要用到的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中

train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# 由于每一个样本需要输入两个图片，因此每一个loader和sampler都有两个

sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.permutation(range(len(train_dataset))))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.permutation(range(len(train_dataset))))

# 训练数据的两个加载器
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = True,
                                           sampler = sampler2
                                           )

# 校验数据和测试数据都各自有两套
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# %% [markdown]
# # MINST Adder

# %% [markdown]
# 为了实现加法器，需要同时处理两个手写体数字图像，并对它进行相应的图像处理
# 因此，网络的架构为两个卷积神经网络，串联上两个全链接层

# %%
#depth = [4, 8]
#class MINSTAdder(nn.Module):
#    def __init__(self):
#        super(MINSTAdder, self).__init__()
#        #处理第一个图像处理用的卷积网络部件
#        self.net1_conv1 = nn.Conv2d(1, 4, 5, padding = 2)
#        self.net_pool = nn.MaxPool2d(2, 2)
#        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2)
        
#        #处理第二个图像处理用的卷积网络部件
#        self.net2_conv1 = nn.Conv2d(1, 4, 5, padding = 2)
#        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2)
        
#        #后面的全连阶层
#        self.fc1 = nn.Linear(2 * image_size // 4 * image_size // 4 * depth[1] , 1024)
#        self.fc2 = nn.Linear(1024, 1)

#    def forward(self, x, y, training = True):
#        #第一张图像的处理流程
#        x = F.relu(self.net1_conv1(x))
#        x = self.net_pool(x)
#        x = F.relu(self.net1_conv2(x))
#        x = self.net_pool(x)
#        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        
#        #第二张图像的处理流程
#        y = F.relu(self.net2_conv1(y))
#        y = self.net_pool(y)
#        y = F.relu(self.net2_conv2(y))
#        y = self.net_pool(y)
#        y = y.view(-1, image_size // 4 * image_size // 4 * depth[1])
        
#        #将前两部处理得到的张量并列到一起，喂给两层全链接前馈网络，最后输出预测数值
#        z = torch.cat((x, y), 1)
#        z = self.fc1(z)
#        z = F.relu(z)
#        z = F.dropout(z, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
#        z = self.fc2(z)
#        return z

## 计算准确度的函数（有多少数字给出了严格的正确输出结果）
#def rightness(y, target):
#    out = torch.round(y).type(torch.LongTensor)
#    out = out.eq(target).sum()
#    out1 = y.size()[0]
#    return(out, out1)

# %%
# 将网络定义为一个预测器，来对加法的结果进行预测，因此用MSE平均平房误差作为我们的损失函数
#net = MINSTAdder()
#criterion = nn.MSELoss()
#optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
#results = {}

# %%
# 开始训练循环，本部分代码需要补齐
#num_epochs = 20
#records = []
#for epoch in range(num_epochs):
#    losses = []
#    # 一个关键技术难点是对两个数据加载器进行读取成对儿的数据。我们的办法是通过zip命令，将loader1和2并列在一起，一对一对的读取数据
#    for idx, data in enumerate(zip(train_loader1, train_loader2)):
#        ((x1, y1), (x2, y2)) = data
#        optimizer.zero_grad()
#        net.train()
#        outputs = net(Variable(x1), Variable(x2))
#        labels = y1 + y2
#        loss = criterion(outputs, Variable(labels.type(torch.FloatTensor)))
#        if idx % 100 == 0:
#            #每间隔一定周期就打印一下训练集、校验集的准确率结果
#            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
#                epoch, idx, len(train_loader1),
#                np.mean(losses), np.mean(val_losses), right_ratio))
#            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
# Out:
# 第0周期，第(0/938)个撮，训练误差：97.00, 校验误差：96.79, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：37.14, 校验误差：16.16, 准确率：0.10
# 第0周期，第(200/938)个撮，训练误差：26.62, 校验误差：15.20, 准确率：0.11
# 第0周期，第(300/938)个撮，训练误差：22.88, 校验误差：14.53, 准确率：0.11
# 第0周期，第(400/938)个撮，训练误差：20.38, 校验误差：11.16, 准确率：0.12
# 第0周期，第(500/938)个撮，训练误差：18.31, 校验误差：9.11, 准确率：0.13
# 第0周期，第(600/938)个撮，训练误差：16.71, 校验误差：8.12, 准确率：0.14
# 第0周期，第(700/938)个撮，训练误差：15.44, 校验误差：7.58, 准确率：0.13
# 第0周期，第(800/938)个撮，训练误差：14.41, 校验误差：6.74, 准确率：0.15
# 第0周期，第(900/938)个撮，训练误差：13.55, 校验误差：6.66, 准确率：0.15
# 第1周期，第(0/938)个撮，训练误差：5.49, 校验误差：6.90, 准确率：0.16
# 第1周期，第(100/938)个撮，训练误差：6.21, 校验误差：6.07, 准确率：0.17
# 第1周期，第(200/938)个撮，训练误差：6.04, 校验误差：6.00, 准确率：0.16
# 第1周期，第(300/938)个撮，训练误差：5.93, 校验误差：5.89, 准确率：0.16
# 第1周期，第(400/938)个撮，训练误差：5.89, 校验误差：5.67, 准确率：0.16
# 第1周期，第(500/938)个撮，训练误差：5.81, 校验误差：5.68, 准确率：0.16
# 第1周期，第(600/938)个撮，训练误差：5.74, 校验误差：5.40, 准确率：0.17
# 第1周期，第(700/938)个撮，训练误差：5.67, 校验误差：5.62, 准确率：0.17
# 第1周期，第(800/938)个撮，训练误差：5.62, 校验误差：5.32, 准确率：0.17
# 第1周期，第(900/938)个撮，训练误差：5.56, 校验误差：5.19, 准确率：0.18
# 第2周期，第(0/938)个撮，训练误差：4.08, 校验误差：5.09, 准确率：0.18
# 第2周期，第(100/938)个撮，训练误差：4.94, 校验误差：5.12, 准确率：0.18
# 第2周期，第(200/938)个撮，训练误差：4.95, 校验误差：5.01, 准确率：0.19
# 第2周期，第(300/938)个撮，训练误差：4.86, 校验误差：4.95, 准确率：0.19
# 第2周期，第(400/938)个撮，训练误差：4.82, 校验误差：5.20, 准确率：0.16
# 第2周期，第(500/938)个撮，训练误差：4.78, 校验误差：4.84, 准确率：0.18
# 第2周期，第(600/938)个撮，训练误差：4.75, 校验误差：5.89, 准确率：0.18
# 第2周期，第(700/938)个撮，训练误差：4.75, 校验误差：4.76, 准确率：0.19
# 第2周期，第(800/938)个撮，训练误差：4.72, 校验误差：4.90, 准确率：0.21
# 第2周期，第(900/938)个撮，训练误差：4.68, 校验误差：4.77, 准确率：0.20
# 第3周期，第(0/938)个撮，训练误差：5.56, 校验误差：4.56, 准确率：0.18
# 第3周期，第(100/938)个撮，训练误差：4.40, 校验误差：4.43, 准确率：0.20
# 第3周期，第(200/938)个撮，训练误差：4.43, 校验误差：4.68, 准确率：0.19
# 第3周期，第(300/938)个撮，训练误差：4.38, 校验误差：4.38, 准确率：0.20
# 第3周期，第(400/938)个撮，训练误差：4.34, 校验误差：4.43, 准确率：0.20
# 第3周期，第(500/938)个撮，训练误差：4.33, 校验误差：4.38, 准确率：0.20
# 第3周期，第(600/938)个撮，训练误差：4.29, 校验误差：4.16, 准确率：0.21
# 第3周期，第(700/938)个撮，训练误差：4.25, 校验误差：4.17, 准确率：0.22
# 第3周期，第(800/938)个撮，训练误差：4.24, 校验误差：4.14, 准确率：0.21
# 第3周期，第(900/938)个撮，训练误差：4.22, 校验误差：3.99, 准确率：0.21
# 第4周期，第(0/938)个撮，训练误差：3.41, 校验误差：4.04, 准确率：0.22
# 第4周期，第(100/938)个撮，训练误差：3.87, 校验误差：4.03, 准确率：0.21
# 第4周期，第(200/938)个撮，训练误差：3.82, 校验误差：3.92, 准确率：0.20
# 第4周期，第(300/938)个撮，训练误差：3.81, 校验误差：3.83, 准确率：0.22
# 第4周期，第(400/938)个撮，训练误差：3.81, 校验误差：3.83, 准确率：0.23
# 第4周期，第(500/938)个撮，训练误差：3.79, 校验误差：3.78, 准确率：0.23
# 第4周期，第(600/938)个撮，训练误差：3.78, 校验误差：3.75, 准确率：0.23
# 第4周期，第(700/938)个撮，训练误差：3.77, 校验误差：3.63, 准确率：0.23
# 第4周期，第(800/938)个撮，训练误差：3.76, 校验误差：3.72, 准确率：0.24
# 第4周期，第(900/938)个撮，训练误差：3.73, 校验误差：3.70, 准确率：0.24
# 第5周期，第(0/938)个撮，训练误差：4.78, 校验误差：3.77, 准确率：0.23
# 第5周期，第(100/938)个撮，训练误差：3.43, 校验误差：3.52, 准确率：0.24
# 第5周期，第(200/938)个撮，训练误差：3.49, 校验误差：3.53, 准确率：0.25
# 第5周期，第(300/938)个撮，训练误差：3.47, 校验误差：3.58, 准确率：0.24
# 第5周期，第(400/938)个撮，训练误差：3.46, 校验误差：3.48, 准确率：0.23
# 第5周期，第(500/938)个撮，训练误差：3.45, 校验误差：3.51, 准确率：0.26
# 第5周期，第(600/938)个撮，训练误差：3.42, 校验误差：3.54, 准确率：0.23
# 第5周期，第(700/938)个撮，训练误差：3.44, 校验误差：3.75, 准确率：0.25
# 第5周期，第(800/938)个撮，训练误差：3.42, 校验误差：3.40, 准确率：0.25
# 第5周期，第(900/938)个撮，训练误差：3.40, 校验误差：3.27, 准确率：0.27
# 第6周期，第(0/938)个撮，训练误差：3.15, 校验误差：3.68, 准确率：0.26
# 第6周期，第(100/938)个撮，训练误差：3.41, 校验误差：3.27, 准确率：0.25
# 第6周期，第(200/938)个撮，训练误差：3.39, 校验误差：3.33, 准确率：0.25
# 第6周期，第(300/938)个撮，训练误差：3.32, 校验误差：3.25, 准确率：0.27
# 第6周期，第(400/938)个撮，训练误差：3.30, 校验误差：3.24, 准确率：0.25
# 第6周期，第(500/938)个撮，训练误差：3.28, 校验误差：3.28, 准确率：0.29
# 第6周期，第(600/938)个撮，训练误差：3.26, 校验误差：3.36, 准确率：0.22
# 第6周期，第(700/938)个撮，训练误差：3.26, 校验误差：3.38, 准确率：0.23
# 第6周期，第(800/938)个撮，训练误差：3.23, 校验误差：3.09, 准确率：0.25
# 第6周期，第(900/938)个撮，训练误差：3.23, 校验误差：3.06, 准确率：0.26
# 第7周期，第(0/938)个撮，训练误差：3.27, 校验误差：3.25, 准确率：0.27
# 第7周期，第(100/938)个撮，训练误差：3.10, 校验误差：3.22, 准确率：0.25
# 第7周期，第(200/938)个撮，训练误差：3.09, 校验误差：3.06, 准确率：0.27
# 第7周期，第(300/938)个撮，训练误差：3.09, 校验误差：3.04, 准确率：0.27
# 第7周期，第(400/938)个撮，训练误差：3.08, 校验误差：2.95, 准确率：0.27
# 第7周期，第(500/938)个撮，训练误差：3.08, 校验误差：2.95, 准确率：0.28
# 第7周期，第(600/938)个撮，训练误差：3.07, 校验误差：3.00, 准确率：0.27
# 第7周期，第(700/938)个撮，训练误差：3.05, 校验误差：3.19, 准确率：0.27
# 第7周期，第(800/938)个撮，训练误差：3.04, 校验误差：2.91, 准确率：0.28
# 第7周期，第(900/938)个撮，训练误差：3.03, 校验误差：2.84, 准确率：0.28
# 第8周期，第(0/938)个撮，训练误差：2.43, 校验误差：3.02, 准确率：0.30
# 第8周期，第(100/938)个撮，训练误差：3.01, 校验误差：2.85, 准确率：0.29
# 第8周期，第(200/938)个撮，训练误差：3.02, 校验误差：2.94, 准确率：0.29
# 第8周期，第(300/938)个撮，训练误差：2.99, 校验误差：3.09, 准确率：0.29
# 第8周期，第(400/938)个撮，训练误差：2.98, 校验误差：3.03, 准确率：0.25
# 第8周期，第(500/938)个撮，训练误差：2.95, 校验误差：2.89, 准确率：0.28
# 第8周期，第(600/938)个撮，训练误差：2.94, 校验误差：2.87, 准确率：0.28
# 第8周期，第(700/938)个撮，训练误差：2.92, 校验误差：2.87, 准确率：0.28
# 第8周期，第(800/938)个撮，训练误差：2.89, 校验误差：2.80, 准确率：0.29
# 第8周期，第(900/938)个撮，训练误差：2.89, 校验误差：2.77, 准确率：0.28
# 第9周期，第(0/938)个撮，训练误差：3.35, 校验误差：2.81, 准确率：0.27
# 第9周期，第(100/938)个撮，训练误差：2.78, 校验误差：2.81, 准确率：0.29
# 第9周期，第(200/938)个撮，训练误差：2.80, 校验误差：2.77, 准确率：0.29
# 第9周期，第(300/938)个撮，训练误差：2.79, 校验误差：2.67, 准确率：0.31
# 第9周期，第(400/938)个撮，训练误差：2.77, 校验误差：2.74, 准确率：0.30
# 第9周期，第(500/938)个撮，训练误差：2.75, 校验误差：2.70, 准确率：0.29
# 第9周期，第(600/938)个撮，训练误差：2.75, 校验误差：2.85, 准确率：0.29
# 第9周期，第(700/938)个撮，训练误差：2.75, 校验误差：2.82, 准确率：0.30
# 第9周期，第(800/938)个撮，训练误差：2.75, 校验误差：2.78, 准确率：0.27
# 第9周期，第(900/938)个撮，训练误差：2.73, 校验误差：2.97, 准确率：0.24
# 第10周期，第(0/938)个撮，训练误差：2.82, 校验误差：2.69, 准确率：0.29
# 第10周期，第(100/938)个撮，训练误差：2.64, 校验误差：2.93, 准确率：0.30
# 第10周期，第(200/938)个撮，训练误差：2.59, 校验误差：2.79, 准确率：0.31
# 第10周期，第(300/938)个撮，训练误差：2.64, 校验误差：2.66, 准确率：0.31
# 第10周期，第(400/938)个撮，训练误差：2.65, 校验误差：2.72, 准确率：0.30
# 第10周期，第(500/938)个撮，训练误差：2.66, 校验误差：2.61, 准确率：0.31
# 第10周期，第(600/938)个撮，训练误差：2.66, 校验误差：2.61, 准确率：0.29
# 第10周期，第(700/938)个撮，训练误差：2.66, 校验误差：2.67, 准确率：0.31
# 第10周期，第(800/938)个撮，训练误差：2.65, 校验误差：2.69, 准确率：0.30
# 第10周期，第(900/938)个撮，训练误差：2.64, 校验误差：2.56, 准确率：0.30
# 第11周期，第(0/938)个撮，训练误差：3.17, 校验误差：2.73, 准确率：0.31
# 第11周期，第(100/938)个撮，训练误差：2.67, 校验误差：2.55, 准确率：0.29
# 第11周期，第(200/938)个撮，训练误差：2.60, 校验误差：2.50, 准确率：0.31
# 第11周期，第(300/938)个撮，训练误差：2.59, 校验误差：2.60, 准确率：0.31
# 第11周期，第(400/938)个撮，训练误差：2.59, 校验误差：2.58, 准确率：0.31
# 第11周期，第(500/938)个撮，训练误差：2.62, 校验误差：2.58, 准确率：0.32
# 第11周期，第(600/938)个撮，训练误差：2.61, 校验误差：2.59, 准确率：0.30
# 第11周期，第(700/938)个撮，训练误差：2.60, 校验误差：2.55, 准确率：0.27
# 第11周期，第(800/938)个撮，训练误差：2.59, 校验误差：2.49, 准确率：0.29
# 第11周期，第(900/938)个撮，训练误差：2.59, 校验误差：2.63, 准确率：0.28
# 第12周期，第(0/938)个撮，训练误差：2.99, 校验误差：2.55, 准确率：0.32
# 第12周期，第(100/938)个撮，训练误差：2.56, 校验误差：2.55, 准确率：0.30
# 第12周期，第(200/938)个撮，训练误差：2.49, 校验误差：2.56, 准确率：0.32
# 第12周期，第(300/938)个撮，训练误差：2.50, 校验误差：2.43, 准确率：0.30
# 第12周期，第(400/938)个撮，训练误差：2.50, 校验误差：2.54, 准确率：0.31
# 第12周期，第(500/938)个撮，训练误差：2.51, 校验误差：2.38, 准确率：0.31
# 第12周期，第(600/938)个撮，训练误差：2.50, 校验误差：2.55, 准确率：0.28
# 第12周期，第(700/938)个撮，训练误差：2.50, 校验误差：2.43, 准确率：0.32
# 第12周期，第(800/938)个撮，训练误差：2.51, 校验误差：2.43, 准确率：0.34
# 第12周期，第(900/938)个撮，训练误差：2.49, 校验误差：2.42, 准确率：0.33
# 第13周期，第(0/938)个撮，训练误差：2.14, 校验误差：2.45, 准确率：0.32
# 第13周期，第(100/938)个撮，训练误差：2.42, 校验误差：2.47, 准确率：0.30
# 第13周期，第(200/938)个撮，训练误差：2.46, 校验误差：2.50, 准确率：0.32
# 第13周期，第(300/938)个撮，训练误差：2.46, 校验误差：2.45, 准确率：0.30
# 第13周期，第(400/938)个撮，训练误差：2.45, 校验误差：2.45, 准确率：0.32
# 第13周期，第(500/938)个撮，训练误差：2.45, 校验误差：2.38, 准确率：0.33
# 第13周期，第(600/938)个撮，训练误差：2.44, 校验误差：2.42, 准确率：0.32
# 第13周期，第(700/938)个撮，训练误差：2.44, 校验误差：2.34, 准确率：0.33
# 第13周期，第(800/938)个撮，训练误差：2.45, 校验误差：2.41, 准确率：0.32
# 第13周期，第(900/938)个撮，训练误差：2.43, 校验误差：2.39, 准确率：0.33
# 第14周期，第(0/938)个撮，训练误差：2.29, 校验误差：2.36, 准确率：0.32
# 第14周期，第(100/938)个撮，训练误差：2.48, 校验误差：2.36, 准确率：0.33
# 第14周期，第(200/938)个撮，训练误差：2.37, 校验误差：2.39, 准确率：0.29
# 第14周期，第(300/938)个撮，训练误差：2.37, 校验误差：2.35, 准确率：0.33
# 第14周期，第(400/938)个撮，训练误差：2.37, 校验误差：2.32, 准确率：0.33
# 第14周期，第(500/938)个撮，训练误差：2.36, 校验误差：2.47, 准确率：0.31
# 第14周期，第(600/938)个撮，训练误差：2.37, 校验误差：2.35, 准确率：0.33
# 第14周期，第(700/938)个撮，训练误差：2.38, 校验误差：2.38, 准确率：0.32
# 第14周期，第(800/938)个撮，训练误差：2.39, 校验误差：2.33, 准确率：0.32
# 第14周期，第(900/938)个撮，训练误差：2.38, 校验误差：2.33, 准确率：0.30
# 第15周期，第(0/938)个撮，训练误差：2.46, 校验误差：2.34, 准确率：0.33
# 第15周期，第(100/938)个撮，训练误差：2.36, 校验误差：2.30, 准确率：0.33
# 第15周期，第(200/938)个撮，训练误差：2.32, 校验误差：2.40, 准确率：0.28
# 第15周期，第(300/938)个撮，训练误差：2.36, 校验误差：2.36, 准确率：0.31
# 第15周期，第(400/938)个撮，训练误差：2.34, 校验误差：2.27, 准确率：0.33
# 第15周期，第(500/938)个撮，训练误差：2.32, 校验误差：2.50, 准确率：0.32
# 第15周期，第(600/938)个撮，训练误差：2.33, 校验误差：2.33, 准确率：0.34
# 第15周期，第(700/938)个撮，训练误差：2.32, 校验误差：2.46, 准确率：0.34
# 第15周期，第(800/938)个撮，训练误差：2.32, 校验误差：2.30, 准确率：0.34
# 第15周期，第(900/938)个撮，训练误差：2.31, 校验误差：2.29, 准确率：0.34
# 第16周期，第(0/938)个撮，训练误差：2.08, 校验误差：2.27, 准确率：0.34
# 第16周期，第(100/938)个撮，训练误差：2.29, 校验误差：2.28, 准确率：0.34
# 第16周期，第(200/938)个撮，训练误差：2.28, 校验误差：2.31, 准确率：0.34
# 第16周期，第(300/938)个撮，训练误差：2.26, 校验误差：2.38, 准确率：0.30
# 第16周期，第(400/938)个撮，训练误差：2.27, 校验误差：2.21, 准确率：0.33
# 第16周期，第(500/938)个撮，训练误差：2.26, 校验误差：2.30, 准确率：0.34
# 第16周期，第(600/938)个撮，训练误差：2.25, 校验误差：2.21, 准确率：0.34
# 第16周期，第(700/938)个撮，训练误差：2.24, 校验误差：2.23, 准确率：0.34
# 第16周期，第(800/938)个撮，训练误差：2.26, 校验误差：2.21, 准确率：0.33
# 第16周期，第(900/938)个撮，训练误差：2.25, 校验误差：2.11, 准确率：0.33
# 第17周期，第(0/938)个撮，训练误差：0.85, 校验误差：2.17, 准确率：0.34
# 第17周期，第(100/938)个撮，训练误差：2.26, 校验误差：2.22, 准确率：0.31
# 第17周期，第(200/938)个撮，训练误差：2.29, 校验误差：2.19, 准确率：0.35
# 第17周期，第(300/938)个撮，训练误差：2.24, 校验误差：2.24, 准确率：0.35
# 第17周期，第(400/938)个撮，训练误差：2.26, 校验误差：2.40, 准确率：0.34
# 第17周期，第(500/938)个撮，训练误差：2.26, 校验误差：2.24, 准确率：0.34
# 第17周期，第(600/938)个撮，训练误差：2.27, 校验误差：2.22, 准确率：0.34
# 第17周期，第(700/938)个撮，训练误差：2.26, 校验误差：2.15, 准确率：0.34
# 第17周期，第(800/938)个撮，训练误差：2.26, 校验误差：2.30, 准确率：0.34
# 第17周期，第(900/938)个撮，训练误差：2.25, 校验误差：2.17, 准确率：0.32
# 第18周期，第(0/938)个撮，训练误差：3.17, 校验误差：2.28, 准确率：0.35
# 第18周期，第(100/938)个撮，训练误差：2.22, 校验误差：2.45, 准确率：0.33
# 第18周期，第(200/938)个撮，训练误差：2.22, 校验误差：2.26, 准确率：0.35
# 第18周期，第(300/938)个撮，训练误差：2.23, 校验误差：2.13, 准确率：0.36
# 第18周期，第(400/938)个撮，训练误差：2.22, 校验误差：2.19, 准确率：0.33
# 第18周期，第(500/938)个撮，训练误差：2.21, 校验误差：2.13, 准确率：0.36
# 第18周期，第(600/938)个撮，训练误差：2.21, 校验误差：2.16, 准确率：0.35
# 第18周期，第(700/938)个撮，训练误差：2.20, 校验误差：2.20, 准确率：0.34
# 第18周期，第(800/938)个撮，训练误差：2.20, 校验误差：2.08, 准确率：0.35
# 第18周期，第(900/938)个撮，训练误差：2.20, 校验误差：2.18, 准确率：0.33
# 第19周期，第(0/938)个撮，训练误差：2.25, 校验误差：2.33, 准确率：0.34
# 第19周期，第(100/938)个撮，训练误差：2.12, 校验误差：2.13, 准确率：0.36
# 第19周期，第(200/938)个撮，训练误差：2.14, 校验误差：2.13, 准确率：0.36
# 第19周期，第(300/938)个撮，训练误差：2.14, 校验误差：2.09, 准确率：0.34
# 第19周期，第(400/938)个撮，训练误差：2.13, 校验误差：2.13, 准确率：0.34
# 第19周期，第(500/938)个撮，训练误差：2.14, 校验误差：2.08, 准确率：0.36
# 第19周期，第(600/938)个撮，训练误差：2.14, 校验误差：2.05, 准确率：0.36
# 第19周期，第(700/938)个撮，训练误差：2.13, 校验误差：2.21, 准确率：0.35
# 第19周期，第(800/938)个撮，训练误差：2.13, 校验误差：2.11, 准确率：0.34
# 第19周期，第(900/938)个撮，训练误差：2.13, 校验误差：2.00, 准确率：0.35
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1098d016a13e> in <module>()
#      35 net.eval()
#      36 for test_data in zip(test_loader1, test_loader2):
# ---> 37     if use_cuda:
#      38         x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
#      39     outputs = net(Variable(x1), Variable(x2))
#
# NameError: name 'use_cuda' is not defined

# %%
# 在测试集上运行我们的加法机网络，并测试预测准确度
