# %% [markdown]
# # 迁移学习——手写数字加法机
#
# 本文件是集智AI学园开发的“火炬上的深度学习”系列课程第四节课：《神经网络移情别恋——迁移学习》的配套文档。在本文档中，我们
# 实现了一个手写数字加法机，它可以通过识别输入的两个手写体图像文件，从而计算两个数字的和，并给出输出。我们展示了三种不同
# 的迁移学习方式，并对它们进行了系统化的比较：
#
# 1、没有迁移学习，网络完全从头学习如何识别数字，如何计算加法；
#
# 2、将已训练好的手写数字识别器网络迁移过来，作为预训练权重；
#
# 3、将已训练好的手写数字识别器网络迁移过来，并作为不可修改的权重。
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn

import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline

# %% [markdown]
# ## 一、加载数据
#
# 首先一个问题是如何加载成对的图像数据？我们采用的解决方案是采用了两套采样器和加载器，
# 这样每一组采样器＋加载器都独立地从原始的数据集中抽样数据，这就让我们可以获得大量不重复
# 的手写数字图像对，从而可以训练我们的神经网络。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 设置图像读取器的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #批处理的尺寸大小

# 如果系统中存在着GPU，我们将用GPU来完成张量的计算
use_cuda = torch.cuda.is_available() #定义一个布尔型变量，标志当前的GPU是否可用

# 如果当前GPU可用，则将优先在GPU上进行张量计算
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
itype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

# 加载测试数据集
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())


# 定义两个采样器，每一个采样器都随机地从原始的数据集中抽样数据。抽样数据采用permutation
# 生成任意一个下标重排，从而利用下标来提取dataset中的数据
sample_size = len(train_dataset)
sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))

# 定义两个加载器，分别封装了前两个采样器，实现采样。
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler2
                                           )

# 对于校验数据和测试数据，我们进行类似的处理。
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# 为了比较不同数据量对迁移学习的影响，我们设定了一个加载数据的比例fraction
# 即我们只加载原训练数据集的1/fraction来训练网络
fraction = 1
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data\MNIST\raw\train-images-idx3-ubyte.gz
# 100%|████████████████████████████████████████████████████████████████████▉| 9895936/9912422 [04:20<00:00, 35537.86it/s]
# Extracting ./mnist_data\MNIST\raw\train-images-idx3-ubyte.gz to ./mnist_data\MNIST\raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data\MNIST\raw\train-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
#   0%|                                                                                        | 0/28881 [00:10<?, ?it/s]
#  28%|████████████████████▉                                                     | 8192/28881 [00:11<00:00, 66064.99it/s]
#  57%|█████████████████████████████████████████▍                               | 16384/28881 [00:11<00:00, 62013.85it/s]
# Extracting ./mnist_data\MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist_data\MNIST\raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 9920512it [04:40, 35537.86it/s]
#
#   0%|                                                                                      | 0/1648877 [00:09<?, ?it/s]
#
#   1%|▋                                                                      | 16384/1648877 [00:10<00:25, 63996.35it/s]
#
#   2%|█▊                                                                     | 40960/1648877 [00:10<00:23, 69657.82it/s]
#
#   3%|██                                                                     | 49152/1648877 [00:10<00:25, 63739.35it/s]
#
#   7%|████▊                                                                 | 114688/1648877 [00:10<00:18, 82183.89it/s]
#
#   8%|█████▌                                                                | 131072/1648877 [00:10<00:16, 92382.32it/s]
#
#  11%|███████▉                                                             | 188416/1648877 [00:11<00:12, 113416.15it/s]
#
#  15%|██████████▋                                                          | 253952/1648877 [00:11<00:09, 143315.62it/s]
#
#  19%|█████████████                                                        | 311296/1648877 [00:11<00:07, 182097.17it/s]
#
#  21%|██████████████▋                                                      | 352256/1648877 [00:11<00:05, 216797.48it/s]
#
\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist_data\MNIST\raw
# 1654784it [00:27, 261974.09it/s]
# Processing...
# Done!

# %% [markdown]
# ## 二、加载网络
#
# 为了实现迁移学习，我们需要从硬盘上加载已经训练好的手写数字识别器卷积神经网络，加载网络需要经过两个步骤：
#
# 1、定义网络模块（nn.Module）的框架，即新定义类ConvNet，实现其forwar函数；
#
# 2、从硬盘文件加载网络
#
# 3、通过绘制其卷积核，验证加载到的网络和导出的网络一致

# %% [markdown]
# ### 1. 定义网络架构
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 定义待迁移的网络框架，所有的神经网络模块包括：Conv2d、MaxPool2d，Linear等模块都不需要重新定义，会自动加载
# 但是网络的forward功能没有办法自动实现，需要重写。
# 一般的，加载网络只加载网络的属性，不加载方法
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        x = F.relu(self.fc1(x)) #全链接，激活函数
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x, dim =1) #log_softmax可以理解为概率对数值
        return x

# %% [markdown]
# ### 2. 从硬盘文件加载网络
#
# 网络加载命令如下：

# %%
original_net = torch.load('minst_conv_checkpoint') #读取硬盘上的minst_conv_checkpoint文件
# Out:
# F:\Anaconda\lib\site-packages\torch\serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# F:\Anaconda\lib\site-packages\torch\serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# F:\Anaconda\lib\site-packages\torch\serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
original_net #将网络打印出来观看（只能看到其神经模块和架构）
# Out:
# ConvNet(
#   (conv1): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=392, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3. 检测加载的正确性
#
# 通过测试它在测试数据集上的分类准确度，以及绘制其卷积核，并与导出的程序（minist_convnet.ipynb）中的分类准确度、卷积核等是否相同判断本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素

#在测试集上分批运行，并计算总的正确率
original_net.eval() #标志模型当前为运行阶段
test_loss = 0
correct = 0
vals = []

#对测试数据集进行循环
for data, target in test_loader1:
#     data, target = data.clone().detach().requires_grad_(False), target.clone().detach()
    with torch.no_grad():
        data = data.clone().detach()
    target = target.clone().detach()
    
    output = original_net(data) #将特征数据喂入网络，得到分类的输出
    val = rightness(output, target) #获得正确样本数以及总样本数
    vals.append(val) #记录结果

#计算准确率
rights = (sum([tup[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 1.0 * rights[0].numpy() / rights[1]
right_rate
# Out:
# 0.9918

# %%
#随便从测试集中读入一张图片，并绘制出来
idx = 4
muteimg = test_dataset[idx][0].numpy()
plt.imshow(muteimg[0,...])
print('标签是：',test_dataset[idx][1])
# Out:
# 标签是： 4

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(original_net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(original_net.conv2.weight.data.numpy()[j, i,...])

# %% [markdown]
# ## 三、数字加法机的实现
#
# 数字加法机：输入两张图像，输出这两个手写数字的加法。网络的架构如下：
#
# 两个并行的卷积模块：两个卷积层、两个Pooling层；一个全链接模块：最多四层全链接层。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
depth = [4, 8]
class Transfer(nn.Module):
    def __init__(self):
        super(Transfer, self).__init__()
        # 两个并行的卷积通道，第一个通道：
        self.net1_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net_pool = nn.MaxPool2d(2, 2) #2*2 池化
        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 第二个通道，注意pooling操作不需要重复定义
        self.net2_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 全链接层
        self.fc1 = nn.Linear(2 * image_size // 4 * image_size // 4 * depth[1] , 1024) #输入为处理后的特征图压平，输出1024个单元
        self.fc2 = nn.Linear(1024, 2 * num_classes) #输入1024个单元，输出20个单元
        self.fc3 = nn.Linear(2 * num_classes, num_classes) #输入20个单元，输出10个单元
        self.fc4 = nn.Linear(num_classes, 1) #输入10个单元，输出为1

    def forward(self, x, y, training = True):
        # 网络的前馈过程。输入两张手写图像x和y，输出一个数字表示两个数字的和
        # x,y都是batch_size*image_size*image_size形状的三阶张量
        # 输出为batch_size长的列向量
        
        # 首先，第一张图像进入第一个通道
        x = F.relu(self.net1_conv1(x)) #第一层卷积
        x = self.net_pool(x)   # 第一层池化
        x = F.relu(self.net1_conv2(x))  # 第二层卷积
        x = self.net_pool(x) # 第二层池化
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1]) # 将特征图张量压平
        
        
        y = F.relu(self.net2_conv1(y)) #第一层卷积
        y = self.net_pool(y) # 第一层池化
        y = F.relu(self.net2_conv2(y)) #第二层卷积
        y = self.net_pool(y) #第二层池化
        y = y.view(-1, image_size // 4 * image_size // 4 * depth[1])# 将特征图张量压平
        
        # 将两个卷积过来的铺平向量拼接在一起，形成一个大向量
        z = torch.cat((x, y), 1) #cat函数为拼接向量操作，1表示拼接的维度为第1个维度（0维度对应了batch）
        z = self.fc1(z) #第一层全链接
        z = F.relu(z)  #对于深层网络来说，激活函数用relu效果会比较好
        z = F.dropout(z, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        z = self.fc2(z) #第二层全链接
        z = F.relu(z)
        z = self.fc3(z) #第三层全链接
        z = F.relu(z)
        z = self.fc4(z) # 第四层全链接
        return z
    def set_filter_values(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为预训练式
        # 输入参数net为从硬盘加载的网络作为迁移源
        
        # 逐个儿为网络的两个卷积模块的权重和偏置进行赋值
        # 注意在赋值的时候需要用deepcopy而不能直接等于，或者copy。
        # 这是因为这种拷贝是将张量中的数值全部拷贝到了目标中，而不是拷贝地址
        # 如果不用deepcopy，由于我们将同一组参数（net.conv1.weight.data,bias）
        #  赋予了两组参数（net1_conv1.weight.data，net2_conv1.weight.data）
        # 所以它们会共享源net.conv1.weight.data中的地址，这样对于net1_conv1.weight.data
        # 的训练也自然会被用到了net2_conv1.weight.data中，但其实我们希望它们是两个不同的参数。
        self.net1_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net1_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net1_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net1_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        self.net2_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net2_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net2_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net2_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        
        # 将变量加载到GPU上        
        self.net1_conv1 = self.net1_conv1.cuda() if use_cuda else self.net1_conv1
        self.net1_conv2 = self.net1_conv2.cuda() if use_cuda else self.net1_conv2
        
        self.net2_conv1 = self.net2_conv1.cuda() if use_cuda else self.net2_conv1
        self.net2_conv2 = self.net2_conv2.cuda() if use_cuda else self.net2_conv2
    def set_filter_values_nograd(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为固定权重式
        # 调用set_filter_values为全部卷积核进行赋值
        self.set_filter_values(net)
        
        # 为了让我们的网络不被训练调整权值，我们需要设定每一个变量的requires_grad为False
        # 即不需要计算梯度值
        self.net1_conv1.weight.requires_grad = False
        self.net1_conv1.bias.requires_grad = False
        self.net1_conv2.weight.requires_grad = False
        self.net1_conv2.bias.requires_grad = False
        
        
        self.net2_conv1.weight.requires_grad = False
        self.net2_conv1.bias.requires_grad = False
        self.net2_conv2.weight.requires_grad = False
        self.net2_conv2.bias.requires_grad = False
def rightness(y, target):
    # 计算分类准确度的函数，y为模型预测的标签，target为数据的标签
    # 输入的y为一个矩阵，行对应了batch中的不同数据记录，列对应了不同的分类选择，数值对应了概率
    # 函数输出分别为预测与数据标签相等的个数，本次判断的所有数据个数
    out = torch.round(y.squeeze()).type(itype)
    out = out.eq(target).sum()
    out1 = y.size()[0]
    return(out, out1)

# %% [markdown]
# ## 四、数据迁移实验

# %% [markdown]
# ### 1. 无迁移实验
#
# 在本试验中，我们不迁移网络，直接训练整个网络

# %%
# 生成网络实例
net = Transfer()

# 如果存在GPU，则将网络加载到GPU中
if use_cuda:
    net = net.cuda()
    
# 定义损失函数，我们用最小均方误差来定义损失
criterion = nn.MSELoss()

# 定义优化器
optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
results = {}

# %%
# 开始训练网络
num_epochs = 1
records = []
for epoch in range(num_epochs):
    losses = []
    
    # 我们可以用zip命令来同时从两个数据加载器中加载数据，enumerate则给这个迭代附加上了计数
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        # 为了比较数据量大小对迁移学习的影响，我们只加载了部分数据，当数据加载个数idx大于
        # 全数据集的1/fraction的时候则不再加载后面的数据
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        optimizer.zero_grad()
        net.train()
        outputs = net(x1.clone().detach(), x2.clone().detach())
        # outputs的size为(batch_size,1),用squeeze降为(batch_size) -hq 20200727
        # 代码其他处同样处理
        outputs = outputs.squeeze()
        labels = y1 + y2
        loss = criterion(outputs, labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            # 在校验数据上计算计算准确率
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach(), x2.clone().detach())
                outputs = outputs.squeeze()
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])

# 在测试数据集上测试准确度
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach(), x2.clone().detach())
    outputs = outputs.squeeze()
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['notransfer'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：11.233806610107422, 校验误差：16.84, 准确率：0.10
# 第0周期，第(100/938)个撮，训练误差：11.922822952270508, 校验误差：8.80, 准确率：0.12
# 第0周期，第(200/938)个撮，训练误差：9.490021705627441, 校验误差：5.46, 准确率：0.16
# 第0周期，第(300/938)个撮，训练误差：8.146960258483887, 校验误差：4.93, 准确率：0.17
# 第0周期，第(400/938)个撮，训练误差：7.391635894775391, 校验误差：4.42, 准确率：0.19
# 第0周期，第(500/938)个撮，训练误差：6.857645511627197, 校验误差：4.32, 准确率：0.20
# 第0周期，第(600/938)个撮，训练误差：6.466929912567139, 校验误差：3.92, 准确率：0.22
# 第0周期，第(700/938)个撮，训练误差：6.133978366851807, 校验误差：4.05, 准确率：0.22
# 第0周期，第(800/938)个撮，训练误差：5.878579616546631, 校验误差：3.64, 准确率：0.23
# 第0周期，第(900/938)个撮，训练误差：5.670831203460693, 校验误差：3.67, 准确率：0.21

# %%
# 绘制实验结果，打印测试集上的准确度
plt.plot([i[0] for i in records])
plt.plot([i[1] for i in records])
plt.plot([100 * (1 - i[2]) for i in records])
right_ratio
# Out:
# tensor(0.2860, device='cuda:0')

# %% [markdown]
# ### 2. 迁移网络，预训练
#
# 在本试验中，我们将手写数字识别的卷积神经网络权重迁移过来，作为新的加法机网络的预训练值（也就是初始值）

# %%
net = Transfer()

# 为新网络赋予权重数值，注意我们只将卷积部分的网络进行迁移，而没有迁移全链接层
net.set_filter_values(original_net)

if use_cuda:
    net = net.cuda()

criterion = nn.MSELoss()

# 将需要训练的参数加载到优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad: #我们只将可以调整权重的变量加到了集合new_parameters
        new_parameters.append(para)
        
# 将new_parameters加载到了优化器中
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        outputs = outputs.squeeze()
        labels = y1 + y2
        loss = criterion(outputs,labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                outputs = outputs.squeeze()
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    outputs = outputs.squeeze()
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_pretrained'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：100.39, 校验误差：100.52, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：37.75, 校验误差：9.05, 准确率：0.12
# 第0周期，第(200/938)个撮，训练误差：23.03, 校验误差：7.15, 准确率：0.14
# 第0周期，第(300/938)个撮，训练误差：17.76, 校验误差：6.33, 准确率：0.16
# 第0周期，第(400/938)个撮，训练误差：14.94, 校验误差：6.04, 准确率：0.17
# 第0周期，第(500/938)个撮，训练误差：13.14, 校验误差：5.75, 准确率：0.18
# 第0周期，第(600/938)个撮，训练误差：11.87, 校验误差：5.30, 准确率：0.18
# 第0周期，第(700/938)个撮，训练误差：10.93, 校验误差：5.25, 准确率：0.17
# 第0周期，第(800/938)个撮，训练误差：10.19, 校验误差：4.64, 准确率：0.20
# 第0周期，第(900/938)个撮，训练误差：9.59, 校验误差：4.58, 准确率：0.21
# 第1周期，第(0/938)个撮，训练误差：4.14, 校验误差：4.76, 准确率：0.21
# 第1周期，第(100/938)个撮，训练误差：4.72, 校验误差：4.82, 准确率：0.20
# 第1周期，第(200/938)个撮，训练误差：4.63, 校验误差：4.14, 准确率：0.21
# 第1周期，第(300/938)个撮，训练误差：4.54, 校验误差：4.15, 准确率：0.19
# 第1周期，第(400/938)个撮，训练误差：4.43, 校验误差：3.91, 准确率：0.22
# 第1周期，第(500/938)个撮，训练误差：4.36, 校验误差：3.71, 准确率：0.23
# 第1周期，第(600/938)个撮，训练误差：4.29, 校验误差：3.76, 准确率：0.23
# 第1周期，第(700/938)个撮，训练误差：4.23, 校验误差：3.71, 准确率：0.25
# 第1周期，第(800/938)个撮，训练误差：4.19, 校验误差：3.52, 准确率：0.24
# 第1周期，第(900/938)个撮，训练误差：4.13, 校验误差：3.53, 准确率：0.25

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# tensor(0.2798, device='cuda:0')

# %% [markdown]
# ### 3.迁移，不更新权重
#
# 在这个试验中，我们首先将识别器的卷积层的权重全部迁移到了加法机的两个卷积部件中，但保持它们的权重不变，只允许后面的全链接层的权重可训练。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
net = Transfer()
# 迁移网络，并设置卷积部件的权重和偏置都不计算梯度
net.set_filter_values_nograd(original_net)
if use_cuda:
    net = net.cuda()
criterion = nn.MSELoss()

# 只将可更新的权重值加载到了优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad:
        new_parameters.append(para)
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 训练整个网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        outputs = outputs.squeeze()
        labels = y1 + y2
        labels = labels.type(dtype)
        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                outputs = outputs.squeeze()
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    outputs = outputs.squeeze()
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_fixed'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：97.02, 校验误差：96.41, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：19.65, 校验误差：8.43, 准确率：0.12
# 第0周期，第(200/938)个撮，训练误差：13.98, 校验误差：7.14, 准确率：0.15
# 第0周期，第(300/938)个撮，训练误差：11.63, 校验误差：6.46, 准确率：0.16
# 第0周期，第(400/938)个撮，训练误差：10.32, 校验误差：7.18, 准确率：0.17
# 第0周期，第(500/938)个撮，训练误差：9.50, 校验误差：6.55, 准确率：0.17
# 第0周期，第(600/938)个撮，训练误差：8.90, 校验误差：6.84, 准确率：0.18
# 第0周期，第(700/938)个撮，训练误差：8.47, 校验误差：5.39, 准确率：0.17
# 第0周期，第(800/938)个撮，训练误差：8.10, 校验误差：4.93, 准确率：0.20
# 第0周期，第(900/938)个撮，训练误差：7.77, 校验误差：4.69, 准确率：0.20
# 第1周期，第(0/938)个撮，训练误差：6.45, 校验误差：5.93, 准确率：0.20
# 第1周期，第(100/938)个撮，训练误差：5.09, 校验误差：4.63, 准确率：0.20
# 第1周期，第(200/938)个撮，训练误差：4.93, 校验误差：4.69, 准确率：0.19
# 第1周期，第(300/938)个撮，训练误差：4.86, 校验误差：4.78, 准确率：0.23
# 第1周期，第(400/938)个撮，训练误差：4.77, 校验误差：4.40, 准确率：0.21
# 第1周期，第(500/938)个撮，训练误差：4.69, 校验误差：4.13, 准确率：0.22
# 第1周期，第(600/938)个撮，训练误差：4.66, 校验误差：3.94, 准确率：0.21
# 第1周期，第(700/938)个撮，训练误差：4.59, 校验误差：4.08, 准确率：0.21
# 第1周期，第(800/938)个撮，训练误差：4.53, 校验误差：4.26, 准确率：0.23
# 第1周期，第(900/938)个撮，训练误差：4.50, 校验误差：3.91, 准确率：0.22
# F:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:431: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# F:\Anaconda\lib\site-packages\torch\nn\modules\loss.py:431: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# tensor(0.2372, device='cuda:0')

# %% [markdown]
# ### 4、结果比较
# 将三次实验的结果放到一起比较

# %%
y1, y2, y3 = results['notransfer'][0], results['transfer_pretrained'][0], results['transfer_fixed'][0]

# %%
plt.figure(figsize = (10, 7))
plt.plot([1 - i[2] for i in y1], 'o-', label = 'no transfer')
plt.plot([1 - i[2] for i in y2], 's:', label = 'transfer pretrained')
plt.plot([1 - i[2] for i in y3], '*-', label = 'transfer fixed')
plt.xlabel('Time')
plt.ylabel('Error Rate')
plt.legend()

# %%
results['notransfer'][1], results['transfer_pretrained'][1], results['transfer_fixed'][1]
# Out:
# (tensor(0.2860, device='cuda:0'),
#  tensor(0.2934, device='cuda:0'),
#  tensor(0.2372, device='cuda:0'))

# %%
experiments = {}
experiments[1] = results

# %%
experiments
# Out:
# {1: {'notransfer': [[[11.233807, 16.84358, tensor(0.1028, device='cuda:0')],
#     [11.922823, 8.8010645, tensor(0.1228, device='cuda:0')],
#     [9.490022, 5.4596562, tensor(0.1588, device='cuda:0')],
#     [8.14696, 4.928023, tensor(0.1730, device='cuda:0')],
#     [7.391636, 4.4167876, tensor(0.1946, device='cuda:0')],
#     [6.8576455, 4.318748, tensor(0.2016, device='cuda:0')],
#     [6.46693, 3.9246335, tensor(0.2194, device='cuda:0')],
#     [6.1339784, 4.047649, tensor(0.2204, device='cuda:0')],
#     [5.8785796, 3.6421041, tensor(0.2294, device='cuda:0')],
#     [5.670831, 3.6683474, tensor(0.2140, device='cuda:0')]],
#    tensor(0.2860, device='cuda:0')],
#   'transfer_pretrained': [[[100.38803,
#      100.519585,
#      tensor(0.0098, device='cuda:0')],
#     [37.745525, 9.046653, tensor(0.1172, device='cuda:0')],
#     [23.02579, 7.148262, tensor(0.1398, device='cuda:0')],
#     [17.75748, 6.3251266, tensor(0.1582, device='cuda:0')],
#     [14.942616, 6.037694, tensor(0.1676, device='cuda:0')],
#     [13.141695, 5.7521424, tensor(0.1838, device='cuda:0')],
#     [11.867466, 5.301555, tensor(0.1830, device='cuda:0')],
#     [10.932172, 5.2501035, tensor(0.1708, device='cuda:0')],
#     [10.188802, 4.644514, tensor(0.1966, device='cuda:0')],
#     [9.590104, 4.581025, tensor(0.2064, device='cuda:0')],
#     [4.139125, 4.763498, tensor(0.2084, device='cuda:0')],
#     [4.719764, 4.8177586, tensor(0.2014, device='cuda:0')],
#     [4.6276817, 4.135642, tensor(0.2072, device='cuda:0')],
#     [4.5372186, 4.145412, tensor(0.1938, device='cuda:0')],
#     [4.42966, 3.9148858, tensor(0.2154, device='cuda:0')],
#     [4.362444, 3.7108011, tensor(0.2284, device='cuda:0')],
#     [4.2898345, 3.7582536, tensor(0.2256, device='cuda:0')],
#     [4.2341175, 3.713416, tensor(0.2482, device='cuda:0')],
#     [4.185412, 3.5152059, tensor(0.2448, device='cuda:0')],
#     [4.128746, 3.5313764, tensor(0.2474, device='cuda:0')]],
#    tensor(0.2934, device='cuda:0')],
#   'transfer_fixed': [[[97.01575, 96.41422, tensor(0.0088, device='cuda:0')],
#     [19.65071, 8.431404, tensor(0.1246, device='cuda:0')],
#     [13.982151, 7.1445513, tensor(0.1514, device='cuda:0')],
#     [11.632292, 6.4626436, tensor(0.1550, device='cuda:0')],
#     [10.3220825, 7.1757154, tensor(0.1742, device='cuda:0')],
#     [9.5017185, 6.5481443, tensor(0.1696, device='cuda:0')],
#     [8.904805, 6.842514, tensor(0.1844, device='cuda:0')],
#     [8.466192, 5.390323, tensor(0.1658, device='cuda:0')],
#     [8.10183, 4.9255967, tensor(0.1998, device='cuda:0')],
#     [7.774919, 4.6853986, tensor(0.1976, device='cuda:0')],
#     [6.4541492, 5.926106, tensor(0.2000, device='cuda:0')],
#     [5.0939097, 4.6338983, tensor(0.1968, device='cuda:0')],
#     [4.9267716, 4.6935406, tensor(0.1930, device='cuda:0')],
#     [4.858345, 4.779489, tensor(0.2266, device='cuda:0')],
#     [4.772512, 4.4045777, tensor(0.2098, device='cuda:0')],
#     [4.687098, 4.1331205, tensor(0.2214, device='cuda:0')],
#     [4.6573696, 3.941798, tensor(0.2060, device='cuda:0')],
#     [4.5876575, 4.0795555, tensor(0.2136, device='cuda:0')],
#     [4.534255, 4.262669, tensor(0.2334, device='cuda:0')],
#     [4.504787, 3.9089959, tensor(0.2204, device='cuda:0')]],
#    tensor(0.2372, device='cuda:0')]}}

# %% [markdown]
# ## 综合试验
#
# 为了系统化的比较不同的参数对迁移学习的影响，我们做了一次大实验：
#
# 该试验包括了三重循环，分别是：
#
# 1、不同的迁移学习方法：无迁移、迁移固定权重、迁移预训练
#
# 2、每一个参数下重复实验times次
#
# 3、加载不同的数据集比例fraction
#
# 由于本试验需要消耗大量的计算时间，所以请慎重执行下面的语句。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
results = {} #记载实验结果
times = 1 # 每一组参数下实验都要被重复10次
fractions = [20, 10, 8, 6, 5, 4, 3, 2, 1] #所有的数据加载的比例值
for experiment in ['no transfer', 'transfer_fixed', 'transfer_pretrained']:
    for time in range(times):
        for fraction in fractions:
            
            # 分不同的迁移学习情况加载网络和优化器
            if experiment == 'no transfer':
                net = Transfer()
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
            if experiment == 'transfer_pretrained':
                net = Transfer()
                net.set_filter_values(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
            if experiment == 'transfer_fixed':
                net = Transfer()
                net.set_filter_values_nograd(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
                
            #开始迁移学习训练
            num_epochs = 20
            records = []
            for epoch in range(num_epochs):
                losses = []
                for idx, data in enumerate(zip(train_loader1, train_loader2)):
                    if idx >= (len(train_loader1) // fraction):
                        break
                    ((x1, y1), (x2, y2)) = data
                    if use_cuda:
                        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                    net.train()
                    optimizer.zero_grad()
                    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                    outputs = outputs.squeeze()
                    labels = y1 + y2
                    loss = criterion(outputs, labels.type(dtype))
                    loss.backward()
                    optimizer.step()
                    loss = loss.cpu() if use_cuda else loss
                    losses.append(loss.data.numpy())
                    if idx % 500 == 0:
                        val_losses = []
                        rights = []
                        net.eval()
                        for val_data in zip(val_loader1, val_loader2):
                            ((x1, y1), (x2, y2)) = val_data
                            if use_cuda:
                                x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                            outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                            outputs = outputs.squeeze()
                            labels = y1 + y2
                            loss = criterion(outputs, labels.type(dtype))
                            loss = loss.cpu() if use_cuda else loss
                            val_losses.append(loss.data.numpy())
                            right = rightness(outputs.data, labels)
                            rights.append(right)
                        right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
                        print('{}网络：第{}试验，比例{}, 第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'
                              .format(experiment,time,fraction,
                            epoch, idx, len(train_loader1),
                            np.mean(losses), np.mean(val_losses), right_ratio))
                        records.append([np.mean(losses), np.mean(val_losses), right_ratio])
            rights = []
            net.eval()
            for test_data in zip(test_loader1, test_loader2):
                ((x1, y1), (x2, y2)) = test_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                outputs = outputs.squeeze()
                labels = y1 + y2
                loss = criterion(outputs, labels.type(dtype))
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print(experiment,time,fraction)
            
            #将结果记录在了results集合之中，records记载了每一个打印周期的训练集损失函数、校验集损失函数、校验集正确率，
            #right_ratio记录了每次实验测试集的准确度
            results[(experiment,time,fraction)] = [records, right_ratio]
# Out:
# no transfer网络：第0试验，比例20, 第0周期，第(0/938)个撮，训练误差：101.83, 校验误差：98.44, 准确率：0.01
# no transfer网络：第0试验，比例20, 第1周期，第(0/938)个撮，训练误差：101.23, 校验误差：85.91, 准确率：0.02
# no transfer网络：第0试验，比例20, 第2周期，第(0/938)个撮，训练误差：70.55, 校验误差：70.80, 准确率：0.03
# no transfer网络：第0试验，比例20, 第3周期，第(0/938)个撮，训练误差：27.46, 校验误差：17.78, 准确率：0.09
# no transfer网络：第0试验，比例20, 第4周期，第(0/938)个撮，训练误差：19.10, 校验误差：16.27, 准确率：0.10
# no transfer网络：第0试验，比例20, 第5周期，第(0/938)个撮，训练误差：17.86, 校验误差：16.56, 准确率：0.11
# no transfer网络：第0试验，比例20, 第6周期，第(0/938)个撮，训练误差：12.40, 校验误差：16.26, 准确率：0.10
# no transfer网络：第0试验，比例20, 第7周期，第(0/938)个撮，训练误差：15.18, 校验误差：15.77, 准确率：0.11
# no transfer网络：第0试验，比例20, 第8周期，第(0/938)个撮，训练误差：16.17, 校验误差：15.87, 准确率：0.10
# no transfer网络：第0试验，比例20, 第9周期，第(0/938)个撮，训练误差：12.68, 校验误差：15.41, 准确率：0.11
# no transfer网络：第0试验，比例20, 第10周期，第(0/938)个撮，训练误差：11.67, 校验误差：15.38, 准确率：0.10
# no transfer网络：第0试验，比例20, 第11周期，第(0/938)个撮，训练误差：13.34, 校验误差：14.07, 准确率：0.11
# no transfer网络：第0试验，比例20, 第12周期，第(0/938)个撮，训练误差：11.24, 校验误差：12.54, 准确率：0.12
# no transfer网络：第0试验，比例20, 第13周期，第(0/938)个撮，训练误差：9.68, 校验误差：10.74, 准确率：0.12
# no transfer网络：第0试验，比例20, 第14周期，第(0/938)个撮，训练误差：10.38, 校验误差：9.60, 准确率：0.12
# no transfer网络：第0试验，比例20, 第15周期，第(0/938)个撮，训练误差：10.21, 校验误差：9.20, 准确率：0.13
# no transfer网络：第0试验，比例20, 第16周期，第(0/938)个撮，训练误差：8.39, 校验误差：8.88, 准确率：0.13
# no transfer网络：第0试验，比例20, 第17周期，第(0/938)个撮，训练误差：8.76, 校验误差：8.13, 准确率：0.12
# no transfer网络：第0试验，比例20, 第18周期，第(0/938)个撮，训练误差：8.42, 校验误差：8.55, 准确率：0.13
# no transfer网络：第0试验，比例20, 第19周期，第(0/938)个撮，训练误差：7.25, 校验误差：7.48, 准确率：0.14
# no transfer 0 20
# no transfer网络：第0试验，比例10, 第0周期，第(0/938)个撮，训练误差：89.48, 校验误差：102.52, 准确率：0.01
# no transfer网络：第0试验，比例10, 第1周期，第(0/938)个撮，训练误差
# no transfer网络：第0试验，比例1, 第11周期，第(0/938)个撮，训练误差：1.16, 校验误差：2.05, 准确率：0.35
# no transfer网络：第0试验，比例1, 第11周期，第(500/938)个撮，训练误差：1.98, 校验误差：1.93, 准确率：0.34
# no transfer网络：第0试验，比例1, 第12周期，第(0/938)个撮，训练误差：1.83, 校验误差：1.93, 准确率：0.35
# no transfer网络：第0试验，比例1, 第12周期，第(500/938)个撮，训练误差：1.87, 校验误差：1.88, 准确率：0.37
# no transfer网络：第0试验，比例1, 第13周期，第(0/938)个撮，训练误差：1.57, 校验误差：1.92, 准确率：0.37
# no transfer网络：第0试验，比例1, 第13周期，第(500/938)个撮，训练误差：1.86, 校验误差：1.81, 准确率：0.36
# no transfer网络：第0试验，比例1, 第14周期，第(0/938)个撮，训练误差：1.78, 校验误差：1.86, 准确率：0.37
# no transfer网络：第0试验，比例1, 第14周期，第(500/938)个撮，训练误差：1.81, 校验误差：1.80, 准确率：0.37
# no transfer网络：第0试验，比例1, 第15周期，第(0/938)个撮，训练误差：2.04, 校验误差：1.83, 准确率：0.37
# no transfer网络：第0试验，比例1, 第15周期，第(500/938)个撮，训练误差：1.72, 校验误差：1.74, 准确率：0.37
# no transfer网络：第0试验，比例1, 第16周期，第(0/938)个撮，训练误差：2.04, 校验误差：1.70, 准确率：0.38
# no transfer网络：第0试验，比例1, 第16周期，第(500/938)个撮，训练误差：1.66, 校验误差：1.71, 准确率：0.38
# no transfer网络：第0试验，比例1, 第17周期，第(0/938)个撮，训练误差：2.11, 校验误差：1.68, 准确率：0.38
# no transfer网络：第0试验，比例1, 第17周期，第(500/938)个撮，训练误差：1.60, 校验误差：1.62, 准确率：0.40
# no transfer网络：第0试验，比例1, 第18周期，第(0/938)个撮，训练误差：1.06, 校验误差：1.66, 准确率：0.40
# no transfer网络：第0试验，比例1, 第18周期，第(500/938)个撮，训练误差：1.59, 校验误差：1.58, 准确率：0.41
# no transfer网络：第0试验，比例1, 第19周期，第(0/938)个撮，训练误差：1.12, 校验误差：1.64, 准确率：0.40
# no transfer网络：第0试验，比例1, 第19周期，第(500/938)个撮，训练误差：1.55, 校验误差：1.68, 准确率：0.40
# no transfer 0 1
# transfer_fixed网络：第0试验，比例20, 第0周期，第(0/938)个撮，训练误差：98.44, 校验误差：94.12, 准确率：0.01
# transfer_fixed网络：第0试验，比例20, 第1周期，第(0/938)个撮，训练误差：12.35, 校验误差：11.36, 准确率：0.11
# transfer_fixed网络：第0试验，比例20, 第2周期，第(0/938)个撮，训练误差：11.18, 校验误差：9.08, 准确率：0.12
# transfer_fixed网络：第0试验，比例20, 第3周期，第(0/938)个撮，训练误差：8.22, 校验误差：8.15, 准确率：0.13
# transfer_fixed网络：第0试验，比例20, 第4周期，第(0/938)个撮，训练误差：6.89, 校验误差：7.97, 准确率：0.15
# transfer_fixed网络：第0试验，比例20, 第5周期，第(0/938)个撮，训练误差：7.01, 校验误差：7.08, 准确率：0.14
# transfer_fixed网络：第0试验，比例20, 第6周期，第(0/938)个撮，训练误差：13.24, 校验误差：6.95, 准确率：0.15
# transfer_fixed网络：第0试验，比例20, 第7周期，第(0/938)个撮，训练误差：6.76, 校验误差：6.39, 准确率：0.15
# transfer_fixed网络：第0试验，比例20, 第8周期，第(0/938)个撮，训练误差：8.77, 校验误差：6.86, 准确率：0.17
# transfer_fixed网络：第0试验，比例20, 第9周期，第(0/938)个撮，训练误差：4.70, 校验误差：5.95, 准确率：0.16
# transfer_fixed网络：第0试验，比例20, 第10周期，第(0/938)个撮，训练误差：5.55, 校验误差：6.33, 准确率：0.17
# transfer_fixed网络：第0试验，比例20, 第11周期，第(0/938)个撮，训练误差：8.02, 校验误差：5.93, 准确率：0.17
# transfer_fixed网络：第0试验，比例20, 第12周期，第(0/938)个撮，训练误差：6.17, 校验误差：6.16, 准确率：0.18
# transfer_fixed网络：第0试验，比例20, 第13周期，第(0/938)个撮，训练误差：5.40, 校验误差：5.55, 准确率：0.17
# transfer_fixed网络：第0试验，比例20, 第14周期，第(0/938)个撮，训练误差
# transfer_fixed网络：第0试验，比例2, 第10周期，第(0/938)个撮，训练误差：3.72, 校验误差：3.14, 准确率：0.27
# transfer_fixed网络：第0试验，比例2, 第11周期，第(0/938)个撮，训练误差：2.75, 校验误差：3.68, 准确率：0.26
# transfer_fixed网络：第0试验，比例2, 第12周期，第(0/938)个撮，训练误差：2.47, 校验误差：2.95, 准确率：0.29
# transfer_fixed网络：第0试验，比例2, 第13周期，第(0/938)个撮，训练误差：2.21, 校验误差：2.66, 准确率：0.29
# transfer_fixed网络：第0试验，比例2, 第14周期，第(0/938)个撮，训练误差：3.20, 校验误差：2.53, 准确率：0.31
# transfer_fixed网络：第0试验，比例2, 第15周期，第(0/938)个撮，训练误差：2.90, 校验误差：2.64, 准确率：0.32
# transfer_fixed网络：第0试验，比例2, 第16周期，第(0/938)个撮，训练误差：3.80, 校验误差：2.57, 准确率：0.28
# transfer_fixed网络：第0试验，比例2, 第17周期，第(0/938)个撮，训练误差：3.11, 校验误差：2.52, 准确率：0.30
# transfer_fixed网络：第0试验，比例2, 第18周期，第(0/938)个撮，训练误差：3.49, 校验误差：2.48, 准确率：0.32
# transfer_fixed网络：第0试验，比例2, 第19周期，第(0/938)个撮，训练误差：3.03, 校验误差：2.40, 准确率：0.32
# transfer_fixed 0 2
# transfer_fixed网络：第0试验，比例1, 第0周期，第(0/938)个撮，训练误差：96.72, 校验误差：89.60, 准确率：0.01
# transfer_fixed网络：第0试验，比例1, 第0周期，第(500/938)个撮，训练误差：9.49, 校验误差：5.90, 准确率：0.16
# transfer_fixed网络：第0试验，比例1, 第1周期，第(0/938)个撮，训练误差：4.75, 校验误差：4.99, 准确率：0.20
# transfer_fixed网络：第0试验，比例1, 第1周期，第(500/938)个撮，训练误差：4.76, 校验误差：4.17, 准确率：0.20
# transfer_fixed网络：第0试验，比例1, 第2周期，第(0/938)个撮，训练误差：4.07, 校验误差：3.89, 准确率：0.22
# transfer_fixed网络：第0试验，比例1, 第2周期，第(500/938)个撮，训练误差：4.07, 校验误差：3.60, 准确率：0.24
# transfer_fixed网络：第0试验，比例1, 第3周期，第(0/938)个撮，训练误差：3.82, 校验误差：3.48, 准确率：0.26
# transfer_fixed网络：第0试验，比例1, 第3周期，第(500/938)个撮，训练误差：3.68, 校验误差：3.32, 准确率：0.25
# transfer_fixed网络：第0试验，比例1, 第4周期，第(0/938)个撮，训练误差：2.81, 校验误差：3.31, 准确率：0.27
# transfer_fixed网络：第0试验，比例1, 第4周期，第(500/938)个撮，训练误差：3.34, 校验误差：3.27, 准确率：0.26
# transfer_fixed网络：第0试验，比例1, 第5周期，第(0/938)个撮，训练误差：3.01, 校验误差：2.90, 准确率：0.27
# transfer_fixed网络：第0试验，比例1, 第5周期，第(500/938)个撮，训练误差：3.12, 校验误差：2.82, 准确率：0.30
# transfer_fixed网络：第0试验，比例1, 第6周期，第(0/938)个撮，训练误差：4.11, 校验误差：2.78, 准确率：0.28
# transfer_fixed网络：第0试验，比例1, 第6周期，第(500/938)个撮，训练误差：2.98, 校验误差：2.87, 准确率：0.29
# transfer_fixed网络：第0试验，比例1, 第7周期，第(0/938)个撮，训练误差：3.09, 校验误差：2.63, 准确率：0.28
# transfer_fixed网络：第0试验，比例1, 第7周期，第(500/938)个撮，训练误差：2.83, 校验误差：2.60, 准确率：0.31
# transfer_fixed网络：第0试验，比例1, 第8周期，第(0/938)个撮，训练误差：3.21, 校验误差：2.67, 准确率：0.31
# transfer_fixed网络：第0试验，比例1, 第8周期，第(500/938)个撮，训练误差：2.65, 校验误差：2.61, 准确率：0.32
# transfer_fixed网络：第0试验，比例1, 第9周期，第(0/938)个撮，训练误差：3.10, 校验误差：2.57, 准确率：0.30
# transfer_fixed网络：第0试验，比例1, 第9周期，第(500/938)个撮，训练误差：2.55, 校验误差：2.45, 准确率：0.33
# transfer_fixed网络：第0试验，比例1, 第10周期，第(0/938)个撮，训练误差：1.95, 校验误差：2.45, 准确率：0.31
# transfer_fixed网络：第0试验，比例1, 第10周期，第(500/938)个撮，训练误差：2.42, 校验误差：2.40, 准确率：0.33
# transfer_fixed网络：第0试验，比例1, 第11周期，第(0/938)个撮，训练误差：2.07, 校验误差：2.19, 准确率：0.34
# transfer_fixed网络：第0试验，比例1, 第11周期，第(500/938)个撮，训练误差：2.38, 校验误差：2.50, 准确率：0.33
# transfer_fixed网络：第0试验，比例1, 第12周期，第(0/938)个撮，训练误差：1.95, 校验误差：2.18, 准确率：0.34
# transfer_fixed网络：第0试验，比例1, 第12周期，第(500/938)个撮，训练误差：2.24, 校验误差：2.12, 准确率：0.34
# transfer_fixed网络：第0试验，比例1, 第13周期，第(0/938)个撮，训练误差：1.98, 校验误差：2.05, 准确率：0.37
# transfer_fixed网络：第0试验，比例1, 第13周期，第(500/938)个撮，训练误差：2.14, 校验误差：2.04, 准确率：0.37
# transfer_fixed网络：第0试验，比例1, 第14周期，第(0/938)个撮，训练误差：2.55, 校验误差：1.95, 准确率：0.37
# transfer_fixed网络：第0试验，比例1, 第14周期，第(500/938)个撮，训练误差：2.02, 校验误差：2.01, 准确率：0.38
# transfer_fixed网络：第0试验，比例1, 第15周期，第(0/938)个撮，训练误差：2.25, 校验误差：1.88, 准确率：0.38
# transfer_fixed网络：第0试验，比例1, 第15周期，第(500/938)个撮，训练误差：1.92, 校验误差：1.82, 准确率：0.38
# transfer_fixed网络：第0试验，比例1, 第16周期，第(0/938)个撮，训练误差：2.13, 校验误差：1.80, 准确率：0.40
# transfer_fixed网络：第0试验，比例1, 第16周期，第(500/938)个撮，训练误差：1.86, 校验误差：1.87, 准确率：0.40
# transfer_fixed网络：第0试验，比例1, 第17周期，第(0/938)个撮，训练误差：1.67, 校验误差：1.73, 准确率：0.41
# transfer_fixed网络：第0试验，比例1, 第17周期，第(500/938)个撮，训练误差：1.78, 校验误差：1.80, 准确率：0.41
# transfer_fixed网络：第0试验，比例1, 第18周期，第(0/938)个撮，训练误差：1.61, 校验误差：1.69, 准确率：0.41
# transfer_fixed网络：第0试验，比例1, 第18周期，第(500/938)个撮，训练误差：1.69, 校验误差：1.72, 准确率：0.43
# transfer_fixed网络：第0试验，比例1, 第19周期，第(0/938)个撮，训练误差：1.74, 校验误差：1.64, 准确率：0.43
# transfer_fixed网络：第0试验，比例1, 第19周期，第(500/938)个撮，训练误差：1.64, 校验误差：1.63, 准确率：0.45
# transfer_fixed 0 1
# transfer_pretrained网络：第0试验，比例20, 第0周期，第(0/938)个撮，训练误差：104.34, 校验误差：88.18, 准确率：0.01
# transfer_pretrained网络：第0试验，比例20, 第1周期，第(0/938)个撮，训练误差：12.52, 校验误差：10.73, 准确率：0.12
# transfer_pretrained网络：第0试验，比例20, 第2周期，第(0/938)个撮，训练误差：10.44, 校验误差：8.76, 准确率：0.12
# transfer_pretrained网络：第0试验，比例20, 第3周期，第(0/938)个撮，训练误差：7.54, 校验误差：7.55, 准确率：0.14
# transfer_pretrained网络：第0试验，比例20, 第4周期，第(0/938)个撮，训练误差：8.84, 校验误差：6.91, 准确率：0.15
# transfer_pretrained网络：第0试验，比例20, 第5周期，第(0/938)个撮，训练误差：7.85, 校验误差：7.20, 准确率：0.15
# transfer_pretrained网络：第0试验，比例20, 第6周期，第(0/938)个撮，训练误差：7.13, 校验误差：6.46, 准确率：0.16
# transfer_pretrained网络：第0试验，比例20, 第7周期，第(0/938)个撮，训练误差：9.46, 校验误差：7.09, 准确率：0.17
# transfer_pretrained网络：第0试验，比例20, 第8周期，第(0/938)个撮，训练误差：8.77, 校验误差：6.03, 准确率：0.16
# transfer_pretrained网络：第0试验，比例20, 第9周期，第(0/938)个撮，训练误差：4.79, 校验误差：5.96, 准确率：0.15
# transfer_pretrained网络：第0试验，比例20, 第10周期，第(0/938)个撮，训练误差：4.40, 校验误差：5.90, 准确率：0.18
# transfer_pretrained网络：第0试验，比例20, 第11周期，第(0/938)个撮，训练误差：7.33, 校验误差：5.35, 准确率：0.17
# transfer_pretrained网络：第0试验，比例20, 第12周期，第(0/938)个撮，训练误差：6.88, 校验误差：5.42, 准确率：0.17
# transfer_pretrained网络：第0试验，比例20, 第13周期，第(0/938)个撮，训练误差：5.07, 校验误差：5.43, 准确率：0.18
# transfer_pretrained网络：第0试验，比例20, 第14周期，第(0/938)个撮，训练误差：6.46, 校验误差：5.31, 准确率：0.19
# transfer_pretrained网络：第0试验，比例20, 第15周期，第(0/938)个撮，训练误差：4.07, 校验误差：4.96, 准确率：0.18
# transfer_pretrained网络：第0试验，比例20, 第16周期，第(0/938)个撮，训练误差：3.96, 校验误差：4.82, 准确率：0.19
# transfer_pretrained网络：第0试验，比例20, 第17周期，第(0/938)个撮，训练误差：4.79, 校验误差：4.72, 准确率：0.20
# transfer_pretrained网络：第0试验，比例20, 第18周期，第(0/938)个撮，训练误差：5.93, 校验误差：4.84, 准确率：0.18
# transfer_pretrained网络：第0试验，比例20, 第19周期，第(0/938)个撮，训练误差：4.85, 校验误差：4.74, 准确率：0.21
# transfer_pretrained 0 20
# transfer_pretrained网络：第0试验，比例10, 第0周期，第(0/938)个撮，训练误差：84.48, 校验误差：92.68, 准确率：0.01
# transfer_pretrained网络：第0试验，比例10, 第1周期，第(0/938)个撮，训练误差：8.71, 校验误差：8.63, 准确率：0.14
# transfer_pretrained网络：第0试验，比例10, 第2周期，第(0/938)个撮，训练误差：11.74, 校验误差：7.17, 准确率：0.14
# transfer_pretrained网络：第0试验，比例10, 第3周期，第(0/938)个撮，训练误差：6.76, 校验误差：6.85, 准确率：0.14
# transfer_pretrained网络：第0试验，比例10, 第4周期，第(0/938)个撮，训练误差：8.35, 校验误差：6.09, 准确率：0.16
# transfer_pretrained网络：第0试验，比例10, 第5周期，第(0/938)个撮，训练误差：5.79, 校验误差：6.91, 准确率：0.14
# transfer_pretrained网络：第0试验，比例10, 第6周期，第(0/938)个撮，训练误差：5.40, 校验误差：6.04, 准确率：0.14
# transfer_pretrained网络：第0试验，比例10, 第7周期，第(0/938)个撮，训练误差：4.44, 校验误差：5.02, 准确率：0.19
# transfer_pretrained网络：第0试验，比例10, 第8周期，第(0/938)个撮，训练误差：4.30, 校验误差：4.64, 准确率：0.20
# transfer_pretrained网络：第0试验，比例10, 第9周期，第(0/938)个撮，训练误差：4.51, 校验误差：4.82, 准确率：0.20
# transfer_pretrained网络：第0试验，比例10, 第10周期，第(0/938)个撮，训练误差：4.47, 校验误差：4.53, 准确率：0.19
# transfer_pretrained网络：第0试验，比例10, 第11周期，第(0/938)个撮，训练误差：4.26, 校验误差：4.17, 准确率：0.22
# transfer_pretrained网络：第0试验，比例10, 第12周期，第(0/938)个撮，训练误差：3.13, 校验误差：4.15, 准确率：0.22
# transfer_pretrained网络：第0试验，比例10, 第13周期，第(0/938)个撮，训练误差：4.53, 校验误差：3.93, 准确率：0.22
# transfer_pretrained网络：第0试验，比例10, 第14周期，第(0/938)个撮，训练误差：4.33, 校验误差：3.93, 准确率：0.23
# transfer_pretrained网络：第0试验，比例10, 第15周期，第(0/938)个撮，训练误差：5.21, 校验误差：4.02, 准确率：0.20
# transfer_pretrained网络：第0试验，比例10, 第16周期，第(0/938)个撮，训练误差：3.80, 校验误差：4.21, 准确率：0.23
# transfer_pretrained网络：第0试验，比例10, 第17周期，第(0/938)个撮，训练误差：3.67, 校验误差：3.78, 准确率：0.24
# transfer_pretrained网络：第0试验，比例10, 第18周期，第(0/938)个撮，训练误差：3.47, 校验误差：3.41, 准确率：0.24
# transfer_pretrained网络：第0试验，比例10, 第19周期，第(0/938)个撮，训练误差：5.59, 校验误差：3.50, 准确率：0.24
# transfer_pretrained 0 10
# transfer_pretrained网络：第0试验，比例8, 第0周期，第(0/938)个撮，训练误差：96.23, 校验误差：90.03, 准确率：0.01
# transfer_pretrained网络：第0试验，比例8, 第1周期，第(0/938)个撮，训练误差：8.23, 校验误差：8.23, 准确率：0.13
# transfer_pretrained网络：第0试验，比例8, 第2周期，第(0/938)个撮，训练误差：6.98, 校验误差：7.14, 准确率：0.15
# transfer_pretrained网络：第0试验，比例8, 第3周期，第(0/938)个撮，训练误差：6.47, 校验误差：6.03, 准确率：0.16
# transfer_pretrained网络：第0试验，比例8, 第4周期，第(0/938)个撮，训练误差：4.92, 校验误差：5.90, 准确率：0.17
# transfer_pretrained网络：第0试验，比例8, 第5周期，第(0/938)个撮，训练误差：6.65, 校验误差：5.16, 准确率：0.18
# transfer_pretrained网络：第0试验，比例8, 第6周期，第(0/938)个撮，训练误差：5.24, 校验误差：5.31, 准确率：0.20
# transfer_pretrained网络：第0试验，比例8, 第7周期，第(0/938)个撮，训练误差：5.76, 校验误差：5.34, 准确率：0.20
# transfer_pretrained网络：第0试验，比例8, 第8周期，第(0/938)个撮，训练误差：4.52, 校验误差：4.54, 准确率：0.22
# transfer_pretrained网络：第0试验，比例8, 第9周期，第(0/938)个撮，训练误差：4.38, 校验误差：4.25, 准确率：0.21
# transfer_pretrained网络：第0试验，比例8, 第10周期，第(0/938)个撮，训练误差：4.10, 校验误差：4.35, 准确率：0.20
# transfer_pretrained网络：第0试验，比例8, 第11周期，第(0/938)个撮，训练误差：3.89, 校验误差：3.81, 准确率：0.23
# transfer_pretrained网络：第0试验，比例8, 第12周期，第(0/938)个撮，训练误差：3.69, 校验误差：4.25, 准确率：0.23
# transfer_pretrained网络：第0试验，比例8, 第13周期，第(0/938)个撮，训练误差：3.64, 校验误差：3.74, 准确率：0.23
# transfer_pretrained网络：第0试验，比例8, 第14周期，第(0/938)个撮，训练误差：3.27, 校验误差：3.77, 准确率：0.25
# transfer_pretrained网络：第0试验，比例8, 第15周期，第(0/938)个撮，训练误差：4.62, 校验误差：3.50, 准确率：0.25
# transfer_pretrained网络：第0试验，比例8, 第16周期，第(0/938)个撮，训练误差：3.97, 校验误差：3.52, 准确率：0.25
# transfer_pretrained网络：第0试验，比例8, 第17周期，第(0/938)个撮，训练误差：3.28, 校验误差：3.27, 准确率：0.26
# transfer_pretrained网络：第0试验，比例8, 第18周期，第(0/938)个撮，训练误差：3.71, 校验误差：3.27, 准确率：0.26
# transfer_pretrained网络：第0试验，比例8, 第19周期，第(0/938)个撮，训练误差：3.49, 校验误差：3.16, 准确率：0.27
# transfer_pretrained 0 8
# transfer_pretrained网络：第0试验，比例6, 第0周期，第(0/938)个撮，训练误差：116.04, 校验误差：100.49, 准确率：0.01
# transfer_pretrained网络：第0试验，比例6, 第1周期，第(0/938)个撮，训练误差：7.18, 校验误差：7.50, 准确率：0.14
# transfer_pretrained网络：第0试验，比例6, 第2周期，第(0/938)个撮，训练误差：6.47, 校验误差：6.96, 准确率：0.17
# transfer_pretrained网络：第0试验，比例6, 第3周期，第(0/938)个撮，训练误差：5.71, 校验误差：5.50, 准确率：0.16
# transfer_pretrained网络：第0试验，比例6, 第4周期，第(0/938)个撮，训练误差：4.00, 校验误差：5.45, 准确率：0.20
# transfer_pretrained网络：第0试验，比例6, 第5周期，第(0/938)个撮，训练误差：3.71, 校验误差：4.71, 准确率：0.20
# transfer_pretrained网络：第0试验，比例6, 第6周期，第(0/938)个撮，训练误差：3.52, 校验误差：4.55, 准确率：0.19
# transfer_pretrained网络：第0试验，比例6, 第7周期，第(0/938)个撮，训练误差：3.97, 校验误差：4.50, 准确率：0.24
# transfer_pretrained网络：第0试验，比例6, 第8周期，第(0/938)个撮，训练误差：4.25, 校验误差：4.06, 准确率：0.23
# transfer_pretrained网络：第0试验，比例6, 第9周期，第(0/938)个撮，训练误差：3.52, 校验误差：4.49, 准确率：0.24
# transfer_pretrained网络：第0试验，比例6, 第10周期，第(0/938)个撮，训练误差：3.52, 校验误差：3.75, 准确率：0.25
# transfer_pretrained网络：第0试验，比例6, 第11周期，第(0/938)个撮，训练误差：3.04, 校验误差：3.44, 准确率：0.24
# transfer_pretrained网络：第0试验，比例6, 第12周期，第(0/938)个撮，训练误差：5.56, 校验误差：3.88, 准确率：0.24
# transfer_pretrained网络：第0试验，比例6, 第13周期，第(0/938)个撮，训练误差：2.08, 校验误差：3.28, 准确率：0.26
# transfer_pretrained网络：第0试验，比例6, 第14周期，第(0/938)个撮，训练误差：3.16, 校验误差：3.26, 准确率：0.25
# transfer_pretrained网络：第0试验，比例6, 第15周期，第(0/938)个撮，训练误差：4.36, 校验误差：3.20, 准确率：0.25
# transfer_pretrained网络：第0试验，比例6, 第16周期，第(0/938)个撮，训练误差：3.50, 校验误差：3.04, 准确率：0.26
# transfer_pretrained网络：第0试验，比例6, 第17周期，第(0/938)个撮，训练误差：2.44, 校验误差：3.07, 准确率：0.27
# transfer_pretrained网络：第0试验，比例6, 第18周期，第(0/938)个撮，训练误差：2.70, 校验误差：3.11, 准确率：0.28
# transfer_pretrained网络：第0试验，比例6, 第19周期，第(0/938)个撮，训练误差：3.36, 校验误差：2.81, 准确率：0.28
# transfer_pretrained 0 6
# transfer_pretrained网络：第0试验，比例5, 第0周期，第(0/938)个撮，训练误差：92.89, 校验误差：97.48, 准确率：0.01
# transfer_pretrained网络：第0试验，比例5, 第1周期，第(0/938)个撮，训练误差：6.62, 校验误差：8.19, 准确率：0.15
# transfer_pretrained网络：第0试验，比例5, 第2周期，第(0/938)个撮，训练误差：7.04, 校验误差：6.03, 准确率：0.17
# transfer_pretrained网络：第0试验，比例5, 第3周期，第(0/938)个撮，训练误差：5.88, 校验误差：5.45, 准确率：0.16
# transfer_pretrained网络：第0试验，比例5, 第4周期，第(0/938)个撮，训练误差：6.42, 校验误差：4.83, 准确率：0.20
# transfer_pretrained网络：第0试验，比例5, 第5周期，第(0/938)个撮，训练误差：3.68, 校验误差：4.34, 准确率：0.21
# transfer_pretrained网络：第0试验，比例5, 第6周期，第(0/938)个撮，训练误差：5.68, 校验误差：4.22, 准确率：0.20
# transfer_pretrained网络：第0试验，比例5, 第7周期，第(0/938)个撮，训练误差：4.24, 校验误差：3.84, 准确率：0.24
# transfer_pretrained网络：第0试验，比例5, 第8周期，第(0/938)个撮，训练误差：3.28, 校验误差：3.65, 准确率：0.24
# transfer_pretrained网络：第0试验，比例5, 第9周期，第(0/938)个撮，训练误差：3.09, 校验误差：3.80, 准确率：0.25
# transfer_pretrained网络：第0试验，比例5, 第10周期，第(0/938)个撮，训练误差：4.35, 校验误差：3.42, 准确率：0.24
# transfer_pretrained网络：第0试验，比例5, 第11周期，第(0/938)个撮，训练误差：3.42, 校验误差：3.46, 准确率：0.28
# transfer_pretrained网络：第0试验，比例5, 第12周期，第(0/938)个撮，训练误差：2.79, 校验误差：3.12, 准确率：0.26
# transfer_pretrained网络：第0试验，比例5, 第13周期，第(0/938)个撮，训练误差：4.25, 校验误差：3.28, 准确率：0.26
# transfer_pretrained网络：第0试验，比例5, 第14周期，第(0/938)个撮，训练误差：2.64, 校验误差：3.22, 准确率：0.28
# transfer_pretrained网络：第0试验，比例5, 第15周期，第(0/938)个撮，训练误差：4.12, 校验误差：2.96, 准确率：0.29
# transfer_pretrained网络：第0试验，比例5, 第16周期，第(0/938)个撮，训练误差：2.89, 校验误差：2.84, 准确率：0.29
# transfer_pretrained网络：第0试验，比例5, 第17周期，第(0/938)个撮，训练误差：2.89, 校验误差：2.84, 准确率：0.29
# transfer_pretrained网络：第0试验，比例5, 第18周期，第(0/938)个撮，训练误差：2.89, 校验误差：2.72, 准确率：0.29
# transfer_pretrained网络：第0试验，比例5, 第19周期，第(0/938)个撮，训练误差：3.63, 校验误差：2.72, 准确率：0.28
# transfer_pretrained 0 5
# transfer_pretrained网络：第0试验，比例4, 第0周期，第(0/938)个撮，训练误差：120.50, 校验误差：101.74, 准确率：0.01
# transfer_pretrained网络：第0试验，比例4, 第1周期，第(0/938)个撮，训练误差：9.87, 校验误差：6.88, 准确率：0.15
# transfer_pretrained网络：第0试验，比例4, 第2周期，第(0/938)个撮，训练误差：7.39, 校验误差：5.70, 准确率：0.16
# transfer_pretrained网络：第0试验，比例4, 第3周期，第(0/938)个撮，训练误差：3.82, 校验误差：4.96, 准确率：0.17
# transfer_pretrained网络：第0试验，比例4, 第4周期，第(0/938)个撮，训练误差：6.67, 校验误差：4.65, 准确率：0.21
# transfer_pretrained网络：第0试验，比例4, 第5周期，第(0/938)个撮，训练误差：3.38, 校验误差：4.18, 准确率：0.24
# transfer_pretrained网络：第0试验，比例4, 第6周期，第(0/938)个撮，训练误差：4.60, 校验误差：4.11, 准确率：0.24
# transfer_pretrained网络：第0试验，比例4, 第7周期，第(0/938)个撮，训练误差：4.01, 校验误差：3.64, 准确率：0.23
# transfer_pretrained网络：第0试验，比例4, 第8周期，第(0/938)个撮，训练误差：4.30, 校验误差：3.46, 准确率：0.25
# transfer_pretrained网络：第0试验，比例4, 第9周期，第(0/938)个撮，训练误差：2.74, 校验误差：3.44, 准确率：0.26
# transfer_pretrained网络：第0试验，比例4, 第10周期，第(0/938)个撮，训练误差：4.14, 校验误差：3.41, 准确率：0.26
# transfer_pretrained网络：第0试验，比例4, 第11周期，第(0/938)个撮，训练误差：2.81, 校验误差：3.05, 准确率：0.25
# transfer_pretrained网络：第0试验，比例4, 第12周期，第(0/938)个撮，训练误差：2.82, 校验误差：3.01, 准确率：0.27
# transfer_pretrained网络：第0试验，比例4, 第13周期，第(0/938)个撮，训练误差：2.51, 校验误差：3.36, 准确率：0.27
# transfer_pretrained网络：第0试验，比例4, 第14周期，第(0/938)个撮，训练误差：3.73, 校验误差：2.87, 准确率：0.26
# transfer_pretrained网络：第0试验，比例4, 第15周期，第(0/938)个撮，训练误差：2.93, 校验误差：2.75, 准确率：0.26
# transfer_pretrained网络：第0试验，比例4, 第16周期，第(0/938)个撮，训练误差：3.17, 校验误差：3.04, 准确率：0.29
# transfer_pretrained网络：第0试验，比例4, 第17周期，第(0/938)个撮，训练误差：3.98, 校验误差：2.65, 准确率：0.28
# transfer_pretrained网络：第0试验，比例4, 第18周期，第(0/938)个撮，训练误差：2.80, 校验误差：2.56, 准确率：0.31
# transfer_pretrained网络：第0试验，比例4, 第19周期，第(0/938)个撮，训练误差：1.94, 校验误差：2.56, 准确率：0.30
# transfer_pretrained 0 4
# transfer_pretrained网络：第0试验，比例3, 第0周期，第(0/938)个撮，训练误差：100.65, 校验误差：98.31, 准确率：0.01
# transfer_pretrained网络：第0试验，比例3, 第1周期，第(0/938)个撮，训练误差：6.91, 校验误差：6.99, 准确率：0.14
# transfer_pretrained网络：第0试验，比例3, 第2周期，第(0/938)个撮，训练误差：6.19, 校验误差：5.77, 准确率：0.16
# transfer_pretrained网络：第0试验，比例3, 第3周期，第(0/938)个撮，训练误差：5.45, 校验误差：4.62, 准确率：0.20
# transfer_pretrained网络：第0试验，比例3, 第4周期，第(0/938)个撮，训练误差：4.94, 校验误差：3.91, 准确率：0.21
# transfer_pretrained网络：第0试验，比例3, 第5周期，第(0/938)个撮，训练误差：3.92, 校验误差：3.67, 准确率：0.25
# transfer_pretrained网络：第0试验，比例3, 第6周期，第(0/938)个撮，训练误差：3.02, 校验误差：3.45, 准确率：0.23
# transfer_pretrained网络：第0试验，比例3, 第7周期，第(0/938)个撮，训练误差：2.73, 校验误差：3.66, 准确率：0.26
# transfer_pretrained网络：第0试验，比例3, 第8周期，第(0/938)个撮，训练误差：2.54, 校验误差：3.03, 准确率：0.26
# transfer_pretrained网络：第0试验，比例3, 第9周期，第(0/938)个撮，训练误差：2.85, 校验误差：3.04, 准确率：0.27
# transfer_pretrained网络：第0试验，比例3, 第10周期，第(0/938)个撮，训练误差：3.53, 校验误差：3.13, 准确率：0.28
# transfer_pretrained网络：第0试验，比例3, 第11周期，第(0/938)个撮，训练误差：4.20, 校验误差：2.93, 准确率：0.28
# transfer_pretrained网络：第0试验，比例3, 第12周期，第(0/938)个撮，训练误差：2.64, 校验误差：2.75, 准确率：0.29
# transfer_pretrained网络：第0试验，比例3, 第13周期，第(0/938)个撮，训练误差：2.67, 校验误差：2.69, 准确率：0.31
# transfer_pretrained网络：第0试验，比例3, 第14周期，第(0/938)个撮，训练误差：2.30, 校验误差：2.88, 准确率：0.30
# transfer_pretrained网络：第0试验，比例3, 第15周期，第(0/938)个撮，训练误差：2.35, 校验误差：2.48, 准确率：0.30
# transfer_pretrained网络：第0试验，比例3, 第16周期，第(0/938)个撮，训练误差：2.39, 校验误差：2.66, 准确率：0.30
# transfer_pretrained网络：第0试验，比例3, 第17周期，第(0/938)个撮，训练误差：1.60, 校验误差：2.58, 准确率：0.32
# transfer_pretrained网络：第0试验，比例3, 第18周期，第(0/938)个撮，训练误差：1.69, 校验误差：2.46, 准确率：0.33
# transfer_pretrained网络：第0试验，比例3, 第19周期，第(0/938)个撮，训练误差：2.56, 校验误差：2.46, 准确率：0.32
# transfer_pretrained 0 3
# transfer_pretrained网络：第0试验，比例2, 第0周期，第(0/938)个撮，训练误差：104.47, 校验误差：97.37, 准确率：0.01
# transfer_pretrained网络：第0试验，比例2, 第1周期，第(0/938)个撮，训练误差：4.46, 校验误差：5.74, 准确率：0.17
# transfer_pretrained网络：第0试验，比例2, 第2周期，第(0/938)个撮，训练误差：4.44, 校验误差：4.97, 准确率：0.22
# transfer_pretrained网络：第0试验，比例2, 第3周期，第(0/938)个撮，训练误差：4.51, 校验误差：4.02, 准确率：0.20
# transfer_pretrained网络：第0试验，比例2, 第4周期，第(0/938)个撮，训练误差：4.33, 校验误差：3.72, 准确率：0.21
# transfer_pretrained网络：第0试验，比例2, 第5周期，第(0/938)个撮，训练误差：3.99, 校验误差：3.31, 准确率：0.25
# transfer_pretrained网络：第0试验，比例2, 第6周期，第(0/938)个撮，训练误差：2.93, 校验误差：2.98, 准确率：0.28
# transfer_pretrained网络：第0试验，比例2, 第7周期，第(0/938)个撮，训练误差：2.74, 校验误差：2.74, 准确率：0.27
# transfer_pretrained网络：第0试验，比例2, 第8周期，第(0/938)个撮，训练误差：1.74, 校验误差：2.76, 准确率：0.29
# transfer_pretrained网络：第0试验，比例2, 第9周期，第(0/938)个撮，训练误差：2.77, 校验误差：2.57, 准确率：0.30
# transfer_pretrained网络：第0试验，比例2, 第10周期，第(0/938)个撮，训练误差：3.16, 校验误差：2.51, 准确率：0.32
# transfer_pretrained网络：第0试验，比例2, 第11周期，第(0/938)个撮，训练误差：2.17, 校验误差：3.33, 准确率：0.27
# transfer_pretrained网络：第0试验，比例2, 第12周期，第(0/938)个撮，训练误差：2.02, 校验误差：2.49, 准确率：0.30
# transfer_pretrained网络：第0试验，比例2, 第13周期，第(0/938)个撮，训练误差：2.75, 校验误差：2.38, 准确率：0.31
# transfer_pretrained网络：第0试验，比例2, 第14周期，第(0/938)个撮，训练误差：3.16, 校验误差：2.18, 准确率：0.33
# transfer_pretrained网络：第0试验，比例2, 第15周期，第(0/938)个撮，训练误差：2.10, 校验误差：2.16, 准确率：0.32
# transfer_pretrained网络：第0试验，比例2, 第16周期，第(0/938)个撮，训练误差：2.39, 校验误差：2.10, 准确率：0.33
# transfer_pretrained网络：第0试验，比例2, 第17周期，第(0/938)个撮，训练误差：2.03, 校验误差：2.12, 准确率：0.36
# transfer_pretrained网络：第0试验，比例2, 第18周期，第(0/938)个撮，训练误差：3.21, 校验误差：2.11, 准确率：0.36
# transfer_pretrained网络：第0试验，比例2, 第19周期，第(0/938)个撮，训练误差：1.83, 校验误差：2.18, 准确率：0.35
# transfer_pretrained 0 2
# transfer_pretrained网络：第0试验，比例1, 第0周期，第(0/938)个撮，训练误差：114.82, 校验误差：101.94, 准确率：0.01
# transfer_pretrained网络：第0试验，比例1, 第0周期，第(500/938)个撮，训练误差：10.59, 校验误差：5.52, 准确率：0.17
# transfer_pretrained网络：第0试验，比例1, 第1周期，第(0/938)个撮，训练误差：5.73, 校验误差：4.81, 准确率：0.17
# transfer_pretrained网络：第0试验，比例1, 第1周期，第(500/938)个撮，训练误差：4.30, 校验误差：3.78, 准确率：0.21
# transfer_pretrained网络：第0试验，比例1, 第2周期，第(0/938)个撮，训练误差：2.61, 校验误差：3.50, 准确率：0.24
# transfer_pretrained网络：第0试验，比例1, 第2周期，第(500/938)个撮，训练误差：3.51, 校验误差：3.14, 准确率：0.26
# transfer_pretrained网络：第0试验，比例1, 第3周期，第(0/938)个撮，训练误差：4.98, 校验误差：2.96, 准确率：0.27
# transfer_pretrained网络：第0试验，比例1, 第3周期，第(500/938)个撮，训练误差：3.12, 校验误差：2.92, 准确率：0.30
# transfer_pretrained网络：第0试验，比例1, 第4周期，第(0/938)个撮，训练误差：3.14, 校验误差：2.88, 准确率：0.29
# transfer_pretrained网络：第0试验，比例1, 第4周期，第(500/938)个撮，训练误差：2.79, 校验误差：2.51, 准确率：0.30
# transfer_pretrained网络：第0试验，比例1, 第5周期，第(0/938)个撮，训练误差：2.74, 校验误差：2.53, 准确率：0.29
# transfer_pretrained网络：第0试验，比例1, 第5周期，第(500/938)个撮，训练误差：2.63, 校验误差：2.43, 准确率：0.29
# transfer_pretrained网络：第0试验，比例1, 第6周期，第(0/938)个撮，训练误差：2.78, 校验误差：2.26, 准确率：0.32
# transfer_pretrained网络：第0试验，比例1, 第6周期，第(500/938)个撮，训练误差：2.50, 校验误差：2.30, 准确率：0.32
# transfer_pretrained网络：第0试验，比例1, 第7周期，第(0/938)个撮，训练误差：2.99, 校验误差：2.32, 准确率：0.30
# transfer_pretrained网络：第0试验，比例1, 第7周期，第(500/938)个撮，训练误差：2.33, 校验误差：2.19, 准确率：0.32
# transfer_pretrained网络：第0试验，比例1, 第8周期，第(0/938)个撮，训练误差：1.66, 校验误差：2.12, 准确率：0.35
# transfer_pretrained网络：第0试验，比例1, 第8周期，第(500/938)个撮，训练误差：2.27, 校验误差：2.15, 准确率：0.34
# transfer_pretrained网络：第0试验，比例1, 第9周期，第(0/938)个撮，训练误差：1.93, 校验误差：2.05, 准确率：0.34
# transfer_pretrained网络：第0试验，比例1, 第9周期，第(500/938)个撮，训练误差：2.15, 校验误差：2.09, 准确率：0.33
# transfer_pretrained网络：第0试验，比例1, 第10周期，第(0/938)个撮，训练误差：1.85, 校验误差：2.03, 准确率：0.36
# transfer_pretrained网络：第0试验，比例1, 第10周期，第(500/938)个撮，训练误差：2.10, 校验误差：2.19, 准确率：0.34
# transfer_pretrained网络：第0试验，比例1, 第11周期，第(0/938)个撮，训练误差：2.11, 校验误差：1.99, 准确率：0.37
# transfer_pretrained网络：第0试验，比例1, 第11周期，第(500/938)个撮，训练误差：1.99, 校验误差：1.92, 准确率：0.37
# transfer_pretrained网络：第0试验，比例1, 第12周期，第(0/938)个撮，训练误差：2.98, 校验误差：1.81, 准确率：0.38
# transfer_pretrained网络：第0试验，比例1, 第12周期，第(500/938)个撮，训练误差：1.93, 校验误差：1.81, 准确率：0.38
# transfer_pretrained网络：第0试验，比例1, 第13周期，第(0/938)个撮，训练误差：2.38, 校验误差：1.82, 准确率：0.37
# transfer_pretrained网络：第0试验，比例1, 第13周期，第(500/938)个撮，训练误差：1.88, 校验误差：1.77, 准确率：0.39
# transfer_pretrained网络：第0试验，比例1, 第14周期，第(0/938)个撮，训练误差：2.62, 校验误差：1.72, 准确率：0.39
# transfer_pretrained网络：第0试验，比例1, 第14周期，第(500/938)个撮，训练误差：1.81, 校验误差：1.77, 准确率：0.39
# transfer_pretrained网络：第0试验，比例1, 第15周期，第(0/938)个撮，训练误差：1.56, 校验误差：1.72, 准确率：0.38
# transfer_pretrained网络：第0试验，比例1, 第15周期，第(500/938)个撮，训练误差：1.77, 校验误差：1.67, 准确率：0.40
# transfer_pretrained网络：第0试验，比例1, 第16周期，第(0/938)个撮，训练误差：1.97, 校验误差：1.76, 准确率：0.41
# transfer_pretrained网络：第0试验，比例1, 第16周期，第(500/938)个撮，训练误差：1.71, 校验误差：1.66, 准确率：0.41
# transfer_pretrained网络：第0试验，比例1, 第17周期，第(0/938)个撮，训练误差：1.65, 校验误差：1.61, 准确率：0.41
# transfer_pretrained网络：第0试验，比例1, 第17周期，第(500/938)个撮，训练误差：1.67, 校验误差：1.61, 准确率：0.41
# transfer_pretrained网络：第0试验，比例1, 第18周期，第(0/938)个撮，训练误差：1.54, 校验误差：1.57, 准确率：0.42
# transfer_pretrained网络：第0试验，比例1, 第18周期，第(500/938)个撮，训练误差：1.60, 校验误差：1.55, 准确率：0.43
# transfer_pretrained网络：第0试验，比例1, 第19周期，第(0/938)个撮，训练误差：2.26, 校验误差：1.54, 准确率：0.42
# transfer_pretrained网络：第0试验，比例1, 第19周期，第(500/938)个撮，训练误差：1.58, 校验误差：1.58, 准确率：0.43
# transfer_pretrained 0 1

# %%
print(len(results))
# Out:
# 27

# %%
# 处理实验数据
# 首先对于同一组参数下的数据求多次试验的平均值

one_curve = {}
tests = {}
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    for fraction in fractions:
        one_experiment = []
        test_value = []
        for time in range(times):
            rr = results[(experiment, time, fraction)]
            one_experiment.append([ii[2] for ii in rr[0]])
            test_value.append(rr[1])
        aa = np.array(one_experiment)
        # 将test_value的值装到cpu中 --hq 20200727
        test_value = [l.cpu().numpy() for l in test_value]
        one_curve[(experiment, fraction)] = np.mean(aa, 0)
        tests[(experiment, fraction)] = np.mean(test_value)

# %%
# 然后再绘制它们的误差曲线
for fraction in fractions:
    plt.figure(figsize = (10, 7))
    plt.title('{:.2f} % of the data'.format(100.0 / fraction))
    plt.plot(1 - one_curve[('no transfer', fraction)], label = 'no transfer')
    plt.plot(1 - one_curve[('transfer_pretrained', fraction)], label = 'transfer pretrained')
    plt.plot(1 - one_curve[('transfer_fixed', fraction)] , label = 'transfer fixed')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Error')

# %%
# 绘制测试准确度随着fraction变化的曲线
plt.figure(figsize = (10, 7))
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    testss = []
    for fraction in fractions:
        test = 1 - tests[(experiment, fraction)]
        testss.append(test)
    plt.plot(fractions, testss, 'o-', label = experiment)
plt.legend()
plt.xlabel('Fractions')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码
