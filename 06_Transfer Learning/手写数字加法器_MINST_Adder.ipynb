# %% [markdown]
# # 迁移学习——手写数字加法机
#
# 本文件是集智AI学园开发的“火炬上的深度学习”系列课程第四节课：《神经网络移情别恋——迁移学习》的配套文档。在本文档中，我们
# 实现了一个手写数字加法机，它可以通过识别输入的两个手写体图像文件，从而计算两个数字的和，并给出输出。我们展示了三种不同
# 的迁移学习方式，并对它们进行了系统化的比较：
#
# 1、没有迁移学习，网络完全从头学习如何识别数字，如何计算加法；
#
# 2、将已训练好的手写数字识别器网络迁移过来，作为预训练权重；
#
# 3、将已训练好的手写数字识别器网络迁移过来，并作为不可修改的权重。
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline

# %% [markdown]
# ## 一、加载数据
#
# 首先一个问题是如何加载成对的图像数据？我们采用的解决方案是采用了两套采样器和加载器，
# 这样每一组采样器＋加载器都独立地从原始的数据集中抽样数据，这就让我们可以获得大量不重复
# 的手写数字图像对，从而可以训练我们的神经网络。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 设置图像读取器的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #批处理的尺寸大小

# 如果系统中存在着GPU，我们将用GPU来完成张量的计算
use_cuda = torch.cuda.is_available() #定义一个布尔型变量，标志当前的GPU是否可用

# 如果当前GPU可用，则将优先在GPU上进行张量计算
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
itype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

# 加载测试数据集
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())


# 定义两个采样器，每一个采样器都随机地从原始的数据集中抽样数据。抽样数据采用permutation
# 生成任意一个下标重排，从而利用下标来提取dataset中的数据
sample_size = len(train_dataset)
sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))

# 定义两个加载器，分别封装了前两个采样器，实现采样。
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler2
                                           )

# 对于校验数据和测试数据，我们进行类似的处理。
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# 为了比较不同数据量对迁移学习的影响，我们设定了一个加载数据的比例fraction
# 即我们只加载原训练数据集的1/fraction来训练网络
fraction = 1

# %% [markdown]
# ## 二、加载网络
#
# 为了实现迁移学习，我们需要从硬盘上加载已经训练好的手写数字识别器卷积神经网络，加载网络需要经过两个步骤：
#
# 1、定义网络模块（nn.Module）的框架，即新定义类ConvNet，实现其forwar函数；
#
# 2、从硬盘文件加载网络
#
# 3、通过绘制其卷积核，验证加载到的网络和导出的网络一致

# %% [markdown]
# ### 1. 定义网络架构
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 定义待迁移的网络框架，所有的神经网络模块包括：Conv2d、MaxPool2d，Linear等模块都不需要重新定义，会自动加载
# 但是网络的forward功能没有办法自动实现，需要重写。
# 一般的，加载网络只加载网络的属性，不加载方法
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        x = F.relu(self.fc1(x)) #全链接，激活函数
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x, dim =1) #log_softmax可以理解为概率对数值
        return x

# %% [markdown]
# ### 2. 从硬盘文件加载网络
#
# 网络加载命令如下：

# %%
original_net = torch.load('minst_conv_checkpoint') #读取硬盘上的minst_conv_checkpoint文件

# %%
original_net #将网络打印出来观看（只能看到其神经模块和架构）
# Out:
# ConvNet(
#   (conv1): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=392, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3. 检测加载的正确性
#
# 通过测试它在测试数据集上的分类准确度，以及绘制其卷积核，并与导出的程序（minist_convnet.ipynb）中的分类准确度、卷积核等是否相同判断本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素

#在测试集上分批运行，并计算总的正确率
original_net.eval() #标志模型当前为运行阶段
test_loss = 0
correct = 0
vals = []

#对测试数据集进行循环
for data, target in test_loader1:
#     data, target = data.clone().detach().requires_grad_(False), target.clone().detach()
    with torch.no_grad():
        data = data.clone().detach()
    target = target.clone().detach()
    
    output = original_net(data) #将特征数据喂入网络，得到分类的输出
    val = rightness(output, target) #获得正确样本数以及总样本数
    vals.append(val) #记录结果

#计算准确率
rights = (sum([tup[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 1.0 * rights[0].numpy() / rights[1]
right_rate
# Out:
# 0.9918

# %%
#随便从测试集中读入一张图片，并绘制出来
idx = 4
muteimg = test_dataset[idx][0].numpy()
plt.imshow(muteimg[0,...])
print('标签是：',test_dataset[idx][1])
# Out:
# 标签是： tensor(4)

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(original_net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(original_net.conv2.weight.data.numpy()[j, i,...])

# %% [markdown]
# ## 三、数字加法机的实现
#
# 数字加法机：输入两张图像，输出这两个手写数字的加法。网络的架构如下：
#
# 两个并行的卷积模块：两个卷积层、两个Pooling层；一个全链接模块：最多四层全链接层。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
depth = [4, 8]
class Transfer(nn.Module):
    def __init__(self):
        super(Transfer, self).__init__()
        # 两个并行的卷积通道，第一个通道：
        self.net1_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net_pool = nn.MaxPool2d(2, 2) #2*2 池化
        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 第二个通道，注意pooling操作不需要重复定义
        self.net2_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 全链接层
        self.fc1 = nn.Linear(2 * image_size // 4 * image_size // 4 * depth[1] , 1024) #输入为处理后的特征图压平，输出1024个单元
        self.fc2 = nn.Linear(1024, 2 * num_classes) #输入1024个单元，输出20个单元
        self.fc3 = nn.Linear(2 * num_classes, num_classes) #输入20个单元，输出10个单元
        self.fc4 = nn.Linear(num_classes, 1) #输入10个单元，输出为1

    def forward(self, x, y, training = True):
        # 网络的前馈过程。输入两张手写图像x和y，输出一个数字表示两个数字的和
        # x,y都是batch_size*image_size*image_size形状的三阶张量
        # 输出为batch_size长的列向量
        
        # 首先，第一张图像进入第一个通道
        x = F.relu(self.net1_conv1(x)) #第一层卷积
        x = self.net_pool(x)   # 第一层池化
        x = F.relu(self.net1_conv2(x))  # 第二层卷积
        x = self.net_pool(x) # 第二层池化
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1]) # 将特征图张量压平
        
        
        y = F.relu(self.net2_conv1(y)) #第一层卷积
        y = self.net_pool(y) # 第一层池化
        y = F.relu(self.net2_conv2(y)) #第二层卷积
        y = self.net_pool(y) #第二层池化
        y = y.view(-1, image_size // 4 * image_size // 4 * depth[1])# 将特征图张量压平
        
        # 将两个卷积过来的铺平向量拼接在一起，形成一个大向量
        z = torch.cat((x, y), 1) #cat函数为拼接向量操作，1表示拼接的维度为第1个维度（0维度对应了batch）
        z = self.fc1(z) #第一层全链接
        z = F.relu(z)  #对于深层网络来说，激活函数用relu效果会比较好
        z = F.dropout(z, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        z = self.fc2(z) #第二层全链接
        z = F.relu(z)
        z = self.fc3(z) #第三层全链接
        z = F.relu(z)
        z = self.fc4(z) # 第四层全链接
        return z
    def set_filter_values(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为预训练式
        # 输入参数net为从硬盘加载的网络作为迁移源
        
        # 逐个儿为网络的两个卷积模块的权重和偏置进行赋值
        # 注意在赋值的时候需要用deepcopy而不能直接等于，或者copy。
        # 这是因为这种拷贝是将张量中的数值全部拷贝到了目标中，而不是拷贝地址
        # 如果不用deepcopy，由于我们将同一组参数（net.conv1.weight.data,bias）
        #  赋予了两组参数（net1_conv1.weight.data，net2_conv1.weight.data）
        # 所以它们会共享源net.conv1.weight.data中的地址，这样对于net1_conv1.weight.data
        # 的训练也自然会被用到了net2_conv1.weight.data中，但其实我们希望它们是两个不同的参数。
        self.net1_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net1_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net1_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net1_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        self.net2_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net2_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net2_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net2_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        
        # 将变量加载到GPU上        
        self.net1_conv1 = self.net1_conv1.cuda() if use_cuda else self.net1_conv1
        self.net1_conv2 = self.net1_conv2.cuda() if use_cuda else self.net1_conv2
        
        self.net2_conv1 = self.net2_conv1.cuda() if use_cuda else self.net2_conv1
        self.net2_conv2 = self.net2_conv2.cuda() if use_cuda else self.net2_conv2
    def set_filter_values_nograd(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为固定权重式
        # 调用set_filter_values为全部卷积核进行赋值
        self.set_filter_values(net)
        
        # 为了让我们的网络不被训练调整权值，我们需要设定每一个变量的requires_grad为False
        # 即不需要计算梯度值
        self.net1_conv1.weight.requires_grad = False
        self.net1_conv1.bias.requires_grad = False
        self.net1_conv2.weight.requires_grad = False
        self.net1_conv2.bias.requires_grad = False
        
        
        self.net2_conv1.weight.requires_grad = False
        self.net2_conv1.bias.requires_grad = False
        self.net2_conv2.weight.requires_grad = False
        self.net2_conv2.bias.requires_grad = False
def rightness(y, target):
    # 计算分类准确度的函数，y为模型预测的标签，target为数据的标签
    # 输入的y为一个矩阵，行对应了batch中的不同数据记录，列对应了不同的分类选择，数值对应了概率
    # 函数输出分别为预测与数据标签相等的个数，本次判断的所有数据个数
    out = torch.round(y.squeeze()).type(itype)
    out = out.eq(target).sum()
    out1 = y.size()[0]
    return(out, out1)

# %% [markdown]
# ## 四、数据迁移实验

# %% [markdown]
# ### 1. 无迁移实验
#
# 在本试验中，我们不迁移网络，直接训练整个网络

# %%
# 生成网络实例
net = Transfer()

# 如果存在GPU，则将网络加载到GPU中
if use_cuda:
    net = net.cuda()
    
# 定义损失函数，我们用最小均方误差来定义损失
criterion = nn.MSELoss()

# 定义优化器
optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
results = {}

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    
    # 我们可以用zip命令来同时从两个数据加载器中加载数据，enumerate则给这个迭代附加上了计数
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        # 为了比较数据量大小对迁移学习的影响，我们只加载了部分数据，当数据加载个数idx大于
        # 全数据集的1/fraction的时候则不再加载后面的数据
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        optimizer.zero_grad()
        net.train()
        outputs = net(x1.clone().detach(), x2.clone().detach())
        labels = y1 + y2
        loss = criterion(outputs, labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            # 在校验数据上计算计算准确率
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach(), x2.clone().detach())
                labels = y1 + y2
                
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])

# 在测试数据集上测试准确度
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach(), x2.clone().detach())
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['notransfer'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：103.05038452148438, 校验误差：99.30, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：58.25237274169922, 校验误差：16.88, 准确率：0.11
# 第0周期，第(200/938)个撮，训练误差：37.722721099853516, 校验误差：16.96, 准确率：0.10
# 第0周期，第(300/938)个撮，训练误差：30.91132354736328, 校验误差：16.62, 准确率：0.10
# 第0周期，第(400/938)个撮，训练误差：27.49819564819336, 校验误差：17.20, 准确率：0.10
# 第0周期，第(500/938)个撮，训练误差：25.325162887573242, 校验误差：16.82, 准确率：0.08
# 第0周期，第(600/938)个撮，训练误差：24.017854690551758, 校验误差：16.97, 准确率：0.08
# 第0周期，第(700/938)个撮，训练误差：22.98237419128418, 校验误差：17.04, 准确率：0.11
# 第0周期，第(800/938)个撮，训练误差：22.26513671875, 校验误差：16.99, 准确率：0.09
# 第0周期，第(900/938)个撮，训练误差：21.676315307617188, 校验误差：16.73, 准确率：0.10
# 第1周期，第(0/938)个撮，训练误差：16.455543518066406, 校验误差：17.04, 准确率：0.10
# 第1周期，第(100/938)个撮，训练误差：16.850719451904297, 校验误差：16.59, 准确率：0.11
# 第1周期，第(200/938)个撮，训练误差：17.067829132080078, 校验误差：16.65, 准确率：0.10
# 第1周期，第(300/938)个撮，训练误差：17.08477020263672, 校验误差：17.51, 准确率：0.09
# 第1周期，第(400/938)个撮，训练误差：16.92317008972168, 校验误差：16.81, 准确率：0.10
# 第1周期，第(500/938)个撮，训练误差：16.949115753173828, 校验误差：17.20, 准确率：0.09
# 第1周期，第(600/938)个撮，训练误差：16.933815002441406, 校验误差：16.96, 准确率：0.10
# 第1周期，第(700/938)个撮，训练误差：16.988140106201172, 校验误差：17.03, 准确率：0.10
# 第1周期，第(800/938)个撮，训练误差：16.967105865478516, 校验误差：16.44, 准确率：0.10
# 第1周期，第(900/938)个撮，训练误差：16.98237419128418, 校验误差：16.79, 准确率：0.10
# 第2周期，第(0/938)个撮，训练误差：18.48330307006836, 校验误差：16.84, 准确率：0.10
# 第2周期，第(100/938)个撮，训练误差：17.06607437133789, 校验误差：16.85, 准确率：0.09
# 第2周期，第(200/938)个撮，训练误差：16.947193145751953, 校验误差：16.43, 准确率：0.09
# 第2周期，第(300/938)个撮，训练误差：16.928239822387695, 校验误差：17.06, 准确率：0.09
# 第2周期，第(400/938)个撮，训练误差：16.86910629272461, 校验误差：16.76, 准确率：0.10
# 第2周期，第(500/938)个撮，训练误差：16.896547317504883, 校验误差：16.46, 准确率：0.11
# 第2周期，第(600/938)个撮，训练误差：16.893123626708984, 校验误差：16.72, 准确率：0.10
# 第2周期，第(700/938)个撮，训练误差：16.87839126586914, 校验误差：16.50, 准确率：0.10
# 第2周期，第(800/938)个撮，训练误差：16.905397415161133, 校验误差：17.12, 准确率：0.09
# 第2周期，第(900/938)个撮，训练误差：16.83722686767578, 校验误差：16.28, 准确率：0.10
# 第3周期，第(0/938)个撮，训练误差：18.974843978881836, 校验误差：16.72, 准确率：0.10
# 第3周期，第(100/938)个撮，训练误差：16.555269241333008, 校验误差：17.16, 准确率：0.09
# 第3周期，第(200/938)个撮，训练误差：16.82145881652832, 校验误差：16.84, 准确率：0.10
# 第3周期，第(300/938)个撮，训练误差：16.774709701538086, 校验误差：16.63, 准确率：0.10
# 第3周期，第(400/938)个撮，训练误差：16.803054809570312, 校验误差：16.76, 准确率：0.10
# 第3周期，第(500/938)个撮，训练误差：16.856502532958984, 校验误差：16.66, 准确率：0.10
# 第3周期，第(600/938)个撮，训练误差：16.886430740356445, 校验误差：16.54, 准确率：0.10
# 第3周期，第(700/938)个撮，训练误差：16.851512908935547, 校验误差：16.67, 准确率：0.10
# 第3周期，第(800/938)个撮，训练误差：16.814125061035156, 校验误差：16.69, 准确率：0.10
# 第3周期，第(900/938)个撮，训练误差：16.847169876098633, 校验误差：17.39, 准确率：0.10
# 第4周期，第(0/938)个撮，训练误差：13.977843284606934, 校验误差：16.69, 准确率：0.11
# 第4周期，第(100/938)个撮，训练误差：17.2388973236084, 校验误差：16.98, 准确率：0.10
# 第4周期，第(200/938)个撮，训练误差：17.1306095123291, 校验误差：16.82, 准确率：0.10
# 第4周期，第(300/938)个撮，训练误差：17.054975509643555, 校验误差：16.57, 准确率：0.10
# 第4周期，第(400/938)个撮，训练误差：16.963144302368164, 校验误差：16.51, 准确率：0.10
# 第4周期，第(500/938)个撮，训练误差：16.944923400878906, 校验误差：16.36, 准确率：0.09
# 第4周期，第(600/938)个撮，训练误差：16.90181541442871, 校验误差：16.28, 准确率：0.10
# 第4周期，第(700/938)个撮，训练误差：16.95009422302246, 校验误差：16.77, 准确率：0.09
# 第4周期，第(800/938)个撮，训练误差：16.936004638671875, 校验误差：17.16, 准确率：0.10
# 第4周期，第(900/938)个撮，训练误差：16.90300750732422, 校验误差：16.71, 准确率：0.09
# 第5周期，第(0/938)个撮，训练误差：18.191205978393555, 校验误差：17.40, 准确率：0.10
# 第5周期，第(100/938)个撮，训练误差：16.8667049407959, 校验误差：16.53, 准确率：0.11
# 第5周期，第(200/938)个撮，训练误差：16.872133255004883, 校验误差：16.40, 准确率：0.10
# 第5周期，第(300/938)个撮，训练误差：16.87809181213379, 校验误差：16.35, 准确率：0.10
# 第5周期，第(400/938)个撮，训练误差：16.88511848449707, 校验误差：16.60, 准确率：0.10
# 第5周期，第(500/938)个撮，训练误差：16.882984161376953, 校验误差：17.49, 准确率：0.09
# 第5周期，第(600/938)个撮，训练误差：16.823776245117188, 校验误差：16.67, 准确率：0.10
# 第5周期，第(700/938)个撮，训练误差：16.823989868164062, 校验误差：16.79, 准确率：0.09
# 第5周期，第(800/938)个撮，训练误差：16.866273880004883, 校验误差：16.94, 准确率：0.09
# 第5周期，第(900/938)个撮，训练误差：16.824365615844727, 校验误差：16.43, 准确率：0.11
# 第6周期，第(0/938)个撮，训练误差：15.518470764160156, 校验误差：16.50, 准确率：0.11
# 第6周期，第(100/938)个撮，训练误差：16.804306030273438, 校验误差：16.91, 准确率：0.10
# 第6周期，第(200/938)个撮，训练误差：16.924182891845703, 校验误差：16.55, 准确率：0.10
# 第6周期，第(300/938)个撮，训练误差：16.78765106201172, 校验误差：17.17, 准确率：0.10
# 第6周期，第(400/938)个撮，训练误差：16.860553741455078, 校验误差：16.36, 准确率：0.10
# 第6周期，第(500/938)个撮，训练误差：16.833454132080078, 校验误差：17.12, 准确率：0.10
# 第6周期，第(600/938)个撮，训练误差：16.817888259887695, 校验误差：16.37, 准确率：0.10
# 第6周期，第(700/938)个撮，训练误差：16.889245986938477, 校验误差：16.43, 准确率：0.10
# 第6周期，第(800/938)个撮，训练误差：16.85953140258789, 校验误差：16.69, 准确率：0.11
# 第6周期，第(900/938)个撮，训练误差：16.87249755859375, 校验误差：16.93, 准确率：0.11
# 第7周期，第(0/938)个撮，训练误差：15.441970825195312, 校验误差：16.48, 准确率：0.10
# 第7周期，第(100/938)个撮，训练误差：17.049306869506836, 校验误差：16.93, 准确率：0.10
# 第7周期，第(200/938)个撮，训练误差：16.87387466430664, 校验误差：16.66, 准确率：0.10
# 第7周期，第(300/938)个撮，训练误差：16.849193572998047, 校验误差：16.91, 准确率：0.10
# 第7周期，第(400/938)个撮，训练误差：16.950532913208008, 校验误差：16.54, 准确率：0.10
# 第7周期，第(500/938)个撮，训练误差：16.93583869934082, 校验误差：16.67, 准确率：0.10
# 第7周期，第(600/938)个撮，训练误差：16.89573097229004, 校验误差：16.98, 准确率：0.09
# 第7周期，第(700/938)个撮，训练误差：16.873462677001953, 校验误差：16.08, 准确率：0.11
# 第7周期，第(800/938)个撮，训练误差：16.804189682006836, 校验误差：16.81, 准确率：0.11
# 第7周期，第(900/938)个撮，训练误差：16.8128604888916, 校验误差：17.03, 准确率：0.10
# 第8周期，第(0/938)个撮，训练误差：15.889814376831055, 校验误差：16.40, 准确率：0.10
# 第8周期，第(100/938)个撮，训练误差：16.739521026611328, 校验误差：16.63, 准确率：0.10
# 第8周期，第(200/938)个撮，训练误差：16.503496170043945, 校验误差：16.71, 准确率：0.11
# 第8周期，第(300/938)个撮，训练误差：16.601606369018555, 校验误差：16.25, 准确率：0.10
# 第8周期，第(400/938)个撮，训练误差：16.682064056396484, 校验误差：16.30, 准确率：0.10
# 第8周期，第(500/938)个撮，训练误差：16.63377571105957, 校验误差：16.52, 准确率：0.10
# 第8周期，第(600/938)个撮，训练误差：16.668603897094727, 校验误差：16.98, 准确率：0.10
# 第8周期，第(700/938)个撮，训练误差：16.649051666259766, 校验误差：16.91, 准确率：0.10
# 第8周期，第(800/938)个撮，训练误差：16.70201873779297, 校验误差：16.61, 准确率：0.10
# 第8周期，第(900/938)个撮，训练误差：16.68729019165039, 校验误差：16.91, 准确率：0.10
# 第9周期，第(0/938)个撮，训练误差：13.80998706817627, 校验误差：16.95, 准确率：0.10
# 第9周期，第(100/938)个撮，训练误差：16.768646240234375, 校验误差：16.91, 准确率：0.09
# 第9周期，第(200/938)个撮，训练误差：16.82383155822754, 校验误差：16.48, 准确率：0.09
# 第9周期，第(300/938)个撮，训练误差：16.75858497619629, 校验误差：16.63, 准确率：0.09
# 第9周期，第(400/938)个撮，训练误差：16.746416091918945, 校验误差：16.44, 准确率：0.10
# 第9周期，第(500/938)个撮，训练误差：16.761432647705078, 校验误差：16.19, 准确率：0.10
# 第9周期，第(600/938)个撮，训练误差：16.739187240600586, 校验误差：16.74, 准确率：0.10
# 第9周期，第(700/938)个撮，训练误差：16.75490951538086, 校验误差：16.89, 准确率：0.10
# 第9周期，第(800/938)个撮，训练误差：16.832441329956055, 校验误差：16.77, 准确率：0.09
# 第9周期，第(900/938)个撮，训练误差：16.821138381958008, 校验误差：16.81, 准确率：0.09
# 第10周期，第(0/938)个撮，训练误差：14.826025009155273, 校验误差：16.66, 准确率：0.09
# 第10周期，第(100/938)个撮，训练误差：17.16164207458496, 校验误差：16.49, 准确率：0.10
# 第10周期，第(200/938)个撮，训练误差：16.797330856323242, 校验误差：16.97, 准确率：0.10
# 第10周期，第(300/938)个撮，训练误差：16.85702896118164, 校验误差：16.68, 准确率：0.10
# 第10周期，第(400/938)个撮，训练误差：16.832080841064453, 校验误差：16.39, 准确率：0.10
# 第10周期，第(500/938)个撮，训练误差：16.878551483154297, 校验误差：16.68, 准确率：0.10
# 第10周期，第(600/938)个撮，训练误差：16.87030792236328, 校验误差：16.70, 准确率：0.09
# 第10周期，第(700/938)个撮，训练误差：16.885311126708984, 校验误差：16.49, 准确率：0.10
# 第10周期，第(800/938)个撮，训练误差：16.868026733398438, 校验误差：16.45, 准确率：0.10
# 第10周期，第(900/938)个撮，训练误差：16.82377052307129, 校验误差：16.36, 准确率：0.10
# 第11周期，第(0/938)个撮，训练误差：12.179335594177246, 校验误差：16.64, 准确率：0.10
# 第11周期，第(100/938)个撮，训练误差：16.547876358032227, 校验误差：16.21, 准确率：0.10
# 第11周期，第(200/938)个撮，训练误差：16.7271671295166, 校验误差：16.57, 准确率：0.10
# 第11周期，第(300/938)个撮，训练误差：16.500926971435547, 校验误差：16.86, 准确率：0.10
# 第11周期，第(400/938)个撮，训练误差：16.607702255249023, 校验误差：16.86, 准确率：0.11
# 第11周期，第(500/938)个撮，训练误差：16.56186866760254, 校验误差：16.61, 准确率：0.10
# 第11周期，第(600/938)个撮，训练误差：16.537471771240234, 校验误差：16.82, 准确率：0.10
# 第11周期，第(700/938)个撮，训练误差：16.552087783813477, 校验误差：16.76, 准确率：0.10
# 第11周期，第(800/938)个撮，训练误差：16.592918395996094, 校验误差：16.97, 准确率：0.10
# 第11周期，第(900/938)个撮，训练误差：16.623676300048828, 校验误差：16.58, 准确率：0.11
# 第12周期，第(0/938)个撮，训练误差：16.859922409057617, 校验误差：16.80, 准确率：0.10
# 第12周期，第(100/938)个撮，训练误差：17.31744384765625, 校验误差：16.63, 准确率：0.10
# 第12周期，第(200/938)个撮，训练误差：17.09336280822754, 校验误差：17.10, 准确率：0.10
# 第12周期，第(300/938)个撮，训练误差：16.96270179748535, 校验误差：16.67, 准确率：0.10
# 第12周期，第(400/938)个撮，训练误差：16.86217498779297, 校验误差：16.53, 准确率：0.10
# 第12周期，第(500/938)个撮，训练误差：16.79653549194336, 校验误差：17.07, 准确率：0.10
# 第12周期，第(600/938)个撮，训练误差：16.800676345825195, 校验误差：16.58, 准确率：0.10
# 第12周期，第(700/938)个撮，训练误差：16.760173797607422, 校验误差：16.74, 准确率：0.09
# 第12周期，第(800/938)个撮，训练误差：16.772632598876953, 校验误差：16.68, 准确率：0.10
# 第12周期，第(900/938)个撮，训练误差：16.792749404907227, 校验误差：16.66, 准确率：0.11
# 第13周期，第(0/938)个撮，训练误差：15.532033920288086, 校验误差：17.14, 准确率：0.10
# 第13周期，第(100/938)个撮，训练误差：17.261018753051758, 校验误差：16.96, 准确率：0.09
# 第13周期，第(200/938)个撮，训练误差：16.843547821044922, 校验误差：16.71, 准确率：0.10
# 第13周期，第(300/938)个撮，训练误差：16.88800621032715, 校验误差：16.83, 准确率：0.10
# 第13周期，第(400/938)个撮，训练误差：16.966201782226562, 校验误差：16.43, 准确率：0.10
# 第13周期，第(500/938)个撮，训练误差：16.95395851135254, 校验误差：16.69, 准确率：0.10
# 第13周期，第(600/938)个撮，训练误差：16.926944732666016, 校验误差：16.61, 准确率：0.10
# 第13周期，第(700/938)个撮，训练误差：16.850252151489258, 校验误差：16.67, 准确率：0.09
# 第13周期，第(800/938)个撮，训练误差：16.844221115112305, 校验误差：16.84, 准确率：0.10
# 第13周期，第(900/938)个撮，训练误差：16.863277435302734, 校验误差：16.49, 准确率：0.11
# 第14周期，第(0/938)个撮，训练误差：16.24714469909668, 校验误差：16.79, 准确率：0.10
# 第14周期，第(100/938)个撮，训练误差：17.114328384399414, 校验误差：16.39, 准确率：0.10
# 第14周期，第(200/938)个撮，训练误差：17.092002868652344, 校验误差：16.84, 准确率：0.09
# 第14周期，第(300/938)个撮，训练误差：17.067279815673828, 校验误差：16.55, 准确率：0.10
# 第14周期，第(400/938)个撮，训练误差：17.08356285095215, 校验误差：17.07, 准确率：0.10
# 第14周期，第(500/938)个撮，训练误差：17.045021057128906, 校验误差：16.77, 准确率：0.10
# 第14周期，第(600/938)个撮，训练误差：16.969219207763672, 校验误差：16.56, 准确率：0.10
# 第14周期，第(700/938)个撮，训练误差：17.002552032470703, 校验误差：16.68, 准确率：0.10
# 第14周期，第(800/938)个撮，训练误差：16.980878829956055, 校验误差：16.71, 准确率：0.10
# 第14周期，第(900/938)个撮，训练误差：16.983110427856445, 校验误差：16.44, 准确率：0.10
# 第15周期，第(0/938)个撮，训练误差：16.812236785888672, 校验误差：16.76, 准确率：0.10
# 第15周期，第(100/938)个撮，训练误差：16.471298217773438, 校验误差：16.79, 准确率：0.10
# 第15周期，第(200/938)个撮，训练误差：16.634233474731445, 校验误差：16.82, 准确率：0.10
# 第15周期，第(300/938)个撮，训练误差：16.798572540283203, 校验误差：16.95, 准确率：0.10
# 第15周期，第(400/938)个撮，训练误差：16.772092819213867, 校验误差：16.46, 准确率：0.09
# 第15周期，第(500/938)个撮，训练误差：16.773117065429688, 校验误差：16.19, 准确率：0.10
# 第15周期，第(600/938)个撮，训练误差：16.680496215820312, 校验误差：17.14, 准确率：0.11
# 第15周期，第(700/938)个撮，训练误差：16.727733612060547, 校验误差：16.76, 准确率：0.10
# 第15周期，第(800/938)个撮，训练误差：16.71784210205078, 校验误差：16.62, 准确率：0.10
# 第15周期，第(900/938)个撮，训练误差：16.741802215576172, 校验误差：16.39, 准确率：0.10
# 第16周期，第(0/938)个撮，训练误差：21.498416900634766, 校验误差：16.44, 准确率：0.10
# 第16周期，第(100/938)个撮，训练误差：17.106674194335938, 校验误差：16.76, 准确率：0.10
# 第16周期，第(200/938)个撮，训练误差：17.03339385986328, 校验误差：16.85, 准确率：0.10
# 第16周期，第(300/938)个撮，训练误差：16.836017608642578, 校验误差：16.43, 准确率：0.10
# 第16周期，第(400/938)个撮，训练误差：16.83992576599121, 校验误差：16.39, 准确率：0.10
# 第16周期，第(500/938)个撮，训练误差：16.842226028442383, 校验误差：16.52, 准确率：0.10
# 第16周期，第(600/938)个撮，训练误差：16.84827995300293, 校验误差：16.53, 准确率：0.10
# 第16周期，第(700/938)个撮，训练误差：16.844051361083984, 校验误差：16.97, 准确率：0.10
# 第16周期，第(800/938)个撮，训练误差：16.815242767333984, 校验误差：16.31, 准确率：0.11
# 第16周期，第(900/938)个撮，训练误差：16.84149742126465, 校验误差：16.80, 准确率：0.10
# 第17周期，第(0/938)个撮，训练误差：16.645099639892578, 校验误差：17.01, 准确率：0.10
# 第17周期，第(100/938)个撮，训练误差：16.41191291809082, 校验误差：16.91, 准确率：0.11
# 第17周期，第(200/938)个撮，训练误差：16.515520095825195, 校验误差：16.57, 准确率：0.10
# 第17周期，第(300/938)个撮，训练误差：16.677350997924805, 校验误差：16.30, 准确率：0.11
# 第17周期，第(400/938)个撮，训练误差：16.728540420532227, 校验误差：16.39, 准确率：0.10
# 第17周期，第(500/938)个撮，训练误差：16.820526123046875, 校验误差：16.33, 准确率：0.10
# 第17周期，第(600/938)个撮，训练误差：16.82354736328125, 校验误差：16.69, 准确率：0.10
# 第17周期，第(700/938)个撮，训练误差：16.844593048095703, 校验误差：16.88, 准确率：0.10
# 第17周期，第(800/938)个撮，训练误差：16.854740142822266, 校验误差：16.52, 准确率：0.10
# 第17周期，第(900/938)个撮，训练误差：16.881322860717773, 校验误差：16.32, 准确率：0.11
# 第18周期，第(0/938)个撮，训练误差：15.827004432678223, 校验误差：16.69, 准确率：0.10
# 第18周期，第(100/938)个撮，训练误差：16.7268123626709, 校验误差：16.93, 准确率：0.10
# 第18周期，第(200/938)个撮，训练误差：16.7138671875, 校验误差：17.05, 准确率：0.09
# 第18周期，第(300/938)个撮，训练误差：16.670011520385742, 校验误差：16.58, 准确率：0.10
# 第18周期，第(400/938)个撮，训练误差：16.626705169677734, 校验误差：16.26, 准确率：0.10
# 第18周期，第(500/938)个撮，训练误差：16.666418075561523, 校验误差：16.52, 准确率：0.10
# 第18周期，第(600/938)个撮，训练误差：16.666372299194336, 校验误差：16.95, 准确率：0.10
# 第18周期，第(700/938)个撮，训练误差：16.6871337890625, 校验误差：16.33, 准确率：0.10
# 第18周期，第(800/938)个撮，训练误差：16.666385650634766, 校验误差：16.73, 准确率：0.10
# 第18周期，第(900/938)个撮，训练误差：16.654916763305664, 校验误差：17.06, 准确率：0.10
# 第19周期，第(0/938)个撮，训练误差：20.79199981689453, 校验误差：16.13, 准确率：0.11
# 第19周期，第(100/938)个撮，训练误差：16.795528411865234, 校验误差：16.58, 准确率：0.10
# 第19周期，第(200/938)个撮，训练误差：17.042373657226562, 校验误差：16.46, 准确率：0.10
# 第19周期，第(300/938)个撮，训练误差：16.921314239501953, 校验误差：17.34, 准确率：0.10
# 第19周期，第(400/938)个撮，训练误差：16.847089767456055, 校验误差：15.99, 准确率：0.10
# 第19周期，第(500/938)个撮，训练误差：16.784822463989258, 校验误差：16.90, 准确率：0.10
# 第19周期，第(600/938)个撮，训练误差：16.790332794189453, 校验误差：16.91, 准确率：0.10
# 第19周期，第(700/938)个撮，训练误差：16.75165557861328, 校验误差：16.34, 准确率：0.10
# 第19周期，第(800/938)个撮，训练误差：16.769027709960938, 校验误差：16.90, 准确率：0.10
# 第19周期，第(900/938)个撮，训练误差：16.79368019104004, 校验误差：16.59, 准确率：0.11

# %%
# 绘制实验结果，打印测试集上的准确度
plt.plot([i[0] for i in records])
plt.plot([i[1] for i in records])
plt.plot([100 * (1 - i[2]) for i in records])
right_ratio
# Out:
# 0.1092

# %% [markdown]
# ### 2. 迁移网络，预训练
#
# 在本试验中，我们将手写数字识别的卷积神经网络权重迁移过来，作为新的加法机网络的预训练值（也就是初始值）

# %%
net = Transfer()

# 为新网络赋予权重数值，注意我们只将卷积部分的网络进行迁移，而没有迁移全链接层
net.set_filter_values(original_net)

if use_cuda:
    net = net.cuda()

criterion = nn.MSELoss()

# 将需要训练的参数加载到优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad: #我们只将可以调整权重的变量加到了集合new_parameters
        new_parameters.append(para)
        
# 将new_parameters加载到了优化器中
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        labels = y1 + y2
        loss = criterion(outputs,labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_pretrained'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：14.37, 校验误差：16.52, 准确率：0.10
# 第0周期，第(100/938)个撮，训练误差：16.52, 校验误差：17.13, 准确率：0.10
# 第0周期，第(200/938)个撮，训练误差：16.75, 校验误差：16.79, 准确率：0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d5f90bb613e4> in <module>
#       4 for epoch in range(num_epochs):
#       5     losses = []
# ----> 6     for idx, data in enumerate(zip(train_loader1, train_loader2)):
#       7         if idx >= (len(train_loader1) // fraction):
#       8             break
#
# ~/anaconda3/envs/maggie-torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/maggie-torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/envs/maggie-torch/lib/python3.6/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      75
#      76         if self.transform is not None:
# ---> 77             img = self.transform(img)
#      78
#      79         if self.target_transform is not None:
#
# ~/anaconda3/envs/maggie-torch/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      74             Tensor: Converted image.
#      75         """
# ---> 76         return F.to_tensor(pic)
#      77
#      78     def __repr__(self):
#
# ~/anaconda3/envs/maggie-torch/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      81     img = img.transpose(0, 1).transpose(0, 2).contiguous()
#      82     if isinstance(img, torch.ByteTensor):
# ---> 83         return img.float().div(255)
#      84     else:
#      85         return img
#
# KeyboardInterrupt:

# %%
plt.plot([1 - i[2] for i in records])
right_ratio

# %% [markdown]
# ### 3.迁移，不更新权重
#
# 在这个试验中，我们首先将识别器的卷积层的权重全部迁移到了加法机的两个卷积部件中，但保持它们的权重不变，只允许后面的全链接层的权重可训练。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
net = Transfer()
# 迁移网络，并设置卷积部件的权重和偏置都不计算梯度
net.set_filter_values_nograd(original_net)
if use_cuda:
    net = net.cuda()
criterion = nn.MSELoss()

# 只将可更新的权重值加载到了优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad:
        new_parameters.append(para)
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 训练整个网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        labels = y1 + y2
        labels = labels.type(dtype)
        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_fixed'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：107.63, 校验误差：96.17, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：32.11, 校验误差：19.15, 准确率：0.09
# 第0周期，第(200/938)个撮，训练误差：25.16, 校验误差：17.86, 准确率：0.09
# 第0周期，第(300/938)个撮，训练误差：22.77, 校验误差：17.48, 准确率：0.09
# 第0周期，第(400/938)个撮，训练误差：21.60, 校验误差：17.66, 准确率：0.09
# 第0周期，第(500/938)个撮，训练误差：20.75, 校验误差：17.37, 准确率：0.10
# 第0周期，第(600/938)个撮，训练误差：20.22, 校验误差：17.32, 准确率：0.10
# 第0周期，第(700/938)个撮，训练误差：19.83, 校验误差：17.47, 准确率：0.10
# 第0周期，第(800/938)个撮，训练误差：19.57, 校验误差：18.77, 准确率：0.08
# 第0周期，第(900/938)个撮，训练误差：19.32, 校验误差：16.91, 准确率：0.10
# 第1周期，第(0/938)个撮，训练误差：18.19, 校验误差：19.48, 准确率：0.08
# 第1周期，第(100/938)个撮，训练误差：17.66, 校验误差：17.14, 准确率：0.10
# 第1周期，第(200/938)个撮，训练误差：17.85, 校验误差：17.41, 准确率：0.10
# 第1周期，第(300/938)个撮，训练误差：17.67, 校验误差：17.61, 准确率：0.09
# 第1周期，第(400/938)个撮，训练误差：17.65, 校验误差：17.39, 准确率：0.09
# 第1周期，第(500/938)个撮，训练误差：17.62, 校验误差：18.15, 准确率：0.09
# 第1周期，第(600/938)个撮，训练误差：17.67, 校验误差：16.92, 准确率：0.10
# 第1周期，第(700/938)个撮，训练误差：17.60, 校验误差：17.36, 准确率：0.09
# 第1周期，第(800/938)个撮，训练误差：17.63, 校验误差：17.76, 准确率：0.08
# 第1周期，第(900/938)个撮，训练误差：17.63, 校验误差：17.37, 准确率：0.10
# 第2周期，第(0/938)个撮，训练误差：16.83, 校验误差：16.67, 准确率：0.10
# 第2周期，第(100/938)个撮，训练误差：17.48, 校验误差：17.97, 准确率：0.09
# 第2周期，第(200/938)个撮，训练误差：17.83, 校验误差：17.67, 准确率：0.09
# 第2周期，第(300/938)个撮，训练误差：17.69, 校验误差：16.73, 准确率：0.10
# 第2周期，第(400/938)个撮，训练误差：17.72, 校验误差：16.99, 准确率：0.10
# 第2周期，第(500/938)个撮，训练误差：17.70, 校验误差：16.46, 准确率：0.10
# 第2周期，第(600/938)个撮，训练误差：17.67, 校验误差：17.25, 准确率：0.10
# 第2周期，第(700/938)个撮，训练误差：17.66, 校验误差：17.67, 准确率：0.09
# 第2周期，第(800/938)个撮，训练误差：17.66, 校验误差：17.61, 准确率：0.09
# 第2周期，第(900/938)个撮，训练误差：17.67, 校验误差：17.30, 准确率：0.09
# 第3周期，第(0/938)个撮，训练误差：18.99, 校验误差：17.69, 准确率：0.09
# 第3周期，第(100/938)个撮，训练误差：17.46, 校验误差：17.40, 准确率：0.09
# 第3周期，第(200/938)个撮，训练误差：17.30, 校验误差：17.33, 准确率：0.09
# 第3周期，第(300/938)个撮，训练误差：17.48, 校验误差：17.35, 准确率：0.10
# 第3周期，第(400/938)个撮，训练误差：17.44, 校验误差：16.89, 准确率：0.10
# 第3周期，第(500/938)个撮，训练误差：17.37, 校验误差：17.30, 准确率：0.09
# 第3周期，第(600/938)个撮，训练误差：17.41, 校验误差：17.62, 准确率：0.10
# 第3周期，第(700/938)个撮，训练误差：17.43, 校验误差：17.00, 准确率：0.10
# 第3周期，第(800/938)个撮，训练误差：17.41, 校验误差：17.97, 准确率：0.08
# 第3周期，第(900/938)个撮，训练误差：17.43, 校验误差：17.19, 准确率：0.10
# 第4周期，第(0/938)个撮，训练误差：16.81, 校验误差：17.38, 准确率：0.09
# 第4周期，第(100/938)个撮，训练误差：17.20, 校验误差：18.05, 准确率：0.08
# 第4周期，第(200/938)个撮，训练误差：17.41, 校验误差：17.07, 准确率：0.10
# 第4周期，第(300/938)个撮，训练误差：17.24, 校验误差：18.01, 准确率：0.09
# 第4周期，第(400/938)个撮，训练误差：17.30, 校验误差：17.59, 准确率：0.09
# 第4周期，第(500/938)个撮，训练误差：17.30, 校验误差：16.90, 准确率：0.10
# 第4周期，第(600/938)个撮，训练误差：17.39, 校验误差：16.88, 准确率：0.10
# 第4周期，第(700/938)个撮，训练误差：17.37, 校验误差：16.81, 准确率：0.11
# 第4周期，第(800/938)个撮，训练误差：17.36, 校验误差：16.97, 准确率：0.10
# 第4周期，第(900/938)个撮，训练误差：17.29, 校验误差：17.06, 准确率：0.09
# 第5周期，第(0/938)个撮，训练误差：15.59, 校验误差：17.04, 准确率：0.10
# 第5周期，第(100/938)个撮，训练误差：17.06, 校验误差：17.38, 准确率：0.10
# 第5周期，第(200/938)个撮，训练误差：17.40, 校验误差：17.19, 准确率：0.10
# 第5周期，第(300/938)个撮，训练误差：17.29, 校验误差：17.25, 准确率：0.09
# 第5周期，第(400/938)个撮，训练误差：17.32, 校验误差：17.31, 准确率：0.09
# 第5周期，第(500/938)个撮，训练误差：17.29, 校验误差：16.88, 准确率：0.10
# 第5周期，第(600/938)个撮，训练误差：17.32, 校验误差：17.49, 准确率：0.09
# 第5周期，第(700/938)个撮，训练误差：17.29, 校验误差：17.04, 准确率：0.10
# 第5周期，第(800/938)个撮，训练误差：17.30, 校验误差：17.01, 准确率：0.11
# 第5周期，第(900/938)个撮，训练误差：17.30, 校验误差：17.11, 准确率：0.10
# 第6周期，第(0/938)个撮，训练误差：15.85, 校验误差：17.22, 准确率：0.10
# 第6周期，第(100/938)个撮，训练误差：16.97, 校验误差：16.82, 准确率：0.09
# 第6周期，第(200/938)个撮，训练误差：17.06, 校验误差：17.05, 准确率：0.10
# 第6周期，第(300/938)个撮，训练误差：17.19, 校验误差：18.07, 准确率：0.09
# 第6周期，第(400/938)个撮，训练误差：17.20, 校验误差：17.64, 准确率：0.08
# 第6周期，第(500/938)个撮，训练误差：17.24, 校验误差：16.84, 准确率：0.10
# 第6周期，第(600/938)个撮，训练误差：17.24, 校验误差：17.05, 准确率：0.10
# 第6周期，第(700/938)个撮，训练误差：17.22, 校验误差：16.89, 准确率：0.10
# 第6周期，第(800/938)个撮，训练误差：17.20, 校验误差：16.71, 准确率：0.11
# 第6周期，第(900/938)个撮，训练误差：17.20, 校验误差：17.33, 准确率：0.10
# 第7周期，第(0/938)个撮，训练误差：14.77, 校验误差：16.76, 准确率：0.09
# 第7周期，第(100/938)个撮，训练误差：17.31, 校验误差：17.22, 准确率：0.09
# 第7周期，第(200/938)个撮，训练误差：17.17, 校验误差：16.79, 准确率：0.11
# 第7周期，第(300/938)个撮，训练误差：17.20, 校验误差：16.90, 准确率：0.10
# 第7周期，第(400/938)个撮，训练误差：17.25, 校验误差：17.95, 准确率：0.09
# 第7周期，第(500/938)个撮，训练误差：17.20, 校验误差：17.18, 准确率：0.10
# 第7周期，第(600/938)个撮，训练误差：17.13, 校验误差：16.94, 准确率：0.10
# 第7周期，第(700/938)个撮，训练误差：17.16, 校验误差：17.50, 准确率：0.10
# 第7周期，第(800/938)个撮，训练误差：17.13, 校验误差：16.94, 准确率：0.09
# 第7周期，第(900/938)个撮，训练误差：17.19, 校验误差：16.38, 准确率：0.10
# 第8周期，第(0/938)个撮，训练误差：19.83, 校验误差：17.16, 准确率：0.10
# 第8周期，第(100/938)个撮，训练误差：17.61, 校验误差：17.35, 准确率：0.08
# 第8周期，第(200/938)个撮，训练误差：17.52, 校验误差：16.88, 准确率：0.10
# 第8周期，第(300/938)个撮，训练误差：17.41, 校验误差：16.79, 准确率：0.10
# 第8周期，第(400/938)个撮，训练误差：17.32, 校验误差：17.31, 准确率：0.10
# 第8周期，第(500/938)个撮，训练误差：17.33, 校验误差：17.05, 准确率：0.10
# 第8周期，第(600/938)个撮，训练误差：17.29, 校验误差：18.20, 准确率：0.09
# 第8周期，第(700/938)个撮，训练误差：17.30, 校验误差：18.19, 准确率：0.09
# 第8周期，第(800/938)个撮，训练误差：17.28, 校验误差：16.90, 准确率：0.10
# 第8周期，第(900/938)个撮，训练误差：17.26, 校验误差：16.76, 准确率：0.10
# 第9周期，第(0/938)个撮，训练误差：19.19, 校验误差：17.39, 准确率：0.09
# 第9周期，第(100/938)个撮，训练误差：17.28, 校验误差：17.09, 准确率：0.10
# 第9周期，第(200/938)个撮，训练误差：16.94, 校验误差：17.13, 准确率：0.09
# 第9周期，第(300/938)个撮，训练误差：16.87, 校验误差：16.91, 准确率：0.10
# 第9周期，第(400/938)个撮，训练误差：17.01, 校验误差：16.50, 准确率：0.10
# 第9周期，第(500/938)个撮，训练误差：17.09, 校验误差：16.55, 准确率：0.10
# 第9周期，第(600/938)个撮，训练误差：17.15, 校验误差：16.90, 准确率：0.10
# 第9周期，第(700/938)个撮，训练误差：17.15, 校验误差：16.95, 准确率：0.10
# 第9周期，第(800/938)个撮，训练误差：17.12, 校验误差：16.88, 准确率：0.10
# 第9周期，第(900/938)个撮，训练误差：17.12, 校验误差：16.54, 准确率：0.10
# 第10周期，第(0/938)个撮，训练误差：21.32, 校验误差：17.31, 准确率：0.10
# 第10周期，第(100/938)个撮，训练误差：17.05, 校验误差：16.79, 准确率：0.11
# 第10周期，第(200/938)个撮，训练误差：17.02, 校验误差：17.59, 准确率：0.10
# 第10周期，第(300/938)个撮，训练误差：17.06, 校验误差：17.58, 准确率：0.09
# 第10周期，第(400/938)个撮，训练误差：17.15, 校验误差：17.26, 准确率：0.10
# 第10周期，第(500/938)个撮，训练误差：17.12, 校验误差：16.71, 准确率：0.11
# 第10周期，第(600/938)个撮，训练误差：17.07, 校验误差：17.26, 准确率：0.10
# 第10周期，第(700/938)个撮，训练误差：17.06, 校验误差：16.85, 准确率：0.10
# 第10周期，第(800/938)个撮，训练误差：17.04, 校验误差：16.94, 准确率：0.10
# 第10周期，第(900/938)个撮，训练误差：17.05, 校验误差：17.57, 准确率：0.09
# 第11周期，第(0/938)个撮，训练误差：19.86, 校验误差：17.09, 准确率：0.10
# 第11周期，第(100/938)个撮，训练误差：17.19, 校验误差：16.57, 准确率：0.10
# 第11周期，第(200/938)个撮，训练误差：17.06, 校验误差：16.58, 准确率：0.10
# 第11周期，第(300/938)个撮，训练误差：17.07, 校验误差：17.27, 准确率：0.10
# 第11周期，第(400/938)个撮，训练误差：17.13, 校验误差：16.50, 准确率：0.10
# 第11周期，第(500/938)个撮，训练误差：17.06, 校验误差：16.91, 准确率：0.10
# 第11周期，第(600/938)个撮，训练误差：17.03, 校验误差：16.82, 准确率：0.09
# 第11周期，第(700/938)个撮，训练误差：17.00, 校验误差：16.95, 准确率：0.09
# 第11周期，第(800/938)个撮，训练误差：17.02, 校验误差：16.65, 准确率：0.10
# 第11周期，第(900/938)个撮，训练误差：17.01, 校验误差：17.33, 准确率：0.09
# 第12周期，第(0/938)个撮，训练误差：13.14, 校验误差：17.07, 准确率：0.10
# 第12周期，第(100/938)个撮，训练误差：16.77, 校验误差：16.64, 准确率：0.10
# 第12周期，第(200/938)个撮，训练误差：16.92, 校验误差：16.85, 准确率：0.10
# 第12周期，第(300/938)个撮，训练误差：16.82, 校验误差：16.96, 准确率：0.10
# 第12周期，第(400/938)个撮，训练误差：16.93, 校验误差：16.89, 准确率：0.09
# 第12周期，第(500/938)个撮，训练误差：16.95, 校验误差：17.09, 准确率：0.09
# 第12周期，第(600/938)个撮，训练误差：16.98, 校验误差：16.83, 准确率：0.10
# 第12周期，第(700/938)个撮，训练误差：16.93, 校验误差：16.71, 准确率：0.10
# 第12周期，第(800/938)个撮，训练误差：16.97, 校验误差：16.77, 准确率：0.10
# 第12周期，第(900/938)个撮，训练误差：16.97, 校验误差：16.97, 准确率：0.10
# 第13周期，第(0/938)个撮，训练误差：13.44, 校验误差：16.66, 准确率：0.09
# 第13周期，第(100/938)个撮，训练误差：17.19, 校验误差：16.83, 准确率：0.10
# 第13周期，第(200/938)个撮，训练误差：17.30, 校验误差：16.89, 准确率：0.10
# 第13周期，第(300/938)个撮，训练误差：17.27, 校验误差：16.52, 准确率：0.11
# 第13周期，第(400/938)个撮，训练误差：17.10, 校验误差：16.83, 准确率：0.10
# 第13周期，第(500/938)个撮，训练误差：17.10, 校验误差：16.39, 准确率：0.10
# 第13周期，第(600/938)个撮，训练误差：17.08, 校验误差：16.91, 准确率：0.10
# 第13周期，第(700/938)个撮，训练误差：17.05, 校验误差：16.58, 准确率：0.10
# 第13周期，第(800/938)个撮，训练误差：17.04, 校验误差：16.84, 准确率：0.09
# 第13周期，第(900/938)个撮，训练误差：16.99, 校验误差：16.94, 准确率：0.10
# 第14周期，第(0/938)个撮，训练误差：18.38, 校验误差：17.24, 准确率：0.09
# 第14周期，第(100/938)个撮，训练误差：17.28, 校验误差：17.60, 准确率：0.09
# 第14周期，第(200/938)个撮，训练误差：17.15, 校验误差：17.01, 准确率：0.11
# 第14周期，第(300/938)个撮，训练误差：17.07, 校验误差：17.15, 准确率：0.10
# 第14周期，第(400/938)个撮，训练误差：17.08, 校验误差：16.92, 准确率：0.09
# 第14周期，第(500/938)个撮，训练误差：17.08, 校验误差：16.57, 准确率：0.10
# 第14周期，第(600/938)个撮，训练误差：17.09, 校验误差：16.85, 准确率：0.10
# 第14周期，第(700/938)个撮，训练误差：17.01, 校验误差：17.22, 准确率：0.10
# 第14周期，第(800/938)个撮，训练误差：16.98, 校验误差：16.81, 准确率：0.10
# 第14周期，第(900/938)个撮，训练误差：16.94, 校验误差：16.93, 准确率：0.10
# 第15周期，第(0/938)个撮，训练误差：15.98, 校验误差：16.99, 准确率：0.09
# 第15周期，第(100/938)个撮，训练误差：16.93, 校验误差：16.20, 准确率：0.11
# 第15周期，第(200/938)个撮，训练误差：16.99, 校验误差：16.67, 准确率：0.10
# 第15周期，第(300/938)个撮，训练误差：16.95, 校验误差：17.26, 准确率：0.08
# 第15周期，第(400/938)个撮，训练误差：17.01, 校验误差：17.50, 准确率：0.09
# 第15周期，第(500/938)个撮，训练误差：16.94, 校验误差：16.90, 准确率：0.11
# 第15周期，第(600/938)个撮，训练误差：16.93, 校验误差：17.16, 准确率：0.10
# 第15周期，第(700/938)个撮，训练误差：16.85, 校验误差：16.88, 准确率：0.09
# 第15周期，第(800/938)个撮，训练误差：16.81, 校验误差：17.11, 准确率：0.10
# 第15周期，第(900/938)个撮，训练误差：16.84, 校验误差：17.02, 准确率：0.10
# 第16周期，第(0/938)个撮，训练误差：15.50, 校验误差：16.81, 准确率：0.10
# 第16周期，第(100/938)个撮，训练误差：16.70, 校验误差：16.62, 准确率：0.10
# 第16周期，第(200/938)个撮，训练误差：16.74, 校验误差：16.47, 准确率：0.11
# 第16周期，第(300/938)个撮，训练误差：16.85, 校验误差：16.56, 准确率：0.10
# 第16周期，第(400/938)个撮，训练误差：16.91, 校验误差：16.83, 准确率：0.10
# 第16周期，第(500/938)个撮，训练误差：16.85, 校验误差：16.19, 准确率：0.11
# 第16周期，第(600/938)个撮，训练误差：16.88, 校验误差：16.60, 准确率：0.10
# 第16周期，第(700/938)个撮，训练误差：16.90, 校验误差：16.68, 准确率：0.10
# 第16周期，第(800/938)个撮，训练误差：16.85, 校验误差：16.64, 准确率：0.09
# 第16周期，第(900/938)个撮，训练误差：16.82, 校验误差：17.12, 准确率：0.10
# 第17周期，第(0/938)个撮，训练误差：14.59, 校验误差：17.11, 准确率：0.10
# 第17周期，第(100/938)个撮，训练误差：16.70, 校验误差：16.49, 准确率：0.10
# 第17周期，第(200/938)个撮，训练误差：16.65, 校验误差：16.26, 准确率：0.11
# 第17周期，第(300/938)个撮，训练误差：16.70, 校验误差：16.72, 准确率：0.10
# 第17周期，第(400/938)个撮，训练误差：16.77, 校验误差：16.78, 准确率：0.10
# 第17周期，第(500/938)个撮，训练误差：16.71, 校验误差：17.30, 准确率：0.10
# 第17周期，第(600/938)个撮，训练误差：16.69, 校验误差：16.79, 准确率：0.10
# 第17周期，第(700/938)个撮，训练误差：16.69, 校验误差：16.61, 准确率：0.09
# 第17周期，第(800/938)个撮，训练误差：16.74, 校验误差：16.98, 准确率：0.09
# 第17周期，第(900/938)个撮，训练误差：16.74, 校验误差：16.60, 准确率：0.10
# 第18周期，第(0/938)个撮，训练误差：17.46, 校验误差：16.87, 准确率：0.10
# 第18周期，第(100/938)个撮，训练误差：16.73, 校验误差：16.77, 准确率：0.10
# 第18周期，第(200/938)个撮，训练误差：16.88, 校验误差：16.57, 准确率：0.10
# 第18周期，第(300/938)个撮，训练误差：16.79, 校验误差：16.86, 准确率：0.10
# 第18周期，第(400/938)个撮，训练误差：16.84, 校验误差：16.51, 准确率：0.11
# 第18周期，第(500/938)个撮，训练误差：16.85, 校验误差：16.81, 准确率：0.10
# 第18周期，第(600/938)个撮，训练误差：16.90, 校验误差：17.19, 准确率：0.09
# 第18周期，第(700/938)个撮，训练误差：16.85, 校验误差：16.80, 准确率：0.10
# 第18周期，第(800/938)个撮，训练误差：16.82, 校验误差：16.53, 准确率：0.11
# 第18周期，第(900/938)个撮，训练误差：16.75, 校验误差：16.91, 准确率：0.09
# 第19周期，第(0/938)个撮，训练误差：17.78, 校验误差：16.74, 准确率：0.10
# 第19周期，第(100/938)个撮，训练误差：16.37, 校验误差：16.47, 准确率：0.10
# 第19周期，第(200/938)个撮，训练误差：16.39, 校验误差：16.95, 准确率：0.10
# 第19周期，第(300/938)个撮，训练误差：16.50, 校验误差：16.82, 准确率：0.10
# 第19周期，第(400/938)个撮，训练误差：16.63, 校验误差：17.20, 准确率：0.09
# 第19周期，第(500/938)个撮，训练误差：16.71, 校验误差：17.04, 准确率：0.10
# 第19周期，第(600/938)个撮，训练误差：16.80, 校验误差：16.10, 准确率：0.10
# 第19周期，第(700/938)个撮，训练误差：16.79, 校验误差：16.78, 准确率：0.10
# 第19周期，第(800/938)个撮，训练误差：16.84, 校验误差：16.64, 准确率：0.10
# 第19周期，第(900/938)个撮，训练误差：16.81, 校验误差：16.49, 准确率：0.10

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# 0.0964

# %% [markdown]
# ### 4、结果比较
# 将三次实验的结果放到一起比较

# %%
y1, y2, y3 = results['notransfer'][0], results['transfer_pretrained'][0], results['transfer_fixed'][0]

# %%
plt.figure(figsize = (10, 7))
plt.plot([1 - i[2] for i in y1], 'o-', label = 'no transfer')
plt.plot([1 - i[2] for i in y2], 's:', label = 'transfer pretrained')
plt.plot([1 - i[2] for i in y3], '*-', label = 'transfer fixed')
plt.xlabel('Time')
plt.ylabel('Error Rate')
plt.legend()

# %%
results['notransfer'][1], results['transfer_pretrained'][1], results['transfer_fixed'][1]
# Out:
# (0.1092, 0.1038, 0.0964)

# %%
experiments = {}
experiments[1] = results

# %%
experiments
# Out:
# {1: {'notransfer': [[[103.050385, 99.295456, 0.0066],
#     [58.252373, 16.880579, 0.1062],
#     [37.72272, 16.962456, 0.1012],
#     [30.911324, 16.61742, 0.0972],
#     [27.498196, 17.20053, 0.103],
#     [25.325163, 16.816895, 0.0772],
#     [24.017855, 16.974735, 0.0772],
#     [22.982374, 17.036127, 0.1056],
#     [22.265137, 16.989168, 0.0928],
#     [21.676315, 16.734169, 0.1004],
#     [16.455544, 17.039072, 0.1022],
#     [16.85072, 16.594624, 0.1068],
#     [17.06783, 16.647789, 0.0996],
#     [17.08477, 17.514627, 0.0908],
#     [16.92317, 16.80835, 0.098],
#     [16.949116, 17.20403, 0.0856],
#     [16.933815, 16.961155, 0.0954],
#     [16.98814, 17.027548, 0.0954],
#     [16.967106, 16.436249, 0.1006],
#     [16.982374, 16.79469, 0.102],
#     [18.483303, 16.840239, 0.1032],
#     [17.066074, 16.852255, 0.0894],
#     [16.947193, 16.432554, 0.0948],
#     [16.92824, 17.059097, 0.0858],
#     [16.869106, 16.75514, 0.0956],
#     [16.896547, 16.459738, 0.1088],
#     [16.893124, 16.722805, 0.1012],
#     [16.878391, 16.502129, 0.1036],
#     [16.905397, 17.118217, 0.0872],
#     [16.837227, 16.275387, 0.1],
#     [18.974844, 16.720327, 0.0988],
#     [16.55527, 17.163548, 0.0942],
#     [16.821459, 16.836132, 0.096],
#     [16.77471, 16.630878, 0.0998],
#     [16.803055, 16.763485, 0.0976],
#     [16.856503, 16.655518, 0.0968],
#     [16.88643, 16.539814, 0.096],
#     [16.851513, 16.665573, 0.1026],
#     [16.814125, 16.69224, 0.0974],
#     [16.84717, 17.392437, 0.0962],
#     [13.977843, 16.691607, 0.1086],
#     [17.238897, 16.977716, 0.1],
#     [17.13061, 16.82279, 0.1032],
#     [17.054976, 16.574184, 0.0982],
#     [16.963144, 16.508577, 0.1022],
#     [16.944923, 16.363733, 0.0944],
#     [16.901815, 16.28428, 0.104],
#     [16.950094, 16.76703, 0.0948],
#     [16.936005, 17.16273, 0.0992],
#     [16.903008, 16.706068, 0.091],
#     [18.191206, 17.396301, 0.0976],
#     [16.866705, 16.531872, 0.107],
#     [16.872133, 16.399109, 0.1036],
#     [16.878092, 16.345747, 0.102],
#     [16.885118, 16.602919, 0.0984],
#     [16.882984, 17.486822, 0.0872],
#     [16.823776, 16.665125, 0.1016],
#     [16.82399, 16.794088, 0.094],
#     [16.866274, 16.94447, 0.0932],
#     [16.824366, 16.4282, 0.1062],
#     [15.518471, 16.500874, 0.111],
#     [16.804306, 16.90986, 0.1006],
#     [16.924183, 16.554928, 0.0984],
#     [16.787651, 17.168474, 0.1012],
#     [16.860554, 16.363949, 0.1048],
#     [16.833454, 17.11702, 0.0988],
#     [16.817888, 16.371681, 0.1028],
#     [16.889246, 16.425835, 0.0964],
#     [16.859531, 16.693848, 0.1062],
#     [16.872498, 16.93291, 0.1126],
#     [15.441971, 16.47657, 0.1018],
#     [17.049307, 16.926592, 0.0998],
#     [16.873875, 16.658245, 0.0968],
#     [16.849194, 16.909948, 0.1022],
#     [16.950533, 16.54362, 0.0972],
#     [16.935839, 16.671062, 0.0996],
#     [16.895731, 16.984314, 0.0918],
#     [16.873463, 16.080986, 0.1058],
#     [16.80419, 16.808691, 0.1052],
#     [16.81286, 17.03178, 0.0976],
#     [15.889814, 16.399967, 0.0976],
#     [16.739521, 16.632147, 0.1028],
#     [16.503496, 16.707052, 0.1056],
#     [16.601606, 16.249525, 0.1018],
#     [16.682064, 16.297981, 0.0996],
#     [16.633776, 16.520908, 0.1032],
#     [16.668604, 16.976358, 0.096],
#     [16.649052, 16.91161, 0.0998],
#     [16.702019, 16.612505, 0.0974],
#     [16.68729, 16.91372, 0.102],
#     [13.809987, 16.945194, 0.0972],
#     [16.768646, 16.913479, 0.0938],
#     [16.823832, 16.484371, 0.0946],
#     [16.758585, 16.62793, 0.0938],
#     [16.746416, 16.438135, 0.1004],
#     [16.761433, 16.190262, 0.1034],
#     [16.739187, 16.738113, 0.095],
#     [16.75491, 16.89135, 0.095],
#     [16.832441, 16.769913, 0.0944],
#     [16.821138, 16.805079, 0.094],
#     [14.826025, 16.657999, 0.0948],
#     [17.161642, 16.488329, 0.0962],
#     [16.79733, 16.973705, 0.0976],
#     [16.857029, 16.675909, 0.0986],
#     [16.83208, 16.394522, 0.1024],
#     [16.878551, 16.678406, 0.1026],
#     [16.870308, 16.69657, 0.093],
#     [16.885311, 16.48645, 0.098],
#     [16.868027, 16.45019, 0.098],
#     [16.82377, 16.3596, 0.0974],
#     [12.179336, 16.635843, 0.0986],
#     [16.547876, 16.20987, 0.0972],
#     [16.727167, 16.573309, 0.0954],
#     [16.500927, 16.858572, 0.1026],
#     [16.607702, 16.863504, 0.1072],
#     [16.561869, 16.6106, 0.101],
#     [16.537472, 16.81632, 0.099],
#     [16.552088, 16.764055, 0.1008],
#     [16.592918, 16.965546, 0.0988],
#     [16.623676, 16.581367, 0.1078],
#     [16.859922, 16.802738, 0.0952],
#     [17.317444, 16.631947, 0.099],
#     [17.093363, 17.101088, 0.1002],
#     [16.962702, 16.672285, 0.1028],
#     [16.862175, 16.534466, 0.101],
#     [16.796535, 17.067488, 0.0956],
#     [16.800676, 16.577305, 0.101],
#     [16.760174, 16.74203, 0.0924],
#     [16.772633, 16.681301, 0.0966],
#     [16.79275, 16.662365, 0.1054],
#     [15.532034, 17.135975, 0.0976],
#     [17.261019, 16.964233, 0.094],
#     [16.843548, 16.708977, 0.0996],
#     [16.888006, 16.834135, 0.1004],
#     [16.966202, 16.432932, 0.0964],
#     [16.953959, 16.690496, 0.0986],
#     [16.926945, 16.606047, 0.1024],
#     [16.850252, 16.667665, 0.0944],
#     [16.844221, 16.839653, 0.0984],
#     [16.863277, 16.492308, 0.107],
#     [16.247145, 16.785482, 0.0996],
#     [17.114328, 16.394817, 0.1006],
#     [17.092003, 16.84088, 0.0898],
#     [17.06728, 16.553553, 0.096],
#     [17.083563, 17.072308, 0.0958],
#     [17.045021, 16.76746, 0.0956],
#     [16.96922, 16.560059, 0.0966],
#     [17.002552, 16.675518, 0.097],
#     [16.980879, 16.70884, 0.1032],
#     [16.98311, 16.440142, 0.096],
#     [16.812237, 16.757542, 0.0988],
#     [16.471298, 16.787117, 0.1],
#     [16.634233, 16.823626, 0.0968],
#     [16.798573, 16.949133, 0.1038],
#     [16.772093, 16.46062, 0.0892],
#     [16.773117, 16.190222, 0.1002],
#     [16.680496, 17.141172, 0.1062],
#     [16.727734, 16.762222, 0.102],
#     [16.717842, 16.615839, 0.1034],
#     [16.741802, 16.394447, 0.0972],
#     [21.498417, 16.435232, 0.102],
#     [17.106674, 16.763033, 0.1046],
#     [17.033394, 16.850828, 0.1],
#     [16.836018, 16.427382, 0.102],
#     [16.839926, 16.393013, 0.1016],
#     [16.842226, 16.522177, 0.1028],
#     [16.84828, 16.5253, 0.105],
#     [16.844051, 16.96999, 0.0964],
#     [16.815243, 16.30991, 0.112],
#     [16.841497, 16.797806, 0.1038],
#     [16.6451, 17.012108, 0.0988],
#     [16.411913, 16.906729, 0.1052],
#     [16.51552, 16.571712, 0.1016],
#     [16.677351, 16.29521, 0.107],
#     [16.72854, 16.3908, 0.0988],
#     [16.820526, 16.330679, 0.0998],
#     [16.823547, 16.694918, 0.096],
#     [16.844593, 16.87602, 0.0956],
#     [16.85474, 16.522642, 0.095],
#     [16.881323, 16.324589, 0.1052],
#     [15.827004, 16.69458, 0.097],
#     [16.726812, 16.927347, 0.0952],
#     [16.713867, 17.054005, 0.0894],
#     [16.670012, 16.581882, 0.0968],
#     [16.626705, 16.263542, 0.1022],
#     [16.666418, 16.520979, 0.1026],
#     [16.666372, 16.947079, 0.1014],
#     [16.687134, 16.32554, 0.1034],
#     [16.666386, 16.725447, 0.1026],
#     [16.654917, 17.059158, 0.0956],
#     [20.792, 16.131392, 0.109],
#     [16.795528, 16.576355, 0.0958],
#     [17.042374, 16.460094, 0.1036],
#     [16.921314, 17.341866, 0.096],
#     [16.84709, 15.988884, 0.1018],
#     [16.784822, 16.895512, 0.1006],
#     [16.790333, 16.906042, 0.105],
#     [16.751656, 16.337523, 0.0992],
#     [16.769028, 16.89996, 0.0998],
#     [16.79368, 16.586138, 0.1064]],
#    0.1092],
#   'transfer_pretrained': [[[101.85663, 91.80648, 0.0116],
#     [25.41283, 17.67533, 0.095],
#     [21.879616, 17.586973, 0.0942],
#     [20.566162, 17.61537, 0.1024],
#     [19.906328, 17.508759, 0.1022],
#     [19.472216, 17.514242, 0.0896],
#     [19.181446, 17.868143, 0.0938],
#     [18.97587, 17.26028, 0.0974],
#     [18.844664, 17.763876, 0.0936],
#     [18.696054, 17.071566, 0.0954],
#     [17.568285, 18.292515, 0.0934],
#     [17.40853, 16.97865, 0.0956],
#     [17.496546, 17.48212, 0.0956],
#     [17.505756, 16.991898, 0.106],
#     [17.50312, 18.000113, 0.0928],
#     [17.486912, 16.757307, 0.0974],
#     [17.5505, 17.678585, 0.0962],
#     [17.583817, 17.119299, 0.093],
#     [17.597483, 16.978981, 0.1014],
#     [17.598097, 16.69623, 0.0998],
#     [17.786053, 17.880377, 0.0934],
#     [17.829277, 17.083948, 0.0998],
#     [17.358248, 18.15871, 0.095],
#     [17.526655, 17.09893, 0.1024],
#     [17.57047, 17.333946, 0.104],
#     [17.548018, 17.5954, 0.0872],
#     [17.466328, 16.896023, 0.0908],
#     [17.437323, 17.594254, 0.0898],
#     [17.445253, 17.354012, 0.0888],
#     [17.3948, 16.998657, 0.0964],
#     [17.003475, 16.87616, 0.1068],
#     [17.30449, 17.31462, 0.0922],
#     [17.305628, 17.031977, 0.0966],
#     [17.322332, 16.553585, 0.0944],
#     [17.252253, 17.023043, 0.0894],
#     [17.235432, 16.776367, 0.1002],
#     [17.229809, 17.512796, 0.0924],
#     [17.220526, 17.246681, 0.09],
#     [17.231678, 16.747435, 0.0978],
#     [17.228676, 16.992672, 0.098],
#     [17.902334, 16.909174, 0.097],
#     [17.622198, 17.147305, 0.1066],
#     [17.63043, 17.351227, 0.0928],
#     [17.53432, 17.162748, 0.1018],
#     [17.610914, 16.678278, 0.0998],
#     [17.551388, 17.102003, 0.096],
#     [17.547342, 16.911316, 0.1008],
#     [17.505028, 18.220951, 0.088],
#     [17.487593, 17.202175, 0.0956],
#     [17.423735, 17.139866, 0.097],
#     [20.948452, 17.14159, 0.0986],
#     [17.169468, 17.269186, 0.1008],
#     [17.163195, 17.762344, 0.0868],
#     [17.296707, 16.674532, 0.0918],
#     [17.21494, 16.612022, 0.101],
#     [17.176928, 17.430162, 0.0936],
#     [17.219837, 16.798075, 0.0982],
#     [17.197702, 16.865564, 0.0986],
#     [17.180727, 17.340702, 0.0938],
#     [17.145527, 17.099594, 0.0908],
#     [15.077368, 17.42364, 0.09],
#     [16.784914, 16.642025, 0.1004],
#     [16.963825, 16.791279, 0.099],
#     [17.135658, 17.062323, 0.097],
#     [17.140882, 18.084059, 0.0934],
#     [17.169827, 16.728605, 0.0958],
#     [17.116617, 16.820705, 0.0984],
#     [17.162342, 16.8404, 0.0982],
#     [17.127945, 17.052168, 0.089],
#     [17.157366, 16.814554, 0.0966],
#     [15.763611, 17.101921, 0.0916],
#     [17.162392, 17.00719, 0.1002],
#     [17.312365, 16.69689, 0.0994],
#     [17.330141, 16.61423, 0.1094],
#     [17.24584, 17.034586, 0.0904],
#     [17.179836, 16.99472, 0.0946],
#     [17.173506, 16.820713, 0.095],
#     [17.100077, 16.735188, 0.1018],
#     [17.097986, 17.436419, 0.0878],
#     [17.086637, 17.050167, 0.0958],
#     [18.440998, 16.912828, 0.0986],
#     [16.955597, 17.009562, 0.0958],
#     [17.045437, 16.897587, 0.0944],
#     [16.935472, 16.50473, 0.097],
#     [16.887613, 17.008965, 0.1068],
#     [16.92414, 16.7696, 0.0974],
#     [16.983917, 17.364576, 0.1056],
#     [16.991924, 16.827875, 0.093],
#     [17.025234, 17.153946, 0.104],
#     [17.003056, 16.98739, 0.0986],
#     [13.828226, 16.653307, 0.0954],
#     [17.559748, 17.305906, 0.089],
#     [17.263556, 16.442547, 0.0946],
#     [17.177713, 16.671864, 0.101],
#     [17.086273, 16.798338, 0.0974],
#     [17.176662, 16.993322, 0.0976],
#     [17.109777, 16.954023, 0.0952],
#     [17.09848, 16.611269, 0.0952],
#     [17.064932, 16.966118, 0.098],
#     [17.076778, 17.140461, 0.0928],
#     [18.731148, 17.197136, 0.0952],
#     [17.204279, 16.892103, 0.0906],
#     [17.041813, 16.71888, 0.097],
#     [17.110758, 17.105629, 0.0948],
#     [16.996666, 16.923792, 0.0966],
#     [17.00106, 17.092001, 0.0952],
#     [16.993734, 17.19665, 0.0936],
#     [17.013689, 16.951187, 0.1022],
#     [17.02867, 16.723166, 0.103],
#     [17.020462, 16.683947, 0.0962],
#     [19.222036, 16.948774, 0.0922],
#     [17.005848, 17.126707, 0.0958],
#     [16.946348, 16.389643, 0.1042],
#     [16.98326, 16.950249, 0.0932],
#     [16.852594, 17.020388, 0.1018],
#     [16.748888, 16.878693, 0.093],
#     [16.80849, 16.8273, 0.1014],
#     [16.885666, 16.861195, 0.0922],
#     [16.8758, 17.168331, 0.0948],
#     [16.906473, 16.911507, 0.0896],
#     [16.915571, 17.13956, 0.094],
#     [17.370996, 16.798315, 0.1046],
#     [17.109653, 17.407164, 0.092],
#     [16.961975, 17.405369, 0.0944],
#     [16.900555, 16.733915, 0.1056],
#     [16.834354, 16.806087, 0.097],
#     [16.796091, 16.73812, 0.0976],
#     [16.817905, 16.924711, 0.0994],
#     [16.863628, 17.195383, 0.104],
#     [16.855137, 16.579926, 0.1012],
#     [16.042545, 16.898396, 0.095],
#     [17.139631, 16.94062, 0.0924],
#     [16.891413, 16.732815, 0.1028],
#     [16.90786, 16.71055, 0.1008],
#     [16.976389, 16.756102, 0.091],
#     [16.904242, 16.740051, 0.0974],
#     [16.875202, 16.985933, 0.0962],
#     [16.822607, 17.108011, 0.0994],
#     [16.861792, 16.796017, 0.1012],
#     [16.889034, 16.785463, 0.1104],
#     [13.963254, 16.285141, 0.101],
#     [16.568089, 16.480793, 0.0924],
#     [16.892149, 17.375654, 0.096],
#     [16.95331, 17.304266, 0.0984],
#     [16.921432, 17.042772, 0.087],
#     [16.819902, 16.802473, 0.0942],
#     [16.851318, 17.31838, 0.0924],
#     [16.856384, 16.42378, 0.1056],
#     [16.887718, 17.116215, 0.0952],
#     [16.856447, 16.968094, 0.1002],
#     [15.4820595, 17.01555, 0.0946],
#     [16.751345, 16.347248, 0.1018],
#     [16.516703, 16.7401, 0.1014],
#     [16.610874, 16.726233, 0.1034],
#     [16.642374, 16.184061, 0.1022],
#     [16.77151, 17.024778, 0.1006],
#     [16.788408, 16.355877, 0.1024],
#     [16.833553, 16.872694, 0.1004],
#     [16.81823, 16.674248, 0.0946],
#     [16.783554, 17.14954, 0.0988],
#     [16.446032, 17.16237, 0.0892],
#     [16.656303, 17.058695, 0.0906],
#     [16.843067, 17.02786, 0.1038],
#     [16.83086, 16.590816, 0.0996],
#     [16.7725, 17.09956, 0.0976],
#     [16.765968, 16.78499, 0.0948],
#     [16.840685, 17.468672, 0.0928],
#     [16.857122, 16.225037, 0.0984],
#     [16.879812, 16.884151, 0.0948],
#     [16.854513, 17.139767, 0.0974],
#     [15.871262, 16.639297, 0.1026],
#     [16.289738, 16.81137, 0.0946],
#     [16.352867, 16.309343, 0.1072],
#     [16.52619, 16.929365, 0.0994],
#     [16.581514, 16.63461, 0.0996],
#     [16.643501, 16.852573, 0.1046],
#     [16.686386, 16.561672, 0.1024],
#     [16.673122, 17.212101, 0.0966],
#     [16.663212, 16.568068, 0.1002],
#     [16.66996, 16.394493, 0.1004],
#     [13.30195, 16.616604, 0.1018],
#     [17.0517, 16.685083, 0.0896],
#     [16.821428, 16.862736, 0.0952],
#     [16.741398, 16.776358, 0.0982],
#     [16.687323, 16.497759, 0.1018],
#     [16.756632, 17.574697, 0.0938],
#     [16.752178, 16.454586, 0.1016],
#     [16.73652, 16.813446, 0.0964],
#     [16.703077, 16.271824, 0.0962],
#     [16.706224, 16.918573, 0.0938],
#     [17.41864, 17.006151, 0.0938],
#     [16.800217, 16.53746, 0.1036],
#     [16.588493, 16.89023, 0.1036],
#     [16.658466, 16.642937, 0.105],
#     [16.712706, 16.725298, 0.1028],
#     [16.795073, 17.311588, 0.1012],
#     [16.843575, 16.652885, 0.1052],
#     [16.802681, 16.48562, 0.0994],
#     [16.769558, 16.451078, 0.1006],
#     [16.784914, 17.043127, 0.0934]],
#    0.1038],
#   'transfer_fixed': [[[107.62943, 96.173035, 0.0094],
#     [32.11131, 19.145412, 0.0862],
#     [25.159758, 17.864708, 0.0872],
#     [22.765612, 17.478552, 0.0938],
#     [21.597963, 17.664066, 0.0886],
#     [20.74946, 17.367567, 0.096],
#     [20.223215, 17.322153, 0.0964],
#     [19.831553, 17.471325, 0.0964],
#     [19.570227, 18.770414, 0.0814],
#     [19.31773, 16.90574, 0.102],
#     [18.18916, 19.478354, 0.0788],
#     [17.661621, 17.14168, 0.1002],
#     [17.84647, 17.412628, 0.0986],
#     [17.665493, 17.613138, 0.092],
#     [17.647558, 17.386482, 0.0878],
#     [17.623318, 18.153767, 0.0916],
#     [17.66715, 16.917927, 0.0956],
#     [17.60297, 17.361774, 0.0948],
#     [17.625221, 17.764082, 0.083],
#     [17.625267, 17.371439, 0.095],
#     [16.829664, 16.67025, 0.101],
#     [17.48048, 17.970964, 0.0906],
#     [17.831882, 17.67403, 0.0932],
#     [17.687923, 16.729635, 0.099],
#     [17.717798, 16.98737, 0.1002],
#     [17.697023, 16.459759, 0.1],
#     [17.674192, 17.249922, 0.0972],
#     [17.657879, 17.665125, 0.094],
#     [17.660059, 17.612541, 0.0858],
#     [17.670753, 17.298344, 0.0934],
#     [18.990395, 17.693798, 0.0938],
#     [17.463352, 17.40291, 0.0922],
#     [17.298525, 17.32561, 0.093],
#     [17.480766, 17.347965, 0.0988],
#     [17.438768, 16.889599, 0.0956],
#     [17.368778, 17.303453, 0.0928],
#     [17.4083, 17.615004, 0.0952],
#     [17.429617, 16.996187, 0.102],
#     [17.409971, 17.973228, 0.0818],
#     [17.430248, 17.194138, 0.1024],
#     [16.806343, 17.378986, 0.0862],
#     [17.198406, 18.052656, 0.083],
#     [17.412737, 17.069082, 0.0994],
#     [17.240498, 18.012672, 0.0932],
#     [17.299263, 17.586254, 0.0894],
#     [17.30121, 16.89716, 0.0968],
#     [17.393454, 16.880774, 0.1034],
#     [17.372028, 16.806932, 0.1114],
#     [17.356207, 16.974792, 0.097],
#     [17.285105, 17.06439, 0.09],
#     [15.585017, 17.037704, 0.1036],
#     [17.061218, 17.384468, 0.097],
#     [17.400965, 17.188347, 0.0996],
#     [17.294558, 17.245106, 0.0942],
#     [17.31598, 17.310349, 0.0948],
#     [17.29059, 16.88484, 0.099],
#     [17.320713, 17.48608, 0.0882],
#     [17.288584, 17.039024, 0.0996],
#     [17.298767, 17.0127, 0.1082],
#     [17.295584, 17.106106, 0.098],
#     [15.848687, 17.224365, 0.098],
#     [16.97161, 16.816442, 0.0944],
#     [17.059507, 17.050304, 0.098],
#     [17.191753, 18.066998, 0.0912],
#     [17.204992, 17.644297, 0.0844],
#     [17.235704, 16.838017, 0.0986],
#     [17.242971, 17.04952, 0.0952],
#     [17.216087, 16.890272, 0.101],
#     [17.196716, 16.709265, 0.11],
#     [17.198704, 17.325615, 0.0962],
#     [14.769907, 16.75556, 0.0948],
#     [17.309875, 17.219381, 0.0866],
#     [17.166813, 16.787352, 0.1084],
#     [17.2022, 16.897993, 0.0976],
#     [17.248598, 17.95081, 0.0862],
#     [17.198677, 17.18335, 0.098],
#     [17.130547, 16.938332, 0.0994],
#     [17.155663, 17.500463, 0.0992],
#     [17.134722, 16.935339, 0.0942],
#     [17.191292, 16.383598, 0.1008],
#     [19.826546, 17.160418, 0.0972],
#     [17.606258, 17.349712, 0.0832],
#     [17.524221, 16.883003, 0.0998],
#     [17.407837, 16.794458, 0.1042],
#     [17.316584, 17.310383, 0.0986],
#     [17.327866, 17.04672, 0.0962],
#     [17.285624, 18.201954, 0.0858],
#     [17.297756, 18.193098, 0.0896],
#     [17.279016, 16.902966, 0.1026],
#     [17.26401, 16.760721, 0.0996],
#     [19.190544, 17.389992, 0.093],
#     [17.275234, 17.086084, 0.1012],
#     [16.941805, 17.132175, 0.089],
#     [16.868893, 16.914526, 0.0978],
#     [17.009378, 16.49571, 0.0996],
#     [17.089855, 16.55116, 0.0994],
#     [17.14885, 16.895538, 0.105],
#     [17.154331, 16.949188, 0.1016],
#     [17.119335, 16.877169, 0.103],
#     [17.1186, 16.543308, 0.1006],
#     [21.317959, 17.313128, 0.0978],
#     [17.054115, 16.791815, 0.1056],
#     [17.022259, 17.589392, 0.0982],
#     [17.05618, 17.582653, 0.0876],
#     [17.153778, 17.257954, 0.1018],
#     [17.121838, 16.705969, 0.109],
#     [17.067385, 17.263733, 0.0952],
#     [17.05869, 16.848526, 0.0964],
#     [17.03536, 16.938612, 0.1016],
#     [17.04901, 17.573889, 0.0892],
#     [19.859789, 17.089466, 0.1028],
#     [17.189545, 16.568441, 0.1044],
#     [17.063557, 16.575565, 0.104],
#     [17.065804, 17.266623, 0.0972],
#     [17.130093, 16.496237, 0.1016],
#     [17.063244, 16.908218, 0.1024],
#     [17.031496, 16.816353, 0.0878],
#     [17.001583, 16.950445, 0.0876],
#     [17.022476, 16.648676, 0.1018],
#     [17.005507, 17.32605, 0.0928],
#     [13.140474, 17.0708, 0.102],
#     [16.770676, 16.641806, 0.1026],
#     [16.917097, 16.851147, 0.098],
#     [16.820436, 16.962984, 0.1006],
#     [16.931528, 16.893002, 0.0906],
#     [16.945717, 17.09479, 0.0906],
#     [16.984602, 16.826267, 0.1044],
#     [16.927942, 16.714947, 0.1026],
#     [16.96756, 16.769644, 0.1004],
#     [16.97267, 16.971472, 0.0972],
#     [13.442615, 16.658142, 0.0942],
#     [17.194954, 16.827658, 0.105],
#     [17.295397, 16.88845, 0.0984],
#     [17.267977, 16.51819, 0.1058],
#     [17.10135, 16.832743, 0.0972],
#     [17.10409, 16.393373, 0.0952],
#     [17.079306, 16.908476, 0.0976],
#     [17.051657, 16.575903, 0.0978],
#     [17.040995, 16.838833, 0.092],
#     [16.98558, 16.935848, 0.0988],
#     [18.37716, 17.238722, 0.0882],
#     [17.283327, 17.603937, 0.0938],
#     [17.146795, 17.007008, 0.1062],
#     [17.065882, 17.154692, 0.096],
#     [17.081669, 16.916052, 0.0928],
#     [17.078865, 16.574966, 0.101],
#     [17.093, 16.846489, 0.0974],
#     [17.010122, 17.216848, 0.0958],
#     [16.983309, 16.811714, 0.0982],
#     [16.94149, 16.934582, 0.097],
#     [15.981265, 16.992887, 0.0942],
#     [16.932552, 16.200153, 0.1096],
#     [16.988358, 16.671236, 0.1004],
#     [16.95144, 17.258947, 0.0836],
#     [17.006878, 17.49823, 0.087],
#     [16.940685, 16.895884, 0.106],
#     [16.929497, 17.157066, 0.1038],
#     [16.849941, 16.875147, 0.0936],
#     [16.810287, 17.11074, 0.102],
#     [16.843105, 17.020975, 0.1024],
#     [15.497686, 16.812187, 0.102],
#     [16.696857, 16.624338, 0.0998],
#     [16.735653, 16.470165, 0.113],
#     [16.84763, 16.564299, 0.102],
#     [16.906727, 16.827703, 0.1022],
#     [16.84574, 16.186096, 0.1056],
#     [16.880108, 16.597013, 0.1002],
#     [16.896187, 16.678307, 0.0978],
#     [16.845432, 16.644573, 0.0932],
#     [16.817583, 17.119177, 0.1006],
#     [14.590575, 17.108082, 0.099],
#     [16.698498, 16.485304, 0.0978],
#     [16.647541, 16.259443, 0.106],
#     [16.700075, 16.7165, 0.1022],
#     [16.76686, 16.784542, 0.0958],
#     [16.710695, 17.295618, 0.099],
#     [16.691269, 16.793932, 0.1038],
#     [16.694792, 16.608955, 0.0942],
#     [16.737719, 16.982508, 0.0948],
#     [16.735989, 16.602806, 0.1034],
#     [17.463814, 16.868393, 0.0992],
#     [16.734327, 16.768723, 0.098],
#     [16.882654, 16.566519, 0.1012],
#     [16.790947, 16.85506, 0.101],
#     [16.844564, 16.51335, 0.1052],
#     [16.8503, 16.805159, 0.0958],
#     [16.902647, 17.193138, 0.0924],
#     [16.854212, 16.799814, 0.0996],
#     [16.821856, 16.531458, 0.1086],
#     [16.75414, 16.910666, 0.0942],
#     [17.783024, 16.74346, 0.0954],
#     [16.365078, 16.466398, 0.1044],
#     [16.390219, 16.95081, 0.0958],
#     [16.495321, 16.819462, 0.099],
#     [16.63186, 17.20459, 0.0932],
#     [16.707132, 17.037275, 0.095],
#     [16.804363, 16.100708, 0.1018],
#     [16.790648, 16.781229, 0.1016],
#     [16.839409, 16.636505, 0.1034],
#     [16.814869, 16.494568, 0.0962]],
#    0.0964]}}

# %% [markdown]
# ## 综合试验
#
# 为了系统化的比较不同的参数对迁移学习的影响，我们做了一次大实验：
#
# 该试验包括了三重循环，分别是：
#
# 1、不同的迁移学习方法：无迁移、迁移固定权重、迁移预训练
#
# 2、每一个参数下重复实验times次
#
# 3、加载不同的数据集比例fraction
#
# 由于本试验需要消耗大量的计算时间，所以请慎重执行下面的语句。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
results = {} #记载实验结果
times = 10 # 每一组参数下实验都要被重复10次
fractions = [20, 10, 8, 6, 5, 4, 3, 2, 1] #所有的数据加载的比例值
for experiment in ['no transfer', 'transfer_fixed', 'transfer_pretrained']:
    for time in range(times):
        for fraction in fractions:
            
            # 分不同的迁移学习情况加载网络和优化器
            if experiment == 'no transfer':
                net = Transfer()
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
            if experiment == 'transfer_pretrained':
                net = Transfer()
                net.set_filter_values(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
            if experiment == 'transfer_fixed':
                net = Transfer()
                net.set_filter_values_nograd(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
                
            #开始迁移学习训练
            num_epochs = 20
            records = []
            for epoch in range(num_epochs):
                losses = []
                for idx, data in enumerate(zip(train_loader1, train_loader2)):
                    if idx >= (len(train_loader1) // fraction):
                        break
                    ((x1, y1), (x2, y2)) = data
                    if use_cuda:
                        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                    net.train()
                    optimizer.zero_grad()
                    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                    labels = y1 + y2
                    loss = criterion(outputs, labels.type(dtype))
                    loss.backward()
                    optimizer.step()
                    loss = loss.cpu() if use_cuda else loss
                    losses.append(loss.data.numpy())
                    if idx % 500 == 0:
                        val_losses = []
                        rights = []
                        net.eval()
                        for val_data in zip(val_loader1, val_loader2):
                            ((x1, y1), (x2, y2)) = val_data
                            if use_cuda:
                                x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                            outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                            labels = y1 + y2
                            loss = criterion(outputs, labels.type(dtype))
                            loss = loss.cpu() if use_cuda else loss
                            val_losses.append(loss.data.numpy())
                            right = rightness(outputs.data, labels)
                            rights.append(right)
                        right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
                        print('{}网络：第{}试验，比例{}, 第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'
                              .format(experiment,time,fraction,
                            epoch, idx, len(train_loader1),
                            np.mean(losses), np.mean(val_losses), right_ratio))
                        records.append([np.mean(losses), np.mean(val_losses), right_ratio])
            rights = []
            net.eval()
            for test_data in zip(test_loader1, test_loader2):
                ((x1, y1), (x2, y2)) = test_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(dtype))
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print(experiment,time,fraction)
            
            #将结果记录在了results集合之中，records记载了每一个打印周期的训练集损失函数、校验集损失函数、校验集正确率，
            #right_ratio记录了每次实验测试集的准确度
            results[(experiment,time,fraction)] = [records, right_ratio]

# %%
# 处理实验数据
# 首先对于同一组参数下的数据求多次试验的平均值

one_curve = {}
tests = {}
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    for fraction in fractions:
        one_experiment = []
        test_value = []
        for time in range(times):
            rr = results[(experiment, time, fraction)]
            one_experiment.append([ii[2] for ii in rr[0]])
            test_value.append(rr[1])
        aa = np.array(one_experiment)
        #print(aa.shape)
        one_curve[(experiment, fraction)] = np.mean(aa, 0)
        tests[(experiment, fraction)] = np.mean(test_value)

# %%
# 然后再绘制它们的误差曲线
for fraction in fractions:
    plt.figure(figsize = (10, 7))
    plt.title('{:.2f} % of the data'.format(100.0 / fraction))
    plt.plot(1 - one_curve[('no transfer', fraction)], label = 'no transfer')
    plt.plot(1 - one_curve[('transfer_pretrained', fraction)], label = 'transfer pretrained')
    plt.plot(1 - one_curve[('transfer_fixed', fraction)] , label = 'transfer fixed')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Error')

# %%
# 绘制测试准确度随着fraction变化的曲线
plt.figure(figsize = (10, 7))
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    testss = []
    for fraction in fractions:
        test = 1 - tests[(experiment, fraction)]
        testss.append(test)
    plt.plot(fractions, testss, 'o-', label = experiment)
plt.legend()
plt.xlabel('Fractions')
plt.ylabel('Error Rate')

# %% [markdown]
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码
