# %% [markdown]
# # 迁移学习——手写数字加法机
#
# 本文件是集智AI学园开发的“火炬上的深度学习”系列课程第四节课：《神经网络移情别恋——迁移学习》的配套文档。在本文档中，我们
# 实现了一个手写数字加法机，它可以通过识别输入的两个手写体图像文件，从而计算两个数字的和，并给出输出。我们展示了三种不同
# 的迁移学习方式，并对它们进行了系统化的比较：
#
# 1、没有迁移学习，网络完全从头学习如何识别数字，如何计算加法；
#
# 2、将已训练好的手写数字识别器网络迁移过来，作为预训练权重；
#
# 3、将已训练好的手写数字识别器网络迁移过来，并作为不可修改的权重。
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline

# %% [markdown]
# ## 一、加载数据
#
# 首先一个问题是如何加载成对的图像数据？我们采用的解决方案是采用了两套采样器和加载器，
# 这样每一组采样器＋加载器都独立地从原始的数据集中抽样数据，这就让我们可以获得大量不重复
# 的手写数字图像对，从而可以训练我们的神经网络。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 设置图像读取器的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #批处理的尺寸大小

# 如果系统中存在着GPU，我们将用GPU来完成张量的计算
use_cuda = torch.cuda.is_available() #定义一个布尔型变量，标志当前的GPU是否可用

# 如果当前GPU可用，则将优先在GPU上进行张量计算
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
itype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

# 加载测试数据集
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())


# 定义两个采样器，每一个采样器都随机地从原始的数据集中抽样数据。抽样数据采用permutation
# 生成任意一个下标重排，从而利用下标来提取dataset中的数据
sample_size = len(train_dataset)
sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))

# 定义两个加载器，分别封装了前两个采样器，实现采样。
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler2
                                           )

# 对于校验数据和测试数据，我们进行类似的处理。
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# 为了比较不同数据量对迁移学习的影响，我们设定了一个加载数据的比例fraction
# 即我们只加载原训练数据集的1/fraction来训练网络
fraction = 1

# %% [markdown]
# ## 二、加载网络
#
# 为了实现迁移学习，我们需要从硬盘上加载已经训练好的手写数字识别器卷积神经网络，加载网络需要经过两个步骤：
#
# 1、定义网络模块（nn.Module）的框架，即新定义类ConvNet，实现其forwar函数；
#
# 2、从硬盘文件加载网络
#
# 3、通过绘制其卷积核，验证加载到的网络和导出的网络一致

# %% [markdown]
# ### 1. 定义网络架构
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
# 定义待迁移的网络框架，所有的神经网络模块包括：Conv2d、MaxPool2d，Linear等模块都不需要重新定义，会自动加载
# 但是网络的forward功能没有办法自动实现，需要重写。
# 一般的，加载网络只加载网络的属性，不加载方法
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        x = F.relu(self.fc1(x)) #全链接，激活函数
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x) #log_softmax可以理解为概率对数值
        return x

# %% [markdown]
# ### 2. 从硬盘文件加载网络
#
# 网络加载命令如下：

# %%
original_net = torch.load('minst_conv_checkpoint') #读取硬盘上的minst_conv_checkpoint文件
# Out:
# /Users/jake/anaconda/envs/pytorch_book/lib/python3.6/site-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/jake/anaconda/envs/pytorch_book/lib/python3.6/site-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /Users/jake/anaconda/envs/pytorch_book/lib/python3.6/site-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
original_net #将网络打印出来观看（只能看到其神经模块和架构）
# Out:
# ConvNet(
#   (conv1): Conv2d (1, 4, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv2): Conv2d (4, 8, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=392, out_features=512)
#   (fc2): Linear(in_features=512, out_features=10)
# )

# %% [markdown]
# ### 3. 检测加载的正确性
#
# 通过测试它在测试数据集上的分类准确度，以及绘制其卷积核，并与导出的程序（minist_convnet.ipynb）中的分类准确度、卷积核等是否相同判断本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素

#在测试集上分批运行，并计算总的正确率
original_net.eval() #标志模型当前为运行阶段
test_loss = 0
correct = 0
vals = []

#对测试数据集进行循环
for data, target in test_loader1:
    data, target = torch.tensor(data, volatile=True,requires_grad = True), torch.tensor(target, requires_grad = True)
    output = original_net(data) #将特征数据喂入网络，得到分类的输出
    val = rightness(output, target) #获得正确样本数以及总样本数
    vals.append(val) #记录结果

#计算准确率
rights = (sum([tup[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 1.0 * rights[0] / rights[1]
right_rate
# Out:
# /Users/jake/anaconda/envs/pytorch_book/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# 0.9916

# %%
#随便从测试集中读入一张图片，并绘制出来
idx = 4
muteimg = test_dataset[idx][0].numpy()
plt.imshow(muteimg[0,...])
print('标签是：',test_dataset[idx][1])
# Out:
# 标签是： 4

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(original_net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(original_net.conv2.weight.data.numpy()[j, i,...])

# %% [markdown]
# ## 三、数字加法机的实现
#
# 数字加法机：输入两张图像，输出这两个手写数字的加法。网络的架构如下：
#
# 两个并行的卷积模块：两个卷积层、两个Pooling层；一个全链接模块：最多四层全链接层。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
depth = [4, 8]
class Transfer(nn.Module):
    def __init__(self):
        super(Transfer, self).__init__()
        # 两个并行的卷积通道，第一个通道：
        self.net1_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net_pool = nn.MaxPool2d(2, 2) #2*2 池化
        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 第二个通道，注意pooling操作不需要重复定义
        self.net2_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 全链接层
        self.fc1 = nn.Linear(2 * image_size // 4 * image_size // 4 * depth[1] , 1024) #输入为处理后的特征图压平，输出1024个单元
        self.fc2 = nn.Linear(1024, 2 * num_classes) #输入1024个单元，输出20个单元
        self.fc3 = nn.Linear(2 * num_classes, num_classes) #输入20个单元，输出10个单元
        self.fc4 = nn.Linear(num_classes, 1) #输入10个单元，输出为1

    def forward(self, x, y, training = True):
        # 网络的前馈过程。输入两张手写图像x和y，输出一个数字表示两个数字的和
        # x,y都是batch_size*image_size*image_size形状的三阶张量
        # 输出为batch_size长的列向量
        
        # 首先，第一张图像进入第一个通道
        x = F.relu(self.net1_conv1(x)) #第一层卷积
        x = self.net_pool(x)   # 第一层池化
        x = F.relu(self.net1_conv2(x))  # 第二层卷积
        x = self.net_pool(x) # 第二层池化
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1]) # 将特征图张量压平
        
        
        y = F.relu(self.net2_conv1(y)) #第一层卷积
        y = self.net_pool(y) # 第一层池化
        y = F.relu(self.net2_conv2(y)) #第二层卷积
        y = self.net_pool(y) #第二层池化
        y = y.view(-1, image_size // 4 * image_size // 4 * depth[1])# 将特征图张量压平
        
        # 将两个卷积过来的铺平向量拼接在一起，形成一个大向量
        z = torch.cat((x, y), 1) #cat函数为拼接向量操作，1表示拼接的维度为第1个维度（0维度对应了batch）
        z = self.fc1(z) #第一层全链接
        z = F.relu(z)  #对于深层网络来说，激活函数用relu效果会比较好
        z = F.dropout(z, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        z = self.fc2(z) #第二层全链接
        z = F.relu(z)
        z = self.fc3(z) #第三层全链接
        z = F.relu(z)
        z = self.fc4(z) # 第四层全链接
        return z
    def set_filter_values(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为预训练式
        # 输入参数net为从硬盘加载的网络作为迁移源
        
        # 逐个儿为网络的两个卷积模块的权重和偏置进行赋值
        # 注意在赋值的时候需要用deepcopy而不能直接等于，或者copy。
        # 这是因为这种拷贝是将张量中的数值全部拷贝到了目标中，而不是拷贝地址
        # 如果不用deepcopy，由于我们将同一组参数（net.conv1.weight.data,bias）
        #  赋予了两组参数（net1_conv1.weight.data，net2_conv1.weight.data）
        # 所以它们会共享源net.conv1.weight.data中的地址，这样对于net1_conv1.weight.data
        # 的训练也自然会被用到了net2_conv1.weight.data中，但其实我们希望它们是两个不同的参数。
        self.net1_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net1_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net1_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net1_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        self.net2_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net2_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net2_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net2_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        
        # 将变量加载到GPU上        
        self.net1_conv1 = self.net1_conv1.cuda() if use_cuda else self.net1_conv1
        self.net1_conv2 = self.net1_conv2.cuda() if use_cuda else self.net1_conv2
        
        self.net2_conv1 = self.net2_conv1.cuda() if use_cuda else self.net2_conv1
        self.net2_conv2 = self.net2_conv2.cuda() if use_cuda else self.net2_conv2
    def set_filter_values_nograd(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为固定权重式
        # 调用set_filter_values为全部卷积核进行赋值
        self.set_filter_values(net)
        
        # 为了让我们的网络不被训练调整权值，我们需要设定每一个变量的requires_grad为False
        # 即不需要计算梯度值
        self.net1_conv1.weight.requires_grad = False
        self.net1_conv1.bias.requires_grad = False
        self.net1_conv2.weight.requires_grad = False
        self.net1_conv2.bias.requires_grad = False
        
        
        self.net2_conv1.weight.requires_grad = False
        self.net2_conv1.bias.requires_grad = False
        self.net2_conv2.weight.requires_grad = False
        self.net2_conv2.bias.requires_grad = False
def rightness(y, target):
    # 计算分类准确度的函数，y为模型预测的标签，target为数据的标签
    # 输入的y为一个矩阵，行对应了batch中的不同数据记录，列对应了不同的分类选择，数值对应了概率
    # 函数输出分别为预测与数据标签相等的个数，本次判断的所有数据个数
    out = torch.round(y.squeeze()).type(itype)
    out = out.eq(target).sum()
    out1 = y.size()[0]
    return(out, out1)

# %% [markdown]
# ## 四、数据迁移实验

# %% [markdown]
# ### 1. 无迁移实验
#
# 在本试验中，我们不迁移网络，直接训练整个网络

# %%
# 生成网络实例
net = Transfer()

# 如果存在GPU，则将网络加载到GPU中
if use_cuda:
    net = net.cuda()
    
# 定义损失函数，我们用最小均方误差来定义损失
criterion = nn.MSELoss()

# 定义优化器
optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
results = {}

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    
    # 我们可以用zip命令来同时从两个数据加载器中加载数据，enumerate则给这个迭代附加上了计数
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        # 为了比较数据量大小对迁移学习的影响，我们只加载了部分数据，当数据加载个数idx大于
        # 全数据集的1/fraction的时候则不再加载后面的数据
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        optimizer.zero_grad()
        net.train()
        outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
        labels = y1 + y2
        loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            # 在校验数据上计算计算准确率
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                labels = y1 + y2
                
                loss = criterion(outputs, torch.tensor(labels.type(dtype),requires_grad = True))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])

# 在测试数据集上测试准确度
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
    labels = y1 + y2
    loss = criterion(outputs, torch.tensor(labels.type(dtype),requires_grad = True))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['notransfer'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：95.794189453125, 校验误差：98.98, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：71.30835723876953, 校验误差：16.20, 准确率：0.09
# 第0周期，第(200/938)个撮，训练误差：44.29765319824219, 校验误差：16.65, 准确率：0.10
# 第0周期，第(300/938)个撮，训练误差：34.49030685424805, 校验误差：12.97, 准确率：0.11
# 第0周期，第(400/938)个撮，训练误差：28.694334030151367, 校验误差：10.02, 准确率：0.13
# 第0周期，第(500/938)个撮，训练误差：24.80965232849121, 校验误差：8.43, 准确率：0.14
# 第0周期，第(600/938)个撮，训练误差：22.059194564819336, 校验误差：7.86, 准确率：0.14
# 第0周期，第(700/938)个撮，训练误差：19.938867568969727, 校验误差：6.72, 准确率：0.15
# 第0周期，第(800/938)个撮，训练误差：18.261743545532227, 校验误差：6.94, 准确率：0.15
# 第0周期，第(900/938)个撮，训练误差：16.90585708618164, 校验误差：6.22, 准确率：0.16
# 第1周期，第(0/938)个撮，训练误差：5.54604959487915, 校验误差：6.34, 准确率：0.17
# 第1周期，第(100/938)个撮，训练误差：5.71030855178833, 校验误差：5.64, 准确率：0.16
# 第1周期，第(200/938)个撮，训练误差：5.540467739105225, 校验误差：5.63, 准确率：0.17
# 第1周期，第(300/938)个撮，训练误差：5.45220947265625, 校验误差：5.10, 准确率：0.18
# 第1周期，第(400/938)个撮，训练误差：5.367753028869629, 校验误差：5.16, 准确率：0.18
# 第1周期，第(500/938)个撮，训练误差：5.241856098175049, 校验误差：4.71, 准确率：0.20
# 第1周期，第(600/938)个撮，训练误差：5.157260894775391, 校验误差：4.72, 准确率：0.18
# 第1周期，第(700/938)个撮，训练误差：5.05911111831665, 校验误差：4.65, 准确率：0.19
# 第1周期，第(800/938)个撮，训练误差：4.991608619689941, 校验误差：4.49, 准确率：0.21
# 第1周期，第(900/938)个撮，训练误差：4.906608581542969, 校验误差：4.47, 准确率：0.19
# 第2周期，第(0/938)个撮，训练误差：5.241722583770752, 校验误差：4.54, 准确率：0.20
# 第2周期，第(100/938)个撮，训练误差：3.9944896697998047, 校验误差：4.19, 准确率：0.19
# 第2周期，第(200/938)个撮，训练误差：4.026300430297852, 校验误差：3.97, 准确率：0.22
# 第2周期，第(300/938)个撮，训练误差：3.964121103286743, 校验误差：4.11, 准确率：0.21
# 第2周期，第(400/938)个撮，训练误差：3.9143495559692383, 校验误差：4.13, 准确率：0.20
# 第2周期，第(500/938)个撮，训练误差：3.9084713459014893, 校验误差：4.65, 准确率：0.22
# 第2周期，第(600/938)个撮，训练误差：3.8932247161865234, 校验误差：3.63, 准确率：0.22
# 第2周期，第(700/938)个撮，训练误差：3.864952325820923, 校验误差：3.79, 准确率：0.24
# 第2周期，第(800/938)个撮，训练误差：3.825589179992676, 校验误差：3.59, 准确率：0.23
# 第2周期，第(900/938)个撮，训练误差：3.7850306034088135, 校验误差：3.66, 准确率：0.23
# 第3周期，第(0/938)个撮，训练误差：2.906486749649048, 校验误差：3.48, 准确率：0.23
# 第3周期，第(100/938)个撮，训练误差：3.23471999168396, 校验误差：3.37, 准确率：0.24
# 第3周期，第(200/938)个撮，训练误差：3.340056896209717, 校验误差：3.59, 准确率：0.25
# 第3周期，第(300/938)个撮，训练误差：3.326932668685913, 校验误差：3.44, 准确率：0.25
# 第3周期，第(400/938)个撮，训练误差：3.244709014892578, 校验误差：3.16, 准确率：0.26
# 第3周期，第(500/938)个撮，训练误差：3.233332633972168, 校验误差：3.54, 准确率：0.22
# 第3周期，第(600/938)个撮，训练误差：3.213785171508789, 校验误差：3.33, 准确率：0.25
# 第3周期，第(700/938)个撮，训练误差：3.20242977142334, 校验误差：3.20, 准确率：0.25
# 第3周期，第(800/938)个撮，训练误差：3.1950321197509766, 校验误差：3.17, 准确率：0.26
# 第3周期，第(900/938)个撮，训练误差：3.1682283878326416, 校验误差：3.09, 准确率：0.24
# 第4周期，第(0/938)个撮，训练误差：4.437862873077393, 校验误差：3.09, 准确率：0.25
# 第4周期，第(100/938)个撮，训练误差：3.0753884315490723, 校验误差：2.99, 准确率：0.27
# 第4周期，第(200/938)个撮，训练误差：2.9820592403411865, 校验误差：3.01, 准确率：0.25
# 第4周期，第(300/938)个撮，训练误差：2.9505743980407715, 校验误差：2.97, 准确率：0.25
# 第4周期，第(400/938)个撮，训练误差：2.92409610748291, 校验误差：2.95, 准确率：0.27
# 第4周期，第(500/938)个撮，训练误差：2.896049737930298, 校验误差：2.82, 准确率：0.28
# 第4周期，第(600/938)个撮，训练误差：2.891845226287842, 校验误差：2.91, 准确率：0.26
# 第4周期，第(700/938)个撮，训练误差：2.875878095626831, 校验误差：2.78, 准确率：0.27
# 第4周期，第(800/938)个撮，训练误差：2.846984386444092, 校验误差：2.75, 准确率：0.27
# 第4周期，第(900/938)个撮，训练误差：2.8301241397857666, 校验误差：2.77, 准确率：0.29
# 第5周期，第(0/938)个撮，训练误差：2.921983242034912, 校验误差：2.92, 准确率：0.25
# 第5周期，第(100/938)个撮，训练误差：2.814614772796631, 校验误差：2.93, 准确率：0.29
# 第5周期，第(200/938)个撮，训练误差：2.780494451522827, 校验误差：2.78, 准确率：0.29
# 第5周期，第(300/938)个撮，训练误差：2.7073123455047607, 校验误差：2.66, 准确率：0.27
# 第5周期，第(400/938)个撮，训练误差：2.67159366607666, 校验误差：2.62, 准确率：0.29
# 第5周期，第(500/938)个撮，训练误差：2.6464731693267822, 校验误差：2.72, 准确率：0.30
# 第5周期，第(600/938)个撮，训练误差：2.6207053661346436, 校验误差：2.61, 准确率：0.31
# 第5周期，第(700/938)个撮，训练误差：2.6170403957366943, 校验误差：2.63, 准确率：0.30
# 第5周期，第(800/938)个撮，训练误差：2.59393048286438, 校验误差：2.65, 准确率：0.30
# 第5周期，第(900/938)个撮，训练误差：2.5755226612091064, 校验误差：2.57, 准确率：0.31
# 第6周期，第(0/938)个撮，训练误差：4.732388019561768, 校验误差：2.65, 准确率：0.30
# 第6周期，第(100/938)个撮，训练误差：2.4724440574645996, 校验误差：2.61, 准确率：0.29
# 第6周期，第(200/938)个撮，训练误差：2.4615702629089355, 校验误差：2.86, 准确率：0.29
# 第6周期，第(300/938)个撮，训练误差：2.461935043334961, 校验误差：2.62, 准确率：0.30
# 第6周期，第(400/938)个撮，训练误差：2.433321475982666, 校验误差：2.54, 准确率：0.29
# 第6周期，第(500/938)个撮，训练误差：2.4285223484039307, 校验误差：2.45, 准确率：0.31
# 第6周期，第(600/938)个撮，训练误差：2.413329601287842, 校验误差：2.41, 准确率：0.33
# 第6周期，第(700/938)个撮，训练误差：2.3981146812438965, 校验误差：2.42, 准确率：0.31
# 第6周期，第(800/938)个撮，训练误差：2.386258840560913, 校验误差：2.45, 准确率：0.30
# 第6周期，第(900/938)个撮，训练误差：2.3822598457336426, 校验误差：2.44, 准确率：0.32
# 第7周期，第(0/938)个撮，训练误差：1.4770965576171875, 校验误差：2.38, 准确率：0.32
# 第7周期，第(100/938)个撮，训练误差：2.4899003505706787, 校验误差：2.45, 准确率：0.33
# 第7周期，第(200/938)个撮，训练误差：2.3902034759521484, 校验误差：2.38, 准确率：0.32
# 第7周期，第(300/938)个撮，训练误差：2.3452162742614746, 校验误差：2.38, 准确率：0.32
# 第7周期，第(400/938)个撮，训练误差：2.3122549057006836, 校验误差：2.43, 准确率：0.30
# 第7周期，第(500/938)个撮，训练误差：2.3094894886016846, 校验误差：2.36, 准确率：0.32
# 第7周期，第(600/938)个撮，训练误差：2.3052752017974854, 校验误差：2.37, 准确率：0.33
# 第7周期，第(700/938)个撮，训练误差：2.294973373413086, 校验误差：2.31, 准确率：0.34
# 第7周期，第(800/938)个撮，训练误差：2.2865004539489746, 校验误差：2.39, 准确率：0.32
# 第7周期，第(900/938)个撮，训练误差：2.271339178085327, 校验误差：2.34, 准确率：0.34
# 第8周期，第(0/938)个撮，训练误差：1.7546135187149048, 校验误差：2.29, 准确率：0.30
# 第8周期，第(100/938)个撮，训练误差：2.2541468143463135, 校验误差：2.25, 准确率：0.33
# 第8周期，第(200/938)个撮，训练误差：2.2256479263305664, 校验误差：2.29, 准确率：0.34
# 第8周期，第(300/938)个撮，训练误差：2.2036290168762207, 校验误差：2.24, 准确率：0.34
# 第8周期，第(400/938)个撮，训练误差：2.1777291297912598, 校验误差：2.21, 准确率：0.35
# 第8周期，第(500/938)个撮，训练误差：2.1596922874450684, 校验误差：2.26, 准确率：0.31
# 第8周期，第(600/938)个撮，训练误差：2.1493489742279053, 校验误差：2.23, 准确率：0.32
# 第8周期，第(700/938)个撮，训练误差：2.1361100673675537, 校验误差：2.21, 准确率：0.34
# 第8周期，第(800/938)个撮，训练误差：2.1299784183502197, 校验误差：2.23, 准确率：0.34
# 第8周期，第(900/938)个撮，训练误差：2.1192054748535156, 校验误差：2.13, 准确率：0.34
# 第9周期，第(0/938)个撮，训练误差：2.3420917987823486, 校验误差：2.11, 准确率：0.33
# 第9周期，第(100/938)个撮，训练误差：2.1988062858581543, 校验误差：2.18, 准确率：0.33
# 第9周期，第(200/938)个撮，训练误差：2.123626232147217, 校验误差：2.20, 准确率：0.34
# 第9周期，第(300/938)个撮，训练误差：2.092668056488037, 校验误差：2.20, 准确率：0.35
# 第9周期，第(400/938)个撮，训练误差：2.053138256072998, 校验误差：2.18, 准确率：0.36
# 第9周期，第(500/938)个撮，训练误差：2.0473146438598633, 校验误差：2.12, 准确率：0.35
# 第9周期，第(600/938)个撮，训练误差：2.043757677078247, 校验误差：2.13, 准确率：0.35
# 第9周期，第(700/938)个撮，训练误差：2.031952381134033, 校验误差：2.08, 准确率：0.36
# 第9周期，第(800/938)个撮，训练误差：2.0288264751434326, 校验误差：2.09, 准确率：0.35
# 第9周期，第(900/938)个撮，训练误差：2.0298268795013428, 校验误差：2.11, 准确率：0.34
# 第10周期，第(0/938)个撮，训练误差：1.7654078006744385, 校验误差：2.08, 准确率：0.36
# 第10周期，第(100/938)个撮，训练误差：2.0091583728790283, 校验误差：2.03, 准确率：0.35
# 第10周期，第(200/938)个撮，训练误差：1.943532109260559, 校验误差：2.05, 准确率：0.35
# 第10周期，第(300/938)个撮，训练误差：1.9209990501403809, 校验误差：2.03, 准确率：0.35
# 第10周期，第(400/938)个撮，训练误差：1.9373189210891724, 校验误差：2.11, 准确率：0.37
# 第10周期，第(500/938)个撮，训练误差：1.9277161359786987, 校验误差：2.06, 准确率：0.36
# 第10周期，第(600/938)个撮，训练误差：1.9135313034057617, 校验误差：2.08, 准确率：0.35
# 第10周期，第(700/938)个撮，训练误差：1.9187204837799072, 校验误差：2.06, 准确率：0.36
# 第10周期，第(800/938)个撮，训练误差：1.92171311378479, 校验误差：2.06, 准确率：0.36
# 第10周期，第(900/938)个撮，训练误差：1.9197449684143066, 校验误差：1.96, 准确率：0.36
# 第11周期，第(0/938)个撮，训练误差：1.1846966743469238, 校验误差：2.15, 准确率：0.36
# 第11周期，第(100/938)个撮，训练误差：1.9022836685180664, 校验误差：1.95, 准确率：0.36
# 第11周期，第(200/938)个撮，训练误差：1.9022338390350342, 校验误差：2.04, 准确率：0.37
# 第11周期，第(300/938)个撮，训练误差：1.8839975595474243, 校验误差：2.03, 准确率：0.38
# 第11周期，第(400/938)个撮，训练误差：1.8863461017608643, 校验误差：1.97, 准确率：0.38
# 第11周期，第(500/938)个撮，训练误差：1.8748347759246826, 校验误差：1.91, 准确率：0.37
# 第11周期，第(600/938)个撮，训练误差：1.8834574222564697, 校验误差：2.18, 准确率：0.37
# 第11周期，第(700/938)个撮，训练误差：1.8710120916366577, 校验误差：1.99, 准确率：0.37
# 第11周期，第(800/938)个撮，训练误差：1.8746579885482788, 校验误差：1.97, 准确率：0.37
# 第11周期，第(900/938)个撮，训练误差：1.8789398670196533, 校验误差：1.95, 准确率：0.36
# 第12周期，第(0/938)个撮，训练误差：2.5457775592803955, 校验误差：1.95, 准确率：0.37
# 第12周期，第(100/938)个撮，训练误差：1.7358992099761963, 校验误差：1.94, 准确率：0.38
# 第12周期，第(200/938)个撮，训练误差：1.780574083328247, 校验误差：2.06, 准确率：0.37
# 第12周期，第(300/938)个撮，训练误差：1.7775598764419556, 校验误差：2.03, 准确率：0.38
# 第12周期，第(400/938)个撮，训练误差：1.7859489917755127, 校验误差：1.91, 准确率：0.37
# 第12周期，第(500/938)个撮，训练误差：1.7744044065475464, 校验误差：1.89, 准确率：0.38
# 第12周期，第(600/938)个撮，训练误差：1.7799537181854248, 校验误差：1.90, 准确率：0.37
# 第12周期，第(700/938)个撮，训练误差：1.7877370119094849, 校验误差：1.86, 准确率：0.39
# 第12周期，第(800/938)个撮，训练误差：1.7929836511611938, 校验误差：1.97, 准确率：0.38
# 第12周期，第(900/938)个撮，训练误差：1.7900850772857666, 校验误差：1.81, 准确率：0.38
# 第13周期，第(0/938)个撮，训练误差：1.5380427837371826, 校验误差：1.86, 准确率：0.39
# 第13周期，第(100/938)个撮，训练误差：1.7529494762420654, 校验误差：1.84, 准确率：0.37
# 第13周期，第(200/938)个撮，训练误差：1.770821213722229, 校验误差：1.86, 准确率：0.38
# 第13周期，第(300/938)个撮，训练误差：1.7682335376739502, 校验误差：1.85, 准确率：0.38
# 第13周期，第(400/938)个撮，训练误差：1.7671486139297485, 校验误差：1.81, 准确率：0.38
# 第13周期，第(500/938)个撮，训练误差：1.760380744934082, 校验误差：1.89, 准确率：0.37
# 第13周期，第(600/938)个撮，训练误差：1.7451086044311523, 校验误差：1.90, 准确率：0.38
# 第13周期，第(700/938)个撮，训练误差：1.746968388557434, 校验误差：1.94, 准确率：0.39
# 第13周期，第(800/938)个撮，训练误差：1.7423676252365112, 校验误差：1.87, 准确率：0.38
# 第13周期，第(900/938)个撮，训练误差：1.7334219217300415, 校验误差：1.91, 准确率：0.39
# 第14周期，第(0/938)个撮，训练误差：1.0227075815200806, 校验误差：1.78, 准确率：0.40
# 第14周期，第(100/938)个撮，训练误差：1.6692754030227661, 校验误差：1.83, 准确率：0.38
# 第14周期，第(200/938)个撮，训练误差：1.6531864404678345, 校验误差：1.81, 准确率：0.38
# 第14周期，第(300/938)个撮，训练误差：1.656343936920166, 校验误差：1.83, 准确率：0.38
# 第14周期，第(400/938)个撮，训练误差：1.6563369035720825, 校验误差：1.85, 准确率：0.39
# 第14周期，第(500/938)个撮，训练误差：1.6719785928726196, 校验误差：1.77, 准确率：0.39
# 第14周期，第(600/938)个撮，训练误差：1.679024338722229, 校验误差：1.81, 准确率：0.38
# 第14周期，第(700/938)个撮，训练误差：1.6773167848587036, 校验误差：1.87, 准确率：0.40
# 第14周期，第(800/938)个撮，训练误差：1.6819158792495728, 校验误差：1.78, 准确率：0.39
# 第14周期，第(900/938)个撮，训练误差：1.682405710220337, 校验误差：1.80, 准确率：0.37
# 第15周期，第(0/938)个撮，训练误差：1.4322121143341064, 校验误差：1.80, 准确率：0.37
# 第15周期，第(100/938)个撮，训练误差：1.739041805267334, 校验误差：1.80, 准确率：0.40
# 第15周期，第(200/938)个撮，训练误差：1.6654353141784668, 校验误差：1.74, 准确率：0.39
# 第15周期，第(300/938)个撮，训练误差：1.6514043807983398, 校验误差：1.85, 准确率：0.39
# 第15周期，第(400/938)个撮，训练误差：1.6586369276046753, 校验误差：1.75, 准确率：0.39
# 第15周期，第(500/938)个撮，训练误差：1.6330113410949707, 校验误差：1.79, 准确率：0.38
# 第15周期，第(600/938)个撮，训练误差：1.6349676847457886, 校验误差：1.73, 准确率：0.38
# 第15周期，第(700/938)个撮，训练误差：1.6353050470352173, 校验误差：1.75, 准确率：0.39
# 第15周期，第(800/938)个撮，训练误差：1.634806752204895, 校验误差：1.88, 准确率：0.40
# 第15周期，第(900/938)个撮，训练误差：1.6391565799713135, 校验误差：1.75, 准确率：0.39
# 第16周期，第(0/938)个撮，训练误差：1.8357254266738892, 校验误差：1.83, 准确率：0.42
# 第16周期，第(100/938)个撮，训练误差：1.6204438209533691, 校验误差：1.81, 准确率：0.38
# 第16周期，第(200/938)个撮，训练误差：1.6326230764389038, 校验误差：1.69, 准确率：0.41
# 第16周期，第(300/938)个撮，训练误差：1.6030325889587402, 校验误差：1.72, 准确率：0.41
# 第16周期，第(400/938)个撮，训练误差：1.599187970161438, 校验误差：1.71, 准确率：0.41
# 第16周期，第(500/938)个撮，训练误差：1.5954346656799316, 校验误差：1.71, 准确率：0.41
# 第16周期，第(600/938)个撮，训练误差：1.6012191772460938, 校验误差：1.69, 准确率：0.40
# 第16周期，第(700/938)个撮，训练误差：1.5916920900344849, 校验误差：1.72, 准确率：0.41
# 第16周期，第(800/938)个撮，训练误差：1.5911568403244019, 校验误差：1.67, 准确率：0.42
# 第16周期，第(900/938)个撮，训练误差：1.593374490737915, 校验误差：1.71, 准确率：0.41
# 第17周期，第(0/938)个撮，训练误差：1.671360731124878, 校验误差：1.64, 准确率：0.39
# 第17周期，第(100/938)个撮，训练误差：1.6232731342315674, 校验误差：1.70, 准确率：0.42
# 第17周期，第(200/938)个撮，训练误差：1.5906739234924316, 校验误差：1.76, 准确率：0.40
# 第17周期，第(300/938)个撮，训练误差：1.5719726085662842, 校验误差：1.70, 准确率：0.41
# 第17周期，第(400/938)个撮，训练误差：1.5791298151016235, 校验误差：1.68, 准确率：0.41
# 第17周期，第(500/938)个撮，训练误差：1.5670289993286133, 校验误差：1.65, 准确率：0.40
# 第17周期，第(600/938)个撮，训练误差：1.5563429594039917, 校验误差：1.69, 准确率：0.41
# 第17周期，第(700/938)个撮，训练误差：1.55830717086792, 校验误差：1.68, 准确率：0.41
# 第17周期，第(800/938)个撮，训练误差：1.5589317083358765, 校验误差：1.73, 准确率：0.41
# 第17周期，第(900/938)个撮，训练误差：1.5536481142044067, 校验误差：1.70, 准确率：0.41
# 第18周期，第(0/938)个撮，训练误差：1.9163134098052979, 校验误差：1.68, 准确率：0.41
# 第18周期，第(100/938)个撮，训练误差：1.6067472696304321, 校验误差：1.64, 准确率：0.43
# 第18周期，第(200/938)个撮，训练误差：1.5626609325408936, 校验误差：1.68, 准确率：0.41
# 第18周期，第(300/938)个撮，训练误差：1.5326203107833862, 校验误差：1.72, 准确率：0.43
# 第18周期，第(400/938)个撮，训练误差：1.5199531316757202, 校验误差：1.63, 准确率：0.42
# 第18周期，第(500/938)个撮，训练误差：1.513606309890747, 校验误差：1.74, 准确率：0.37
# 第18周期，第(600/938)个撮，训练误差：1.5217564105987549, 校验误差：1.63, 准确率：0.43
# 第18周期，第(700/938)个撮，训练误差：1.5281639099121094, 校验误差：1.76, 准确率：0.38
# 第18周期，第(800/938)个撮，训练误差：1.51784348487854, 校验误差：1.63, 准确率：0.41
# 第18周期，第(900/938)个撮，训练误差：1.5116331577301025, 校验误差：1.60, 准确率：0.42
# 第19周期，第(0/938)个撮，训练误差：0.9893876314163208, 校验误差：1.70, 准确率：0.39
# 第19周期，第(100/938)个撮，训练误差：1.4860479831695557, 校验误差：1.59, 准确率：0.42
# 第19周期，第(200/938)个撮，训练误差：1.5018359422683716, 校验误差：1.64, 准确率：0.41
# 第19周期，第(300/938)个撮，训练误差：1.479877233505249, 校验误差：1.61, 准确率：0.40
# 第19周期，第(400/938)个撮，训练误差：1.483993411064148, 校验误差：1.64, 准确率：0.41
# 第19周期，第(500/938)个撮，训练误差：1.4856704473495483, 校验误差：1.69, 准确率：0.43
# 第19周期，第(600/938)个撮，训练误差：1.48004150390625, 校验误差：1.65, 准确率：0.39
# 第19周期，第(700/938)个撮，训练误差：1.4822382926940918, 校验误差：1.62, 准确率：0.43
# 第19周期，第(800/938)个撮，训练误差：1.484467625617981, 校验误差：1.64, 准确率：0.42
# 第19周期，第(900/938)个撮，训练误差：1.4782482385635376, 校验误差：1.64, 准确率：0.43

# %%
# 绘制实验结果，打印测试集上的准确度
plt.plot([i[0] for i in records])
plt.plot([i[1] for i in records])
plt.plot([100 * (1 - i[2]) for i in records])
right_ratio
# Out:
# 0.51200000000000001

# %% [markdown]
# ### 2. 迁移网络，预训练
#
# 在本试验中，我们将手写数字识别的卷积神经网络权重迁移过来，作为新的加法机网络的预训练值（也就是初始值）

# %%
net = Transfer()

# 为新网络赋予权重数值，注意我们只将卷积部分的网络进行迁移，而没有迁移全链接层
net.set_filter_values(original_net)

if use_cuda:
    net = net.cuda()

criterion = nn.MSELoss()

# 将需要训练的参数加载到优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad: #我们只将可以调整权重的变量加到了集合new_parameters
        new_parameters.append(para)
        
# 将new_parameters加载到了优化器中
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
        labels = y1 + y2
        loss = criterion(outputs,torch.tensor(labels.type(dtype),requires_grad = True))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                labels = y1 + y2
                loss = criterion(outputs, torch.tensor(labels.type(dtype),requires_grad = True))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
    labels = y1 + y2
    loss = criterion(outputs, torch.tensor(labels.type(dtype), dtype = requires_grad = True))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_pretrained'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：97.79, 校验误差：91.39, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：19.75, 校验误差：8.66, 准确率：0.13
# 第0周期，第(200/938)个撮，训练误差：13.99, 校验误差：7.13, 准确率：0.15
# 第0周期，第(300/938)个撮，训练误差：11.65, 校验误差：6.22, 准确率：0.16
# 第0周期，第(400/938)个撮，训练误差：10.30, 校验误差：5.91, 准确率：0.17
# 第0周期，第(500/938)个撮，训练误差：9.44, 校验误差：5.26, 准确率：0.18
# 第0周期，第(600/938)个撮，训练误差：8.80, 校验误差：5.36, 准确率：0.19
# 第0周期，第(700/938)个撮，训练误差：8.31, 校验误差：4.95, 准确率：0.18
# 第0周期，第(800/938)个撮，训练误差：7.93, 校验误差：4.74, 准确率：0.21
# 第0周期，第(900/938)个撮，训练误差：7.59, 校验误差：4.74, 准确率：0.22
# 第1周期，第(0/938)个撮，训练误差：4.13, 校验误差：4.45, 准确率：0.21
# 第1周期，第(100/938)个撮，训练误差：4.72, 校验误差：4.43, 准确率：0.19
# 第1周期，第(200/938)个撮，训练误差：4.69, 校验误差：4.75, 准确率：0.22
# 第1周期，第(300/938)个撮，训练误差：4.64, 校验误差：4.92, 准确率：0.22
# 第1周期，第(400/938)个撮，训练误差：4.58, 校验误差：4.08, 准确率：0.23
# 第1周期，第(500/938)个撮，训练误差：4.53, 校验误差：4.12, 准确率：0.23
# 第1周期，第(600/938)个撮，训练误差：4.48, 校验误差：4.06, 准确率：0.20
# 第1周期，第(700/938)个撮，训练误差：4.45, 校验误差：3.91, 准确率：0.24
# 第1周期，第(800/938)个撮，训练误差：4.41, 校验误差：3.78, 准确率：0.25
# 第1周期，第(900/938)个撮，训练误差：4.37, 校验误差：3.53, 准确率：0.25
# 第2周期，第(0/938)个撮，训练误差：3.34, 校验误差：3.75, 准确率：0.23
# 第2周期，第(100/938)个撮，训练误差：3.81, 校验误差：3.65, 准确率：0.25
# 第2周期，第(200/938)个撮，训练误差：3.83, 校验误差：3.61, 准确率：0.25
# 第2周期，第(300/938)个撮，训练误差：3.88, 校验误差：3.49, 准确率：0.26
# 第2周期，第(400/938)个撮，训练误差：3.83, 校验误差：3.50, 准确率：0.26
# 第2周期，第(500/938)个撮，训练误差：3.78, 校验误差：3.46, 准确率：0.27
# 第2周期，第(600/938)个撮，训练误差：3.76, 校验误差：3.34, 准确率：0.25
# 第2周期，第(700/938)个撮，训练误差：3.74, 校验误差：3.39, 准确率：0.25
# 第2周期，第(800/938)个撮，训练误差：3.71, 校验误差：3.46, 准确率：0.27
# 第2周期，第(900/938)个撮，训练误差：3.70, 校验误差：3.22, 准确率：0.26
# 第3周期，第(0/938)个撮，训练误差：3.21, 校验误差：3.36, 准确率：0.27
# 第3周期，第(100/938)个撮，训练误差：3.34, 校验误差：3.24, 准确率：0.27
# 第3周期，第(200/938)个撮，训练误差：3.41, 校验误差：3.25, 准确率：0.28
# 第3周期，第(300/938)个撮，训练误差：3.39, 校验误差：3.22, 准确率：0.27
# 第3周期，第(400/938)个撮，训练误差：3.40, 校验误差：3.61, 准确率：0.25
# 第3周期，第(500/938)个撮，训练误差：3.42, 校验误差：3.16, 准确率：0.27
# 第3周期，第(600/938)个撮，训练误差：3.38, 校验误差：3.22, 准确率：0.28
# 第3周期，第(700/938)个撮，训练误差：3.37, 校验误差：2.98, 准确率：0.28
# 第3周期，第(800/938)个撮，训练误差：3.34, 校验误差：2.97, 准确率：0.28
# 第3周期，第(900/938)个撮，训练误差：3.32, 校验误差：2.97, 准确率：0.29
# 第4周期，第(0/938)个撮，训练误差：4.64, 校验误差：2.95, 准确率：0.28
# 第4周期，第(100/938)个撮，训练误差：3.00, 校验误差：2.99, 准确率：0.29
# 第4周期，第(200/938)个撮，训练误差：3.01, 校验误差：2.89, 准确率：0.29
# 第4周期，第(300/938)个撮，训练误差：3.01, 校验误差：3.35, 准确率：0.24
# 第4周期，第(400/938)个撮，训练误差：3.06, 校验误差：2.82, 准确率：0.28
# 第4周期，第(500/938)个撮，训练误差：3.05, 校验误差：2.91, 准确率：0.28
# 第4周期，第(600/938)个撮，训练误差：3.05, 校验误差：2.79, 准确率：0.30
# 第4周期，第(700/938)个撮，训练误差：3.04, 校验误差：2.92, 准确率：0.27
# 第4周期，第(800/938)个撮，训练误差：3.02, 校验误差：2.85, 准确率：0.30
# 第4周期，第(900/938)个撮，训练误差：3.01, 校验误差：2.73, 准确率：0.28
# 第5周期，第(0/938)个撮，训练误差：1.94, 校验误差：2.70, 准确率：0.30
# 第5周期，第(100/938)个撮，训练误差：2.81, 校验误差：2.72, 准确率：0.29
# 第5周期，第(200/938)个撮，训练误差：2.81, 校验误差：2.75, 准确率：0.30
# 第5周期，第(300/938)个撮，训练误差：2.81, 校验误差：2.73, 准确率：0.29
# 第5周期，第(400/938)个撮，训练误差：2.85, 校验误差：2.76, 准确率：0.28
# 第5周期，第(500/938)个撮，训练误差：2.86, 校验误差：2.75, 准确率：0.28
# 第5周期，第(600/938)个撮，训练误差：2.84, 校验误差：2.66, 准确率：0.28
# 第5周期，第(700/938)个撮，训练误差：2.85, 校验误差：2.61, 准确率：0.28
# 第5周期，第(800/938)个撮，训练误差：2.84, 校验误差：2.79, 准确率：0.29
# 第5周期，第(900/938)个撮，训练误差：2.82, 校验误差：2.54, 准确率：0.31
# 第6周期，第(0/938)个撮，训练误差：2.91, 校验误差：2.66, 准确率：0.31
# 第6周期，第(100/938)个撮，训练误差：2.72, 校验误差：2.56, 准确率：0.31
# 第6周期，第(200/938)个撮，训练误差：2.67, 校验误差：2.66, 准确率：0.28
# 第6周期，第(300/938)个撮，训练误差：2.68, 校验误差：2.71, 准确率：0.30
# 第6周期，第(400/938)个撮，训练误差：2.64, 校验误差：2.52, 准确率：0.32
# 第6周期，第(500/938)个撮，训练误差：2.62, 校验误差：2.39, 准确率：0.31
# 第6周期，第(600/938)个撮，训练误差：2.63, 校验误差：2.47, 准确率：0.32
# 第6周期，第(700/938)个撮，训练误差：2.63, 校验误差：2.55, 准确率：0.32
# 第6周期，第(800/938)个撮，训练误差：2.61, 校验误差：2.55, 准确率：0.32
# 第6周期，第(900/938)个撮，训练误差：2.61, 校验误差：2.37, 准确率：0.33
# 第7周期，第(0/938)个撮，训练误差：3.25, 校验误差：2.39, 准确率：0.33
# 第7周期，第(100/938)个撮，训练误差：2.53, 校验误差：2.37, 准确率：0.32
# 第7周期，第(200/938)个撮，训练误差：2.55, 校验误差：2.64, 准确率：0.31
# 第7周期，第(300/938)个撮，训练误差：2.50, 校验误差：2.38, 准确率：0.33
# 第7周期，第(400/938)个撮，训练误差：2.52, 校验误差：2.35, 准确率：0.33
# 第7周期，第(500/938)个撮，训练误差：2.52, 校验误差：2.48, 准确率：0.33
# 第7周期，第(600/938)个撮，训练误差：2.52, 校验误差：2.43, 准确率：0.34
# 第7周期，第(700/938)个撮，训练误差：2.51, 校验误差：2.32, 准确率：0.33
# 第7周期，第(800/938)个撮，训练误差：2.49, 校验误差：2.30, 准确率：0.33
# 第7周期，第(900/938)个撮，训练误差：2.48, 校验误差：2.34, 准确率：0.33
# 第8周期，第(0/938)个撮，训练误差：3.29, 校验误差：2.32, 准确率：0.32
# 第8周期，第(100/938)个撮，训练误差：2.47, 校验误差：2.35, 准确率：0.34
# 第8周期，第(200/938)个撮，训练误差：2.44, 校验误差：2.20, 准确率：0.34
# 第8周期，第(300/938)个撮，训练误差：2.42, 校验误差：2.25, 准确率：0.34
# 第8周期，第(400/938)个撮，训练误差：2.40, 校验误差：2.43, 准确率：0.33
# 第8周期，第(500/938)个撮，训练误差：2.40, 校验误差：2.31, 准确率：0.35
# 第8周期，第(600/938)个撮，训练误差：2.40, 校验误差：2.25, 准确率：0.34
# 第8周期，第(700/938)个撮，训练误差：2.38, 校验误差：2.25, 准确率：0.34
# 第8周期，第(800/938)个撮，训练误差：2.35, 校验误差：2.20, 准确率：0.34
# 第8周期，第(900/938)个撮，训练误差：2.34, 校验误差：2.20, 准确率：0.34
# 第9周期，第(0/938)个撮，训练误差：2.92, 校验误差：2.38, 准确率：0.34
# 第9周期，第(100/938)个撮，训练误差：2.23, 校验误差：2.25, 准确率：0.35
# 第9周期，第(200/938)个撮，训练误差：2.27, 校验误差：2.30, 准确率：0.33
# 第9周期，第(300/938)个撮，训练误差：2.23, 校验误差：2.38, 准确率：0.35
# 第9周期，第(400/938)个撮，训练误差：2.23, 校验误差：2.15, 准确率：0.34
# 第9周期，第(500/938)个撮，训练误差：2.21, 校验误差：2.12, 准确率：0.36
# 第9周期，第(600/938)个撮，训练误差：2.21, 校验误差：2.19, 准确率：0.34
# 第9周期，第(700/938)个撮，训练误差：2.19, 校验误差：2.05, 准确率：0.35
# 第9周期，第(800/938)个撮，训练误差：2.19, 校验误差：2.13, 准确率：0.34
# 第9周期，第(900/938)个撮，训练误差：2.19, 校验误差：2.13, 准确率：0.35
# 第10周期，第(0/938)个撮，训练误差：2.14, 校验误差：2.14, 准确率：0.36
# 第10周期，第(100/938)个撮，训练误差：2.09, 校验误差：2.08, 准确率：0.35
# 第10周期，第(200/938)个撮，训练误差：2.11, 校验误差：2.07, 准确率：0.35
# 第10周期，第(300/938)个撮，训练误差：2.13, 校验误差：2.15, 准确率：0.36
# 第10周期，第(400/938)个撮，训练误差：2.11, 校验误差：2.16, 准确率：0.36
# 第10周期，第(500/938)个撮，训练误差：2.10, 校验误差：2.05, 准确率：0.37
# 第10周期，第(600/938)个撮，训练误差：2.11, 校验误差：2.11, 准确率：0.34
# 第10周期，第(700/938)个撮，训练误差：2.12, 校验误差：1.98, 准确率：0.37
# 第10周期，第(800/938)个撮，训练误差：2.12, 校验误差：2.08, 准确率：0.35
# 第10周期，第(900/938)个撮，训练误差：2.11, 校验误差：2.15, 准确率：0.37
# 第11周期，第(0/938)个撮，训练误差：1.47, 校验误差：2.06, 准确率：0.37
# 第11周期，第(100/938)个撮，训练误差：2.14, 校验误差：2.03, 准确率：0.37
# 第11周期，第(200/938)个撮，训练误差：2.11, 校验误差：2.00, 准确率：0.35
# 第11周期，第(300/938)个撮，训练误差：2.08, 校验误差：2.02, 准确率：0.38
# 第11周期，第(400/938)个撮，训练误差：2.06, 校验误差：2.00, 准确率：0.37
# 第11周期，第(500/938)个撮，训练误差：2.06, 校验误差：2.18, 准确率：0.37
# 第11周期，第(600/938)个撮，训练误差：2.04, 校验误差：2.08, 准确率：0.35
# 第11周期，第(700/938)个撮，训练误差：2.04, 校验误差：1.99, 准确率：0.36
# 第11周期，第(800/938)个撮，训练误差：2.04, 校验误差：1.91, 准确率：0.36
# 第11周期，第(900/938)个撮，训练误差：2.03, 校验误差：2.04, 准确率：0.38
# 第12周期，第(0/938)个撮，训练误差：1.76, 校验误差：2.26, 准确率：0.31
# 第12周期，第(100/938)个撮，训练误差：1.94, 校验误差：1.90, 准确率：0.39
# 第12周期，第(200/938)个撮，训练误差：1.97, 校验误差：1.94, 准确率：0.37
# 第12周期，第(300/938)个撮，训练误差：1.97, 校验误差：1.97, 准确率：0.37
# 第12周期，第(400/938)个撮，训练误差：1.98, 校验误差：1.91, 准确率：0.38
# 第12周期，第(500/938)个撮，训练误差：1.97, 校验误差：1.94, 准确率：0.38
# 第12周期，第(600/938)个撮，训练误差：1.97, 校验误差：2.07, 准确率：0.37
# 第12周期，第(700/938)个撮，训练误差：1.97, 校验误差：1.97, 准确率：0.38
# 第12周期，第(800/938)个撮，训练误差：1.97, 校验误差：1.98, 准确率：0.35
# 第12周期，第(900/938)个撮，训练误差：1.97, 校验误差：1.89, 准确率：0.38
# 第13周期，第(0/938)个撮，训练误差：2.82, 校验误差：2.04, 准确率：0.36
# 第13周期，第(100/938)个撮，训练误差：1.94, 校验误差：1.87, 准确率：0.37
# 第13周期，第(200/938)个撮，训练误差：1.88, 校验误差：1.89, 准确率：0.37
# 第13周期，第(300/938)个撮，训练误差：1.87, 校验误差：1.93, 准确率：0.39
# 第13周期，第(400/938)个撮，训练误差：1.89, 校验误差：1.89, 准确率：0.36
# 第13周期，第(500/938)个撮，训练误差：1.90, 校验误差：1.95, 准确率：0.37
# 第13周期，第(600/938)个撮，训练误差：1.90, 校验误差：1.89, 准确率：0.39
# 第13周期，第(700/938)个撮，训练误差：1.89, 校验误差：1.89, 准确率：0.39
# 第13周期，第(800/938)个撮，训练误差：1.88, 校验误差：1.87, 准确率：0.40
# 第13周期，第(900/938)个撮，训练误差：1.87, 校验误差：1.83, 准确率：0.38
# 第14周期，第(0/938)个撮，训练误差：1.42, 校验误差：1.84, 准确率：0.37
# 第14周期，第(100/938)个撮，训练误差：1.86, 校验误差：1.88, 准确率：0.39
# 第14周期，第(200/938)个撮，训练误差：1.87, 校验误差：1.89, 准确率：0.38
# 第14周期，第(300/938)个撮，训练误差：1.87, 校验误差：1.84, 准确率：0.39
# 第14周期，第(400/938)个撮，训练误差：1.86, 校验误差：1.88, 准确率：0.38
# 第14周期，第(500/938)个撮，训练误差：1.83, 校验误差：1.91, 准确率：0.40
# 第14周期，第(600/938)个撮，训练误差：1.84, 校验误差：1.82, 准确率：0.40
# 第14周期，第(700/938)个撮，训练误差：1.84, 校验误差：1.89, 准确率：0.39
# 第14周期，第(800/938)个撮，训练误差：1.83, 校验误差：1.81, 准确率：0.38
# 第14周期，第(900/938)个撮，训练误差：1.84, 校验误差：1.91, 准确率：0.39
# 第15周期，第(0/938)个撮，训练误差：2.26, 校验误差：1.79, 准确率：0.40
# 第15周期，第(100/938)个撮，训练误差：1.82, 校验误差：1.85, 准确率：0.39
# 第15周期，第(200/938)个撮，训练误差：1.82, 校验误差：1.78, 准确率：0.41
# 第15周期，第(300/938)个撮，训练误差：1.80, 校验误差：1.79, 准确率：0.40
# 第15周期，第(400/938)个撮，训练误差：1.79, 校验误差：1.80, 准确率：0.40
# 第15周期，第(500/938)个撮，训练误差：1.79, 校验误差：1.80, 准确率：0.41
# 第15周期，第(600/938)个撮，训练误差：1.77, 校验误差：1.75, 准确率：0.42
# 第15周期，第(700/938)个撮，训练误差：1.76, 校验误差：1.73, 准确率：0.40
# 第15周期，第(800/938)个撮，训练误差：1.75, 校验误差：1.92, 准确率：0.38
# 第15周期，第(900/938)个撮，训练误差：1.74, 校验误差：1.80, 准确率：0.41
# 第16周期，第(0/938)个撮，训练误差：2.12, 校验误差：1.80, 准确率：0.40
# 第16周期，第(100/938)个撮，训练误差：1.71, 校验误差：1.71, 准确率：0.40
# 第16周期，第(200/938)个撮，训练误差：1.70, 校验误差：1.79, 准确率：0.41
# 第16周期，第(300/938)个撮，训练误差：1.70, 校验误差：1.78, 准确率：0.41
# 第16周期，第(400/938)个撮，训练误差：1.70, 校验误差：1.76, 准确率：0.42
# 第16周期，第(500/938)个撮，训练误差：1.69, 校验误差：1.70, 准确率：0.41
# 第16周期，第(600/938)个撮，训练误差：1.70, 校验误差：1.72, 准确率：0.41
# 第16周期，第(700/938)个撮，训练误差：1.70, 校验误差：1.73, 准确率：0.42
# 第16周期，第(800/938)个撮，训练误差：1.69, 校验误差：1.69, 准确率：0.42
# 第16周期，第(900/938)个撮，训练误差：1.69, 校验误差：1.72, 准确率：0.40
# 第17周期，第(0/938)个撮，训练误差：1.28, 校验误差：1.72, 准确率：0.41
# 第17周期，第(100/938)个撮，训练误差：1.65, 校验误差：1.77, 准确率：0.41
# 第17周期，第(200/938)个撮，训练误差：1.65, 校验误差：1.68, 准确率：0.43
# 第17周期，第(300/938)个撮，训练误差：1.65, 校验误差：1.72, 准确率：0.40
# 第17周期，第(400/938)个撮，训练误差：1.63, 校验误差：1.70, 准确率：0.42
# 第17周期，第(500/938)个撮，训练误差：1.63, 校验误差：1.62, 准确率：0.43
# 第17周期，第(600/938)个撮，训练误差：1.64, 校验误差：1.70, 准确率：0.41
# 第17周期，第(700/938)个撮，训练误差：1.63, 校验误差：1.68, 准确率：0.42
# 第17周期，第(800/938)个撮，训练误差：1.63, 校验误差：1.70, 准确率：0.43
# 第17周期，第(900/938)个撮，训练误差：1.63, 校验误差：1.74, 准确率：0.44
# 第18周期，第(0/938)个撮，训练误差：1.50, 校验误差：1.67, 准确率：0.43
# 第18周期，第(100/938)个撮，训练误差：1.70, 校验误差：1.69, 准确率：0.44
# 第18周期，第(200/938)个撮，训练误差：1.67, 校验误差：1.70, 准确率：0.42
# 第18周期，第(300/938)个撮，训练误差：1.64, 校验误差：1.71, 准确率：0.43
# 第18周期，第(400/938)个撮，训练误差：1.62, 校验误差：1.75, 准确率：0.42
# 第18周期，第(500/938)个撮，训练误差：1.60, 校验误差：1.63, 准确率：0.43
# 第18周期，第(600/938)个撮，训练误差：1.60, 校验误差：1.75, 准确率：0.42
# 第18周期，第(700/938)个撮，训练误差：1.59, 校验误差：1.58, 准确率：0.44
# 第18周期，第(800/938)个撮，训练误差：1.59, 校验误差：1.62, 准确率：0.43
# 第18周期，第(900/938)个撮，训练误差：1.58, 校验误差：1.67, 准确率：0.42
# 第19周期，第(0/938)个撮，训练误差：1.75, 校验误差：1.61, 准确率：0.43
# 第19周期，第(100/938)个撮，训练误差：1.49, 校验误差：1.61, 准确率：0.44
# 第19周期，第(200/938)个撮，训练误差：1.51, 校验误差：1.72, 准确率：0.43
# 第19周期，第(300/938)个撮，训练误差：1.53, 校验误差：1.62, 准确率：0.45
# 第19周期，第(400/938)个撮，训练误差：1.52, 校验误差：1.61, 准确率：0.43
# 第19周期，第(500/938)个撮，训练误差：1.52, 校验误差：1.69, 准确率：0.45
# 第19周期，第(600/938)个撮，训练误差：1.52, 校验误差：1.63, 准确率：0.43
# 第19周期，第(700/938)个撮，训练误差：1.53, 校验误差：1.66, 准确率：0.45
# 第19周期，第(800/938)个撮，训练误差：1.53, 校验误差：1.56, 准确率：0.44
# 第19周期，第(900/938)个撮，训练误差：1.52, 校验误差：1.56, 准确率：0.45

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# 0.51200000000000001

# %% [markdown]
# ### 3.迁移，不更新权重
#
# 在这个试验中，我们首先将识别器的卷积层的权重全部迁移到了加法机的两个卷积部件中，但保持它们的权重不变，只允许后面的全链接层的权重可训练。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
net = Transfer()
# 迁移网络，并设置卷积部件的权重和偏置都不计算梯度
net.set_filter_values_nograd(original_net)
if use_cuda:
    net = net.cuda()
criterion = nn.MSELoss()

# 只将可更新的权重值加载到了优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad:
        new_parameters.append(para)
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 训练整个网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
        labels = y1 + y2
        labels = labels.type(dtype)
        loss = criterion(outputs, torch.tensor(labels, requires_grad = True))
        loss.backward()

        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                labels = y1 + y2
                loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
    labels = y1 + y2
    loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_fixed'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：85.57, 校验误差：93.10, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：22.04, 校验误差：8.43, 准确率：0.14
# 第0周期，第(200/938)个撮，训练误差：14.99, 校验误差：6.67, 准确率：0.15
# 第0周期，第(300/938)个撮，训练误差：12.34, 校验误差：6.29, 准确率：0.16
# 第0周期，第(400/938)个撮，训练误差：10.89, 校验误差：5.89, 准确率：0.16
# 第0周期，第(500/938)个撮，训练误差：9.95, 校验误差：5.45, 准确率：0.17
# 第0周期，第(600/938)个撮，训练误差：9.27, 校验误差：5.24, 准确率：0.17
# 第0周期，第(700/938)个撮，训练误差：8.74, 校验误差：4.94, 准确率：0.18
# 第0周期，第(800/938)个撮，训练误差：8.32, 校验误差：5.12, 准确率：0.19
# 第0周期，第(900/938)个撮，训练误差：7.99, 校验误差：4.84, 准确率：0.19
# 第1周期，第(0/938)个撮，训练误差：6.26, 校验误差：4.75, 准确率：0.21
# 第1周期，第(100/938)个撮，训练误差：4.99, 校验误差：4.88, 准确率：0.17
# 第1周期，第(200/938)个撮，训练误差：4.93, 校验误差：4.71, 准确率：0.22
# 第1周期，第(300/938)个撮，训练误差：4.96, 校验误差：5.02, 准确率：0.16
# 第1周期，第(400/938)个撮，训练误差：4.93, 校验误差：4.26, 准确率：0.20
# 第1周期，第(500/938)个撮，训练误差：4.86, 校验误差：4.07, 准确率：0.23
# 第1周期，第(600/938)个撮，训练误差：4.84, 校验误差：4.03, 准确率：0.23
# 第1周期，第(700/938)个撮，训练误差：4.76, 校验误差：4.14, 准确率：0.23
# 第1周期，第(800/938)个撮，训练误差：4.72, 校验误差：4.13, 准确率：0.23
# 第1周期，第(900/938)个撮，训练误差：4.67, 校验误差：3.82, 准确率：0.22
# 第2周期，第(0/938)个撮，训练误差：4.40, 校验误差：4.64, 准确率：0.17
# 第2周期，第(100/938)个撮，训练误差：4.15, 校验误差：3.88, 准确率：0.22
# 第2周期，第(200/938)个撮，训练误差：4.15, 校验误差：3.80, 准确率：0.24
# 第2周期，第(300/938)个撮，训练误差：4.14, 校验误差：3.98, 准确率：0.24
# 第2周期，第(400/938)个撮，训练误差：4.14, 校验误差：3.91, 准确率：0.22
# 第2周期，第(500/938)个撮，训练误差：4.10, 校验误差：3.64, 准确率：0.25
# 第2周期，第(600/938)个撮，训练误差：4.09, 校验误差：3.92, 准确率：0.24
# 第2周期，第(700/938)个撮，训练误差：4.09, 校验误差：3.60, 准确率：0.22
# 第2周期，第(800/938)个撮，训练误差：4.06, 校验误差：3.70, 准确率：0.22
# 第2周期，第(900/938)个撮，训练误差：4.04, 校验误差：3.50, 准确率：0.25
# 第3周期，第(0/938)个撮，训练误差：2.41, 校验误差：3.50, 准确率：0.26
# 第3周期，第(100/938)个撮，训练误差：3.75, 校验误差：3.32, 准确率：0.25
# 第3周期，第(200/938)个撮，训练误差：3.76, 校验误差：3.44, 准确率：0.27
# 第3周期，第(300/938)个撮，训练误差：3.71, 校验误差：3.43, 准确率：0.26
# 第3周期，第(400/938)个撮，训练误差：3.74, 校验误差：3.42, 准确率：0.24
# 第3周期，第(500/938)个撮，训练误差：3.71, 校验误差：3.50, 准确率：0.26
# 第3周期，第(600/938)个撮，训练误差：3.71, 校验误差：3.68, 准确率：0.26
# 第3周期，第(700/938)个撮，训练误差：3.70, 校验误差：3.59, 准确率：0.26
# 第3周期，第(800/938)个撮，训练误差：3.70, 校验误差：3.25, 准确率：0.26
# 第3周期，第(900/938)个撮，训练误差：3.69, 校验误差：3.24, 准确率：0.26
# 第4周期，第(0/938)个撮，训练误差：3.02, 校验误差：3.50, 准确率：0.26
# 第4周期，第(100/938)个撮，训练误差：3.39, 校验误差：3.13, 准确率：0.26
# 第4周期，第(200/938)个撮，训练误差：3.44, 校验误差：3.21, 准确率：0.26
# 第4周期，第(300/938)个撮，训练误差：3.44, 校验误差：3.32, 准确率：0.27
# 第4周期，第(400/938)个撮，训练误差：3.45, 校验误差：3.21, 准确率：0.27
# 第4周期，第(500/938)个撮，训练误差：3.43, 校验误差：3.01, 准确率：0.28
# 第4周期，第(600/938)个撮，训练误差：3.40, 校验误差：3.05, 准确率：0.27
# 第4周期，第(700/938)个撮，训练误差：3.39, 校验误差：3.07, 准确率：0.28
# 第4周期，第(800/938)个撮，训练误差：3.37, 校验误差：3.06, 准确率：0.26
# 第4周期，第(900/938)个撮，训练误差：3.38, 校验误差：3.24, 准确率：0.27
# 第5周期，第(0/938)个撮，训练误差：2.71, 校验误差：2.91, 准确率：0.27
# 第5周期，第(100/938)个撮，训练误差：3.18, 校验误差：2.87, 准确率：0.28
# 第5周期，第(200/938)个撮，训练误差：3.21, 校验误差：2.88, 准确率：0.28
# 第5周期，第(300/938)个撮，训练误差：3.20, 校验误差：3.08, 准确率：0.26
# 第5周期，第(400/938)个撮，训练误差：3.24, 校验误差：3.47, 准确率：0.27
# 第5周期，第(500/938)个撮，训练误差：3.26, 校验误差：3.28, 准确率：0.28
# 第5周期，第(600/938)个撮，训练误差：3.24, 校验误差：3.33, 准确率：0.27
# 第5周期，第(700/938)个撮，训练误差：3.24, 校验误差：2.88, 准确率：0.28
# 第5周期，第(800/938)个撮，训练误差：3.23, 校验误差：2.87, 准确率：0.28
# 第5周期，第(900/938)个撮，训练误差：3.22, 校验误差：3.08, 准确率：0.28
# 第6周期，第(0/938)个撮，训练误差：3.68, 校验误差：2.93, 准确率：0.28
# 第6周期，第(100/938)个撮，训练误差：3.16, 校验误差：2.95, 准确率：0.29
# 第6周期，第(200/938)个撮，训练误差：3.14, 校验误差：2.90, 准确率：0.29
# 第6周期，第(300/938)个撮，训练误差：3.13, 校验误差：2.96, 准确率：0.28
# 第6周期，第(400/938)个撮，训练误差：3.09, 校验误差：2.75, 准确率：0.30
# 第6周期，第(500/938)个撮，训练误差：3.07, 校验误差：2.81, 准确率：0.30
# 第6周期，第(600/938)个撮，训练误差：3.07, 校验误差：2.74, 准确率：0.30
# 第6周期，第(700/938)个撮，训练误差：3.05, 校验误差：2.69, 准确率：0.27
# 第6周期，第(800/938)个撮，训练误差：3.04, 校验误差：2.73, 准确率：0.28
# 第6周期，第(900/938)个撮，训练误差：3.04, 校验误差：3.44, 准确率：0.27
# 第7周期，第(0/938)个撮，训练误差：3.27, 校验误差：2.81, 准确率：0.30
# 第7周期，第(100/938)个撮，训练误差：2.90, 校验误差：3.28, 准确率：0.27
# 第7周期，第(200/938)个撮，训练误差：2.96, 校验误差：2.67, 准确率：0.30
# 第7周期，第(300/938)个撮，训练误差：2.94, 校验误差：2.82, 准确率：0.30
# 第7周期，第(400/938)个撮，训练误差：2.94, 校验误差：2.72, 准确率：0.30
# 第7周期，第(500/938)个撮，训练误差：2.93, 校验误差：2.63, 准确率：0.31
# 第7周期，第(600/938)个撮，训练误差：2.94, 校验误差：2.67, 准确率：0.29
# 第7周期，第(700/938)个撮，训练误差：2.95, 校验误差：2.67, 准确率：0.30
# 第7周期，第(800/938)个撮，训练误差：2.94, 校验误差：2.66, 准确率：0.30
# 第7周期，第(900/938)个撮，训练误差：2.93, 校验误差：2.70, 准确率：0.31
# 第8周期，第(0/938)个撮，训练误差：2.88, 校验误差：2.64, 准确率：0.31
# 第8周期，第(100/938)个撮，训练误差：2.75, 校验误差：2.71, 准确率：0.32
# 第8周期，第(200/938)个撮，训练误差：2.83, 校验误差：2.52, 准确率：0.30
# 第8周期，第(300/938)个撮，训练误差：2.82, 校验误差：2.55, 准确率：0.31
# 第8周期，第(400/938)个撮，训练误差：2.81, 校验误差：2.81, 准确率：0.30
# 第8周期，第(500/938)个撮，训练误差：2.81, 校验误差：2.45, 准确率：0.32
# 第8周期，第(600/938)个撮，训练误差：2.81, 校验误差：2.75, 准确率：0.31
# 第8周期，第(700/938)个撮，训练误差：2.79, 校验误差：2.60, 准确率：0.31
# 第8周期，第(800/938)个撮，训练误差：2.78, 校验误差：2.56, 准确率：0.32
# 第8周期，第(900/938)个撮，训练误差：2.77, 校验误差：2.65, 准确率：0.31
# 第9周期，第(0/938)个撮，训练误差：2.43, 校验误差：2.51, 准确率：0.32
# 第9周期，第(100/938)个撮，训练误差：2.70, 校验误差：2.56, 准确率：0.30
# 第9周期，第(200/938)个撮，训练误差：2.72, 校验误差：2.46, 准确率：0.33
# 第9周期，第(300/938)个撮，训练误差：2.72, 校验误差：2.48, 准确率：0.30
# 第9周期，第(400/938)个撮，训练误差：2.70, 校验误差：2.43, 准确率：0.32
# 第9周期，第(500/938)个撮，训练误差：2.68, 校验误差：2.45, 准确率：0.31
# 第9周期，第(600/938)个撮，训练误差：2.67, 校验误差：2.55, 准确率：0.32
# 第9周期，第(700/938)个撮，训练误差：2.66, 校验误差：2.43, 准确率：0.32
# 第9周期，第(800/938)个撮，训练误差：2.66, 校验误差：2.61, 准确率：0.32
# 第9周期，第(900/938)个撮，训练误差：2.64, 校验误差：2.35, 准确率：0.32
# 第10周期，第(0/938)个撮，训练误差：1.63, 校验误差：2.37, 准确率：0.31
# 第10周期，第(100/938)个撮，训练误差：2.47, 校验误差：2.51, 准确率：0.34
# 第10周期，第(200/938)个撮，训练误差：2.54, 校验误差：2.71, 准确率：0.30
# 第10周期，第(300/938)个撮，训练误差：2.55, 校验误差：2.54, 准确率：0.31
# 第10周期，第(400/938)个撮，训练误差：2.55, 校验误差：2.77, 准确率：0.32
# 第10周期，第(500/938)个撮，训练误差：2.54, 校验误差：2.42, 准确率：0.32
# 第10周期，第(600/938)个撮，训练误差：2.55, 校验误差：2.38, 准确率：0.34
# 第10周期，第(700/938)个撮，训练误差：2.54, 校验误差：2.31, 准确率：0.34
# 第10周期，第(800/938)个撮，训练误差：2.53, 校验误差：2.44, 准确率：0.33
# 第10周期，第(900/938)个撮，训练误差：2.53, 校验误差：2.32, 准确率：0.33
# 第11周期，第(0/938)个撮，训练误差：2.35, 校验误差：2.25, 准确率：0.33
# 第11周期，第(100/938)个撮，训练误差：2.44, 校验误差：2.29, 准确率：0.35
# 第11周期，第(200/938)个撮，训练误差：2.42, 校验误差：2.51, 准确率：0.34
# 第11周期，第(300/938)个撮，训练误差：2.43, 校验误差：2.29, 准确率：0.35
# 第11周期，第(400/938)个撮，训练误差：2.43, 校验误差：2.23, 准确率：0.33
# 第11周期，第(500/938)个撮，训练误差：2.43, 校验误差：2.34, 准确率：0.34
# 第11周期，第(600/938)个撮，训练误差：2.43, 校验误差：2.16, 准确率：0.35
# 第11周期，第(700/938)个撮，训练误差：2.41, 校验误差：2.21, 准确率：0.33
# 第11周期，第(800/938)个撮，训练误差：2.41, 校验误差：2.48, 准确率：0.29
# 第11周期，第(900/938)个撮，训练误差：2.42, 校验误差：2.33, 准确率：0.36
# 第12周期，第(0/938)个撮，训练误差：5.03, 校验误差：2.70, 准确率：0.32
# 第12周期，第(100/938)个撮，训练误差：2.36, 校验误差：2.29, 准确率：0.36
# 第12周期，第(200/938)个撮，训练误差：2.33, 校验误差：2.34, 准确率：0.35
# 第12周期，第(300/938)个撮，训练误差：2.34, 校验误差：2.16, 准确率：0.35
# 第12周期，第(400/938)个撮，训练误差：2.33, 校验误差：2.31, 准确率：0.35
# 第12周期，第(500/938)个撮，训练误差：2.33, 校验误差：2.15, 准确率：0.35
# 第12周期，第(600/938)个撮，训练误差：2.33, 校验误差：2.48, 准确率：0.35
# 第12周期，第(700/938)个撮，训练误差：2.33, 校验误差：2.21, 准确率：0.36
# 第12周期，第(800/938)个撮，训练误差：2.32, 校验误差：2.08, 准确率：0.37
# 第12周期，第(900/938)个撮，训练误差：2.31, 校验误差：2.25, 准确率：0.37
# 第13周期，第(0/938)个撮，训练误差：2.60, 校验误差：2.23, 准确率：0.35
# 第13周期，第(100/938)个撮，训练误差：2.24, 校验误差：2.16, 准确率：0.36
# 第13周期，第(200/938)个撮，训练误差：2.22, 校验误差：2.08, 准确率：0.37
# 第13周期，第(300/938)个撮，训练误差：2.23, 校验误差：2.10, 准确率：0.36
# 第13周期，第(400/938)个撮，训练误差：2.23, 校验误差：2.18, 准确率：0.35
# 第13周期，第(500/938)个撮，训练误差：2.22, 校验误差：2.27, 准确率：0.35
# 第13周期，第(600/938)个撮，训练误差：2.21, 校验误差：2.25, 准确率：0.35
# 第13周期，第(700/938)个撮，训练误差：2.23, 校验误差：2.09, 准确率：0.36
# 第13周期，第(800/938)个撮，训练误差：2.22, 校验误差：2.06, 准确率：0.38
# 第13周期，第(900/938)个撮，训练误差：2.21, 校验误差：2.04, 准确率：0.37
# 第14周期，第(0/938)个撮，训练误差：1.65, 校验误差：2.24, 准确率：0.36
# 第14周期，第(100/938)个撮，训练误差：2.02, 校验误差：2.25, 准确率：0.37
# 第14周期，第(200/938)个撮，训练误差：2.02, 校验误差：2.05, 准确率：0.38
# 第14周期，第(300/938)个撮，训练误差：2.05, 校验误差：2.01, 准确率：0.36
# 第14周期，第(400/938)个撮，训练误差：2.05, 校验误差：1.92, 准确率：0.36
# 第14周期，第(500/938)个撮，训练误差：2.08, 校验误差：2.00, 准确率：0.39
# 第14周期，第(600/938)个撮，训练误差：2.09, 校验误差：1.92, 准确率：0.37
# 第14周期，第(700/938)个撮，训练误差：2.10, 校验误差：1.99, 准确率：0.36
# 第14周期，第(800/938)个撮，训练误差：2.09, 校验误差：2.06, 准确率：0.37
# 第14周期，第(900/938)个撮，训练误差：2.09, 校验误差：2.03, 准确率：0.38
# 第15周期，第(0/938)个撮，训练误差：1.67, 校验误差：2.12, 准确率：0.37
# 第15周期，第(100/938)个撮，训练误差：2.10, 校验误差：2.01, 准确率：0.39
# 第15周期，第(200/938)个撮，训练误差：2.11, 校验误差：2.06, 准确率：0.39
# 第15周期，第(300/938)个撮，训练误差：2.08, 校验误差：1.95, 准确率：0.38
# 第15周期，第(400/938)个撮，训练误差：2.04, 校验误差：1.95, 准确率：0.39
# 第15周期，第(500/938)个撮，训练误差：2.03, 校验误差：1.94, 准确率：0.39
# 第15周期，第(600/938)个撮，训练误差：2.04, 校验误差：1.91, 准确率：0.39
# 第15周期，第(700/938)个撮，训练误差：2.03, 校验误差：1.88, 准确率：0.39
# 第15周期，第(800/938)个撮，训练误差：2.01, 校验误差：1.84, 准确率：0.38
# 第15周期，第(900/938)个撮，训练误差：2.01, 校验误差：1.95, 准确率：0.41
# 第16周期，第(0/938)个撮，训练误差：1.56, 校验误差：1.95, 准确率：0.40
# 第16周期，第(100/938)个撮，训练误差：1.94, 校验误差：1.84, 准确率：0.41
# 第16周期，第(200/938)个撮，训练误差：1.91, 校验误差：1.86, 准确率：0.39
# 第16周期，第(300/938)个撮，训练误差：1.89, 校验误差：1.85, 准确率：0.39
# 第16周期，第(400/938)个撮，训练误差：1.88, 校验误差：1.84, 准确率：0.41
# 第16周期，第(500/938)个撮，训练误差：1.90, 校验误差：1.83, 准确率：0.40
# 第16周期，第(600/938)个撮，训练误差：1.90, 校验误差：1.91, 准确率：0.40
# 第16周期，第(700/938)个撮，训练误差：1.91, 校验误差：1.93, 准确率：0.39
# 第16周期，第(800/938)个撮，训练误差：1.90, 校验误差：1.84, 准确率：0.39
# 第16周期，第(900/938)个撮，训练误差：1.89, 校验误差：1.95, 准确率：0.40
# 第17周期，第(0/938)个撮，训练误差：1.67, 校验误差：1.85, 准确率：0.41
# 第17周期，第(100/938)个撮，训练误差：1.80, 校验误差：1.88, 准确率：0.42
# 第17周期，第(200/938)个撮，训练误差：1.86, 校验误差：1.77, 准确率：0.41
# 第17周期，第(300/938)个撮，训练误差：1.83, 校验误差：1.80, 准确率：0.40
# 第17周期，第(400/938)个撮，训练误差：1.83, 校验误差：1.77, 准确率：0.42
# 第17周期，第(500/938)个撮，训练误差：1.82, 校验误差：1.84, 准确率：0.43
# 第17周期，第(600/938)个撮，训练误差：1.81, 校验误差：1.78, 准确率：0.42
# 第17周期，第(700/938)个撮，训练误差：1.81, 校验误差：2.12, 准确率：0.39
# 第17周期，第(800/938)个撮，训练误差：1.81, 校验误差：1.80, 准确率：0.44
# 第17周期，第(900/938)个撮，训练误差：1.80, 校验误差：1.78, 准确率：0.44
# 第18周期，第(0/938)个撮，训练误差：2.46, 校验误差：1.86, 准确率：0.42
# 第18周期，第(100/938)个撮，训练误差：1.69, 校验误差：1.85, 准确率：0.42
# 第18周期，第(200/938)个撮，训练误差：1.70, 校验误差：1.70, 准确率：0.43
# 第18周期，第(300/938)个撮，训练误差：1.69, 校验误差：1.70, 准确率：0.44
# 第18周期，第(400/938)个撮，训练误差：1.72, 校验误差：1.70, 准确率：0.42
# 第18周期，第(500/938)个撮，训练误差：1.72, 校验误差：1.76, 准确率：0.45
# 第18周期，第(600/938)个撮，训练误差：1.72, 校验误差：1.78, 准确率：0.42
# 第18周期，第(700/938)个撮，训练误差：1.72, 校验误差：1.60, 准确率：0.44
# 第18周期，第(800/938)个撮，训练误差：1.72, 校验误差：1.76, 准确率：0.45
# 第18周期，第(900/938)个撮，训练误差：1.72, 校验误差：1.62, 准确率：0.46
# 第19周期，第(0/938)个撮，训练误差：1.05, 校验误差：1.66, 准确率：0.44
# 第19周期，第(100/938)个撮，训练误差：1.64, 校验误差：1.65, 准确率：0.46
# 第19周期，第(200/938)个撮，训练误差：1.68, 校验误差：1.75, 准确率：0.43
# 第19周期，第(300/938)个撮，训练误差：1.67, 校验误差：1.65, 准确率：0.47
# 第19周期，第(400/938)个撮，训练误差：1.65, 校验误差：1.83, 准确率：0.44
# 第19周期，第(500/938)个撮，训练误差：1.64, 校验误差：1.73, 准确率：0.46
# 第19周期，第(600/938)个撮，训练误差：1.65, 校验误差：1.60, 准确率：0.46
# 第19周期，第(700/938)个撮，训练误差：1.64, 校验误差：1.61, 准确率：0.46
# 第19周期，第(800/938)个撮，训练误差：1.63, 校验误差：1.56, 准确率：0.47
# 第19周期，第(900/938)个撮，训练误差：1.63, 校验误差：1.56, 准确率：0.48

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# 0.55840000000000001

# %% [markdown]
# ### 4、结果比较
# 将三次实验的结果放到一起比较

# %%
y1, y2, y3 = results['notransfer'][0], results['transfer_pretrained'][0], results['transfer_fixed'][0]

# %%
plt.figure(figsize = (10, 7))
plt.plot([1 - i[2] for i in y1], 'o-', label = 'no transfer')
plt.plot([1 - i[2] for i in y2], 's:', label = 'transfer pretrained')
plt.plot([1 - i[2] for i in y3], '*-', label = 'transfer fixed')
plt.xlabel('Time')
plt.ylabel('Error Rate')
plt.legend()

# %%
results['notransfer'][1], results['transfer_pretrained'][1], results['transfer_fixed'][1]
# Out:
# (0.1372, 0.2068, 0.2176)

# %%
experiments[1] = results

# %%
experiments = {}

# %%
experiments
# Out:
# {5: {'notransfer': [[[91.075851, 95.011086, 0.010999999999999999],
#     [29.263935, 14.003339, 0.1048],
#     [5.9165063, 6.9512377, 0.13980000000000001],
#     [5.5572705, 5.6395063, 0.1736],
#     [3.7584455, 4.6317644, 0.186],
#     [3.8719845, 4.8482666, 0.1956],
#     [3.0421855, 3.8019702, 0.23580000000000001],
#     [3.0747514, 4.2824497, 0.22259999999999999],
#     [3.4442763, 3.2306721, 0.26579999999999998],
#     [2.6466277, 3.5458572, 0.25059999999999999],
#     [3.6584589, 3.0269597, 0.26400000000000001],
#     [2.2583501, 2.8223431, 0.29039999999999999],
#     [2.6701357, 2.913733, 0.29499999999999998],
#     [2.1112831, 2.8725371, 0.24679999999999999],
#     [1.1362149, 2.5071428, 0.31659999999999999],
#     [1.8418362, 2.8013926, 0.27839999999999998],
#     [1.2708039, 2.3316662, 0.3352],
#     [1.6148721, 2.2326846, 0.35720000000000002],
#     [1.5539746, 2.3981738, 0.31859999999999999],
#     [1.6921473, 2.9743233, 0.2848],
#     [1.0975914, 2.5193799, 0.32900000000000001],
#     [1.4771911, 2.0810149, 0.35060000000000002],
#     [1.4211178, 2.0518606, 0.37619999999999998],
#     [1.3788434, 2.0384905, 0.36199999999999999],
#     [1.9869839, 1.9572468, 0.35720000000000002],
#     [1.4397509, 2.1565359, 0.36940000000000001],
#     [1.3871247, 1.9236422, 0.36499999999999999],
#     [1.3441378, 1.9503607, 0.38879999999999998],
#     [1.6075765, 1.9316425, 0.38400000000000001],
#     [1.2318102, 1.8461806, 0.3926],
#     [1.7732345, 2.037518, 0.38479999999999998],
#     [1.2476332, 1.8421102, 0.4022],
#     [1.0129876, 1.8866107, 0.39560000000000001],
#     [1.1408457, 1.7943457, 0.41699999999999998],
#     [1.0196079, 1.9540739, 0.39500000000000002],
#     [1.1609432, 1.7005852, 0.432],
#     [0.59440333, 1.7076204, 0.3916],
#     [0.98482448, 1.7720561, 0.42459999999999998],
#     [1.313911, 1.7071475, 0.42680000000000001],
#     [0.97204483, 1.6277626, 0.432]],
#    0.75],
#   'transfer_differable': [[[102.74642, 92.382515, 0.0080000000000000002],
#     [14.482413, 6.3729343, 0.16220000000000001],
#     [4.411808, 5.0141087, 0.20100000000000001],
#     [4.2236996, 4.4758177, 0.2026],
#     [4.7481141, 4.2149978, 0.22439999999999999],
#     [3.363364, 4.4879475, 0.17319999999999999],
#     [2.1751194, 4.0168867, 0.22500000000000001],
#     [2.9389324, 3.2998502, 0.25259999999999999],
#     [2.3567812, 3.3658123, 0.2278],
#     [2.6370387, 3.0764766, 0.26219999999999999],
#     [2.6883557, 3.2987664, 0.23799999999999999],
#     [2.390631, 3.069031, 0.2742],
#     [2.919997, 3.0150497, 0.255],
#     [2.4093106, 2.9361167, 0.26079999999999998],
#     [2.3573902, 3.4025986, 0.23599999999999999],
#     [2.2257071, 2.7432377, 0.2858],
#     [1.4331822, 2.9926374, 0.2586],
#     [2.0609684, 2.716711, 0.29139999999999999],
#     [1.550662, 2.6250491, 0.29980000000000001],
#     [1.9621058, 2.7728119, 0.30099999999999999],
#     [2.2906499, 3.0597804, 0.2888],
#     [1.7853717, 3.0207219, 0.24460000000000001],
#     [1.6429906, 2.4031804, 0.32379999999999998],
#     [1.7856938, 2.7554176, 0.32040000000000002],
#     [2.3522155, 2.4386902, 0.32119999999999999],
#     [1.7072138, 2.4914508, 0.28760000000000002],
#     [1.3416719, 2.468621, 0.33660000000000001],
#     [1.6415582, 2.2808757, 0.3402],
#     [1.3943104, 2.3626518, 0.30859999999999999],
#     [1.531921, 2.2239509, 0.34139999999999998],
#     [0.91014427, 2.2963307, 0.31719999999999998],
#     [1.5071282, 2.5936108, 0.27760000000000001],
#     [1.2029808, 2.2767563, 0.31080000000000002],
#     [1.5129544, 2.2659962, 0.34060000000000001],
#     [0.94313109, 2.1893001, 0.34860000000000002],
#     [1.4631429, 2.0879817, 0.35599999999999998],
#     [1.153671, 2.2219467, 0.33439999999999998],
#     [1.3418405, 2.143712, 0.36320000000000002],
#     [1.2488406, 2.0985193, 0.35539999999999999],
#     [1.2800888, 2.0076256, 0.379]],
#    0.5],
#   'transfer_nograd': [[[0.9521991, 2.1491826, 0.36159999999999998],
#     [1.2711939, 2.048233, 0.34699999999999998],
#     [1.0736786, 2.0849311, 0.35220000000000001],
#     [1.2650765, 2.0393331, 0.38319999999999999],
#     [0.74931347, 2.146842, 0.36120000000000002],
#     [1.147347, 1.973333, 0.37959999999999999],
#     [1.0105399, 2.1021585, 0.36780000000000002],
#     [1.1332873, 2.0248804, 0.38979999999999998],
#     [1.0148705, 2.0031612, 0.36820000000000003],
#     [1.1244974, 1.9919788, 0.39600000000000002],
#     [1.3225309, 1.9743625, 0.372],
#     [1.0862429, 1.9477898, 0.38779999999999998],
#     [0.97981781, 2.0869424, 0.39200000000000002],
#     [1.0765631, 1.9552587, 0.40679999999999999],
#     [0.96759707, 1.8669266, 0.41260000000000002],
#     [1.0227262, 1.9114078, 0.38159999999999999],
#     [1.1477708, 1.9615674, 0.41139999999999999],
#     [1.0100002, 1.8714886, 0.38379999999999997],
#     [1.3030989, 1.8929625, 0.3856],
#     [1.0038378, 1.9153054, 0.3906],
#     [0.77140903, 1.9225309, 0.4002],
#     [0.93004215, 1.8835552, 0.41299999999999998],
#     [1.1363378, 1.7771868, 0.39439999999999997],
#     [0.9468537, 1.740329, 0.42420000000000002],
#     [1.1465719, 1.8243455, 0.4168],
#     [0.88828778, 1.7999897, 0.39779999999999999],
#     [0.85482132, 1.7882849, 0.40920000000000001],
#     [0.86513919, 1.7533237, 0.42380000000000001],
#     [1.2859159, 1.7217125, 0.4264],
#     [0.85477668, 1.8475914, 0.434],
#     [0.65513468, 1.6739546, 0.43719999999999998],
#     [0.83023995, 1.7904582, 0.43759999999999999],
#     [0.78787607, 1.6785151, 0.4294],
#     [0.80143702, 1.8088707, 0.42259999999999998],
#     [1.2105415, 1.8418062, 0.37819999999999998],
#     [0.829099, 1.7227485, 0.40820000000000001],
#     [0.66086382, 1.7678678, 0.41820000000000002],
#     [0.7347554, 1.7536262, 0.43780000000000002],
#     [0.61475199, 1.6515565, 0.44679999999999997],
#     [0.78986436, 1.6820275, 0.43180000000000002]],
#    0.5]}}

# %% [markdown]
# ## 综合试验
#
# 为了系统化的比较不同的参数对迁移学习的影响，我们做了一次大实验：
#
# 该试验包括了三重循环，分别是：
#
# 1、不同的迁移学习方法：无迁移、迁移固定权重、迁移预训练
#
# 2、每一个参数下重复实验times次
#
# 3、加载不同的数据集比例fraction
#
# 由于本试验需要消耗大量的计算时间，所以请慎重执行下面的语句。本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码

# %%
results = {} #记载实验结果
times = 10 # 每一组参数下实验都要被重复10次
fractions = [20, 10, 8, 6, 5, 4, 3, 2, 1] #所有的数据加载的比例值
for experiment in ['no transfer', 'transfer_fixed', 'transfer_pretrained']:
    for time in range(times):
        for fraction in fractions:
            
            # 分不同的迁移学习情况加载网络和优化器
            if experiment == 'no transfer':
                net = Transfer()
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
            if experiment == 'transfer_pretrained':
                net = Transfer()
                net.set_filter_values(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
            if experiment == 'transfer_fixed':
                net = Transfer()
                net.set_filter_values_nograd(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
                
            #开始迁移学习训练
            num_epochs = 20
            records = []
            for epoch in range(num_epochs):
                losses = []
                for idx, data in enumerate(zip(train_loader1, train_loader2)):
                    if idx >= (len(train_loader1) // fraction):
                        break
                    ((x1, y1), (x2, y2)) = data
                    if use_cuda:
                        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                    net.train()
                    optimizer.zero_grad()
                    outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                    labels = y1 + y2
                    loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
                    loss.backward()
                    optimizer.step()
                    loss = loss.cpu() if use_cuda else loss
                    losses.append(loss.data.numpy())
                    if idx % 500 == 0:
                        val_losses = []
                        rights = []
                        net.eval()
                        for val_data in zip(val_loader1, val_loader2):
                            ((x1, y1), (x2, y2)) = val_data
                            if use_cuda:
                                x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                            outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                            labels = y1 + y2
                            loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
                            loss = loss.cpu() if use_cuda else loss
                            val_losses.append(loss.data.numpy())
                            right = rightness(outputs.data, labels)
                            rights.append(right)
                        right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
                        print('{}网络：第{}试验，比例{}, 第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'
                              .format(experiment,time,fraction,
                            epoch, idx, len(train_loader1),
                            np.mean(losses), np.mean(val_losses), right_ratio))
                        records.append([np.mean(losses), np.mean(val_losses), right_ratio])
            rights = []
            net.eval()
            for test_data in zip(test_loader1, test_loader2):
                ((x1, y1), (x2, y2)) = test_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(torch.tensor(x1, requires_grad = True), torch.tensor(x2, requires_grad = True))
                labels = y1 + y2
                loss = criterion(outputs, torch.tensor(labels.type(dtype), requires_grad = True))
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0] for i in rights]) / np.sum([i[1] for i in rights])
            print(experiment,time,fraction)
            
            #将结果记录在了results集合之中，records记载了每一个打印周期的训练集损失函数、校验集损失函数、校验集正确率，
            #right_ratio记录了每次实验测试集的准确度
            results[(experiment,time,fraction)] = [records, right_ratio]
# Out:
# no transfer网络：第0试验，比例20, 第0周期，第(0/938)个撮，训练误差：97.90, 校验误差：100.24, 准确率：0.01
# no transfer网络：第0试验，比例20, 第1周期，第(0/938)个撮，训练误差：79.89, 校验误差：82.31, 准确率：0.02
# no transfer网络：第0试验，比例20, 第2周期，第(0/938)个撮，训练误差：21.09, 校验误差：17.64, 准确率：0.08
# no transfer网络：第0试验，比例20, 第3周期，第(0/938)个撮，训练误差：15.29, 校验误差：16.56, 准确率：0.08
# no transfer网络：第0试验，比例20, 第4周期，第(0/938)个撮，训练误差：14.40, 校验误差：15.44, 准确率：0.11
# no transfer网络：第0试验，比例20, 第5周期，第(0/938)个撮，训练误差：15.61, 校验误差：15.27, 准确率：0.12
# no transfer网络：第0试验，比例20, 第6周期，第(0/938)个撮，训练误差：14.19, 校验误差：15.18, 准确率：0.10
# no transfer网络：第0试验，比例20, 第7周期，第(0/938)个撮，训练误差：13.32, 校验误差：14.14, 准确率：0.11
# no transfer网络：第0试验，比例20, 第8周期，第(0/938)个撮，训练误差：16.55, 校验误差：12.73, 准确率：0.11
# no transfer网络：第0试验，比例20, 第9周期，第(0/938)个撮，训练误差：11.30, 校验误差：10.44, 准确率：0.11
# no transfer网络：第0试验，比例20, 第10周期，第(0/938)个撮，训练误差：10.97, 校验误差：9.13, 准确率：0.13
# no transfer网络：第0试验，比例20, 第11周期，第(0/938)个撮，训练误差：11.28, 校验误差：9.01, 准确率：0.13
# no transfer网络：第0试验，比例20, 第12周期，第(0/938)个撮，训练误差：8.85, 校验误差：8.41, 准确率：0.13
# no transfer网络：第0试验，比例20, 第13周期，第(0/938)个撮，训练误差：7.00, 校验误差：8.89, 准确率：0.12
# no transfer网络：第0试验，比例20, 第14周期，第(0/938)个撮，训练误差：6.85, 校验误差：8.03, 准确率：0.13
# no transfer网络：第0试验，比例20, 第15周期，第(0/938)个撮，训练误差：12.62, 校验误差：7.85, 准确率：0.14
# no transfer网络：第0试验，比例20, 第16周期，第(0/938)个撮，训练误差：7.42, 校验误差：7.84, 准确率：0.13
# no transfer网络：第0试验，比例20, 第17周期，第(0/938)个撮，训练误差：10.51, 校验误差：7.48, 准确率：0.14
# no transfer网络：第0试验，比例20, 第18周期，第(0/938)个撮，训练误差：6.08, 校验误差：7.42, 准确率：0.14
# no transfer网络：第0试验，比例20, 第19周期，第(0/938)个撮，训练误差：7.44, 校验误差：7.10, 准确率：0.14
# no transfer 0 20
# no transfer网络：第0试验，比例10, 第0周期，第(0/938)个撮，训练误差：108.66, 校验误差：96.53, 准确率：0.01
# no transfer网络：第0试验，比例10, 第1周期，第(0/938)个撮，训练误差：15.58, 校验误差：18.60, 准确率：0.09
# no transfer网络：第0试验，比例10, 第2周期，第(0/938)个撮，训练误差：16.06, 校验误差：14.90, 准确率：0.10
# no transfer网络：第0试验，比例10, 第3周期，第(0/938)个撮，训练误差：15.24, 校验误差：13.55, 准确率：0.10
# no transfer网络：第0试验，比例10, 第4周期，第(0/938)个撮，训练误差：10.21, 校验误差：12.26, 准确率：0.10
# no transfer网络：第0试验，比例10, 第5周期，第(0/938)个撮，训练误差：8.40, 校验误差：11.43, 准确率：0.11
# no transfer网络：第0试验，比例10, 第6周期，第(0/938)个撮，训练误差：6.58, 校验误差：8.73, 准确率：0.14
# no transfer网络：第0试验，比例10, 第7周期，第(0/938)个撮，训练误差：7.71, 校验误差：7.85, 准确率：0.14
# no transfer网络：第0试验，比例10, 第8周期，第(0/938)个撮，训练误差：8.25, 校验误差：6.96, 准确率：0.14
# no transfer网络：第0试验，比例10, 第9周期，第(0/938)个撮，训练误差：5.80, 校验误差：6.53, 准确率：0.16
# no transfer网络：第0试验，比例10, 第10周期，第(0/938)个撮，训练误差：4.92, 校验误差：6.01, 准确率：0.17
# no transfer网络：第0试验，比例10, 第11周期，第(0/938)个撮，训练误差：7.21, 校验误差：5.95, 准确率：0.16
# no transfer网络：第0试验，比例10, 第12周期，第(0/938)个撮，训练误差：5.83, 校验误差：5.47, 准确率：0.17
# no transfer网络：第0试验，比例10, 第13周期，第(0/938)个撮，训练误差：5.27, 校验误差：5.42, 准确率：0.17
# no transfer网络：第0试验，比例10, 第14周期，第(0/938)个撮，训练误差：5.54, 校验误差：5.39, 准确率：0.17
# no transfer网络：第0试验，比例10, 第15周期，第(0/938)个撮，训练误差：5.09, 校验误差：5.54, 准确率：0.18
# no transfer网络：第0试验，比例10, 第16周期，第(0/938)个撮，训练误差：5.10, 校验误差：4.79, 准确率：0.19
# no transfer网络：第0试验，比例10, 第17周期，第(0/938)个撮，训练误差：3.59, 校验误差：4.74, 准确率：0.19
# no transfer网络：第0试验，比例10, 第18周期，第(0/938)个撮，训练误差：4.63, 校验误差：4.69, 准确率：0.20
# no transfer网络：第0试验，比例10, 第19周期，第(0/938)个撮，训练误差：4.39, 校验误差：4.67, 准确率：0.19
# no transfer 0 10
# no transfer网络：第0试验，比例8, 第0周期，第(0/938)个撮，训练误差：90.09, 校验误差：99.33, 准确率：0.01
# no transfer网络：第0试验，比例8, 第1周期，第(0/938)个撮，训练误差：17.80, 校验误差：16.37, 准确率：0.10
# no transfer网络：第0试验，比例8, 第2周期，第(0/938)个撮，训练误差：16.85, 校验误差：15.40, 准确率：0.10
# no transfer网络：第0试验，比例8, 第3周期，第(0/938)个撮，训练误差：11.57, 校验误差：11.01, 准确率：0.12
# no transfer网络：第0试验，比例8, 第4周期，第(0/938)个撮，训练误差：8.06, 校验误差：8.83, 准确率：0.13
# no transfer网络：第0试验，比例8, 第5周期，第(0/938)个撮，训练误差：9.12, 校验误差：7.75, 准确率：0.14
# no transfer网络：第0试验，比例8, 第6周期，第(0/938)个撮，训练误差：8.76, 校验误差：6.94, 准确率：0.15
# no transfer网络：第0试验，比例8, 第7周期，第(0/938)个撮，训练误差：5.73, 校验误差：6.17, 准确率：0.16
# no transfer网络：第0试验，比例8, 第8周期，第(0/938)个撮，训练误差：6.82, 校验误差：5.64, 准确率：0.17
# no transfer网络：第0试验，比例8, 第9周期，第(0/938)个撮，训练误差：3.98, 校验误差：5.93, 准确率：0.16
# no transfer网络：第0试验，比例8, 第10周期，第(0/938)个撮，训练误差：4.90, 校验误差：4.94, 准确率：0.19
# no transfer网络：第0试验，比例8, 第11周期，第(0/938)个撮，训练误差：5.02, 校验误差：5.05, 准确率：0.19
# no transfer网络：第0试验，比例8, 第12周期，第(0/938)个撮，训练误差：4.85, 校验误差：4.76, 准确率：0.19
# no transfer网络：第0试验，比例8, 第13周期，第(0/938)个撮，训练误差：3.57, 校验误差：4.42, 准确率：0.19
# no transfer网络：第0试验，比例8, 第14周期，第(0/938)个撮，训练误差：4.29, 校验误差：4.53, 准确率：0.20
# no transfer网络：第0试验，比例8, 第15周期，第(0/938)个撮，训练误差：3.26, 校验误差：4.23, 准确率：0.20
# no transfer网络：第0试验，比例8, 第16周期，第(0/938)个撮，训练误差：3.92, 校验误差：4.07, 准确率：0.20
# no transfer网络：第0试验，比例8, 第17周期，第(0/938)个撮，训练误差：5.26, 校验误差：4.02, 准确率：0.22
# no transfer网络：第0试验，比例8, 第18周期，第(0/938)个撮，训练误差：3.45, 校验误差：3.82, 准确率：0.23
# no transfer网络：第0试验，比例8, 第19周期，第(0/938)个撮，训练误差：3.58, 校验误差：3.92, 准确率：0.20
# no transfer 0 8
# no transfer网络：第0试验，比例6, 第0周期，第(0/938)个撮，训练误差：100.07, 校验误差：90.78, 准确率：0.01
# no transfer网络：第0试验，比例6, 第1周期，第(0/938)个撮，训练误差：17.35, 校验误差：17.32, 准确率：0.09
# no transfer网络：第0试验，比例6, 第2周期，第(0/938)个撮，训练误差：13.61, 校验误差：15.86, 准确率：0.09
# no transfer网络：第0试验，比例6, 第3周期，第(0/938)个撮，训练误差：15.84, 校验误差：13.08, 准确率：0.10
# no transfer网络：第0试验，比例6, 第4周期，第(0/938)个撮，训练误差：8.47, 校验误差：9.65, 准确率：0.12
# no transfer网络：第0试验，比例6, 第5周期，第(0/938)个撮，训练误差：8.18, 校验误差：8.19, 准确率：0.14
# no transfer网络：第0试验，比例6, 第6周期，第(0/938)个撮，训练误差：7.52, 校验误差：6.79, 准确率：0.14
# no transfer网络：第0试验，比例6, 第7周期，第(0/938)个撮，训练误差：7.94, 校验误差：6.01, 准确率：0.15
# no transfer网络：第0试验，比例6, 第8周期，第(0/938)个撮，训练误差：4.58, 校验误差：5.39, 准确率：0.17
# no transfer网络：第0试验，比例6, 第9周期，第(0/938)个撮，训练误差：4.49, 校验误差：5.02, 准确率：0.19
# no transfer网络：第0试验，比例6, 第10周期，第(0/938)个撮，训练误差：4.58, 校验误差：4.57, 准确率：0.18
# no transfer网络：第0试验，比例6, 第11周期，第(0/938)个撮，训练误差：4.87, 校验误差：4.39, 准确率：0.18
# no transfer网络：第0试验，比例6, 第12周期，第(0/938)个撮，训练误差：4.49, 校验误差：4.83, 准确率：0.20
# no transfer网络：第0试验，比例6, 第13周期，第(0/938)个撮，训练误差：3.47, 校验误差：4.30, 准确率：0.21
# no transfer网络：第0试验，比例6, 第14周期，第(0/938)个撮，训练误差：3.25, 校验误差：3.97, 准确率：0.21
# no transfer网络：第0试验，比例6, 第15周期，第(0/938)个撮，训练误差：4.04, 校验误差：3.84, 准确率：0.21
# no transfer网络：第0试验，比例6, 第16周期，第(0/938)个撮，训练误差：3.79, 校验误差：3.82, 准确率：0.20
# no transfer网络：第0试验，比例6, 第17周期，第(0/938)个撮，训练误差：5.64, 校验误差：3.50, 准确率：0.22
# no transfer网络：第0试验，比例6, 第18周期，第(0/938)个撮，训练误差：3.82, 校验误差：3.46, 准确率：0.22
# no transfer网络：第0试验，比例6, 第19周期，第(0/938)个撮，训练误差：1.86, 校验误差：3.65, 准确率：0.23
# no transfer 0 6
# no transfer网络：第0试验，比例5, 第0周期，第(0/938)个撮，训练误差：99.62, 校验误差：95.53, 准确率：0.01
# no transfer网络：第0试验，比例5, 第1周期，第(0/938)个撮，训练误差：16.88, 校验误差：15.73, 准确率：0.10
# no transfer网络：第0试验，比例5, 第2周期，第(0/938)个撮，训练误差：15.08, 校验误差：13.76, 准确率：0.10
# no transfer网络：第0试验，比例5, 第3周期，第(0/938)个撮，训练误差：9.89, 校验误差：11.61, 准确率：0.12
# no transfer网络：第0试验，比例5, 第4周期，第(0/938)个撮，训练误差：8.64, 校验误差：8.44, 准确率：0.13

# %%
# 处理实验数据
# 首先对于同一组参数下的数据求多次试验的平均值

one_curve = {}
tests = {}
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    for fraction in fractions:
        one_experiment = []
        test_value = []
        for time in range(times):
            rr = results[(experiment, time, fraction)]
            one_experiment.append([ii[2] for ii in rr[0]])
            test_value.append(rr[1])
        aa = np.array(one_experiment)
        #print(aa.shape)
        one_curve[(experiment, fraction)] = np.mean(aa, 0)
        tests[(experiment, fraction)] = np.mean(test_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac3b8b5cfa9f> in <module>()
#       5 tests = {}
#       6 for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
# ----> 7     for fraction in fractions:
#       8         one_experiment = []
#       9         test_value = []
#
# NameError: name 'fractions' is not defined

# %%
# 然后再绘制它们的误差曲线
for fraction in fractions:
    plt.figure(figsize = (10, 7))
    plt.title('{:.2f} % of the data'.format(100.0 / fraction))
    plt.plot(1 - one_curve[('no transfer', fraction)], label = 'no transfer')
    plt.plot(1 - one_curve[('transfer_pretrained', fraction)], label = 'transfer pretrained')
    plt.plot(1 - one_curve[('transfer_fixed', fraction)] , label = 'transfer fixed')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Error')

# %%
# 绘制测试准确度随着fraction变化的曲线
plt.figure(figsize = (10, 7))
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    testss = []
    for fraction in fractions:
        test = 1 - tests[(experiment, fraction)]
        testss.append(test)
    plt.plot(fractions, testss, 'o-', label = experiment)
plt.legend()
plt.xlabel('Fractions')
plt.ylabel('Error Rate')

# %% [markdown]
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第IV课的配套源代码
