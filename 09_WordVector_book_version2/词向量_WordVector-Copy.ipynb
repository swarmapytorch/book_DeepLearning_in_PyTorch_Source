# %% [markdown]
# # 词汇的星空——词向量（Word Vector）技术
#
# 在这节课中，我们学习了如何通过人工神经网络得到单词的向量表达。
#
# 首先，我们构建了一个简单的NGram语言模型，根据N个历史词汇预测下一个单词，从而得到每一个单词的向量表示。我们用在集智俱乐部公众号上的一百篇科普文章为例，展示了我们的词向量嵌入效果。
#
# 其次，我们学习了如何使用成熟的Google开发的Word2Vec包来进行大规模语料的词向量训练，以及如何加载已经训练好的词向量，从而利用这些词向量来做一些简单的运算和测试。
#
# 本文件是集智学园http://campus.swarma.org 出品的“火炬上的深度学习”第VI课的配套源代码

# %%
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in /opt/anaconda3/envs/wchfting/lib/python3.7/site-packages (0.42.1)

# %%
# 加载必要的程序包
# PyTorch的程序包
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# 数值运算和绘图的程序包
import numpy as np
import matplotlib.pyplot as plt
import matplotlib


# 加载机器学习的软件包
from sklearn.decomposition import PCA

#加载Word2Vec的软件包
import gensim as gensim
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models.word2vec import LineSentence

#加载‘结巴’中文分词软件包

import jieba

#加载正则表达式处理的包
import re

# %matplotlib inline

# %% [markdown]
# ## 一、NGram 词向量模型

# %% [markdown]
# NGram词向量模型的原理是利用一个人工神经网络来根据前N个单词来预测下一个单词，从而得到每个单词的词向量

# %% [markdown]
# ### 1. 文本预处理
#
# 这里我们使用的语料是发表在集智俱乐部公众号上的一百篇科普文章，来展示利用NGram模型训练词向量的方法。集智俱乐部公众号长期关注复杂科学与人工智能研究，追踪学术进展，推介学习资源，科普交叉前沿，ID是：swarma_org，欢迎大家关注。
#
# 预处理分为两个步骤：
#
# 1、读取文件
#
# 2、分词
#
# 3、将语料划分为N＋1元组，准备好训练用数据
#
# 在这里，我们并没有去除标点符号，一是为了编程简洁，而是考虑到分词会自动将标点符号当作一个单词处理，因此不需要额外考虑。

# %% [markdown]
# #### 1). 读入原始文件，筛掉所有标点符号

# %%
f = open("swarma_article_small.txt", 'r',encoding='UTF-8')
# 若想加快运行速度，使用下面的语句（选用了三体的其中一章）：
#f = open("3body.txt",'r',encoding='UTF-8') 
text = str(f.read())
f.close()

# %% [markdown]
# #### 2)、分词，并去掉标点符号

# %%
# 分词
temp = jieba.lcut(text)
words = []
for i in temp:
    #过滤掉所有的标点符号
    i = re.sub("[\s+\.\!\/_,$%^*(+\"\'“”《》?“]+|[+——！，。？、~@#￥%……&*（）：]+", "", i)
    if len(i) > 0:
        words.append(i)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/v7/qc74ljfx76nb_xfpww7qpqfm0000gn/T/jieba.cache
# Loading model cost 0.912 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# #### 3)、构建N+1元组作为训练数据对

# %%
# 构建三元组列表.  每一个元素为： ([ i-2位置的词, i-1位置的词 ], 下一个词)
# 我们选择的Ngram中的N，即窗口大小为2
trigrams = [([words[i], words[i + 1]], words[i + 2]) for i in range(len(words) - 2)]
# 打印出前三个元素看看
print(trigrams[:3])
# Out:
# [(['导语', '科学家'], '什么'), (['科学家', '什么'], '时候'), (['什么', '时候'], '能够')]

# %% [markdown]
# #### 4). 将每个单词进行编码，构造词典

# %%
# 得到词汇表
vocab = set(words)
print(len(vocab))
# 两个字典，一个根据单词索引其编号，一个根据编号索引单词
#word_to_idx中的值包含两部分，一部分为id，另一部分为单词出现的次数
#word_to_idx中的每一个元素形如：{w:[id, count]}，其中w为一个词，id为该词的编号，count为该单词在words全文中出现的次数
word_to_idx = {} 
idx_to_word = {}
ids = 0

#对全文循环，构建这两个字典
for w in words:
    cnt = word_to_idx.get(w, [ids, 0])
    if cnt[1] == 0:
        ids += 1
    cnt[1] += 1
    word_to_idx[w] = cnt
    idx_to_word[ids] = w
# Out:
# 7395

# %%
word_to_idx
# Out:
# {'导语': [0, 23],
#  '科学家': [1, 45],
#  '什么': [2, 17],
#  '时候': [3, 5],
#  '能够': [4, 52],
#  '迎来': [5, 3],
#  '事业': [6, 4],
#  '巅峰': [7, 2],
#  '科学': [8, 196],
#  '创新': [9, 39],
#  '的': [10, 3250],
#  '生命周期': [11, 6],
#  '是': [12, 375],
#  '多久': [13, 4],
#  '职业生涯': [14, 7],
#  '中': [15, 380],
#  '出现': [16, 47],
#  '突破性': [17, 4],
#  '进展': [18, 15],
#  '迹象': [19, 2],
#  '是否': [20, 15],
#  '存在': [21, 49],
#  '什么样': [22, 5],
#  '合作': [23, 15],
#  '会': [24, 112],
#  '带来': [25, 21],
#  '成功': [26, 16],
#  '年轻': [27, 8],
#  '科研人员': [28, 8],
#  '如何': [29, 58],
#  '将': [30, 120],
#  '概率': [31, 9],
#  '最大化': [32, 6],
#  '这些': [33, 98],
#  '都': [34, 82],
#  '科学学': [35, 15],
#  'the': [36, 45],
#  'science': [37, 8],
#  'of': [38, 85],
#  '正在': [39, 16],
#  '探索': [40, 42],
#  '问题': [41, 99],
#  '当': [42, 32],
#  '我们': [43, 180],
#  '把': [44, 10],
#  '视为': [45, 8],
#  '一个': [46, 162],
#  '复杂': [47, 284],
#  '系统': [48, 361],
#  '来': [49, 66],
#  '研究': [50, 300],
#  '有': [51, 108],
#  '令人兴奋': [52, 3],
#  '洞察': [53, 2],
#  '由': [54, 59],
#  '王大顺': [55, 4],
#  '美国西北大学': [56, 2],
#  '凯洛': [57, 2],
#  '格': [58, 3],
#  '商学院': [59, 2],
#  '教授': [60, 17],
#  '与': [61, 272],
#  '中心': [62, 33],
#  '创始': [63, 2],
#  '主任': [64, 5],
#  '和': [65, 605],
#  'Albert': [66, 2],
#  '-': [67, 351],
#  'L': [68, 6],
#  'á': [69, 8],
#  'szl': [70, 2],
#  'ó': [71, 3],
#  'Barab': [72, 4],
#  'si': [73, 4],
#  '美国': [74, 24],
#  '东北大学': [75, 2],
#  '网络': [76, 146],
#  '无': [77, 17],
#  '标度': [78, 11],
#  '模型': [79, 176],
#  '提出': [80, 33],
#  '者': [81, 12],
#  '完成': [82, 12],
#  '新书': [83, 3],
#  '给': [84, 15],
#  '思维': [85, 7],
#  'The': [86, 6],
#  'Science': [87, 31],
#  '中文版': [88, 2],
#  '于': [89, 86],
#  '近日': [90, 8],
#  '上市': [91, 2],
#  '本书': [92, 2],
#  '中译': [93, 2],
#  '版': [94, 4],
#  '贾韬': [95, 4],
#  '西南': [96, 2],
#  '大学': [97, 9],
#  '计算机': [98, 15],
#  '信息科学': [99, 4],
#  '学院': [100, 7],
#  '汪小帆': [101, 4],
#  '长江': [102, 3],
#  '学者': [103, 25],
#  '特聘': [104, 2],
#  '上海大学': [105, 2],
#  '副校长': [106, 2],
#  '翻译': [107, 6],
#  '结合': [108, 21],
#  '了': [109, 433],
#  '大': [110, 40],
#  '数据': [111, 138],
#  '机器': [112, 60],
#  '学习': [113, 138],
#  '等': [114, 154],
#  '方法': [115, 84],
#  '对': [116, 231],
#  '领域': [117, 115],
#  '前沿': [118, 35],
#  '做': [119, 9],
#  '介绍': [120, 28],
#  '展示': [121, 23],
#  '科研': [122, 24],
#  '发展': [123, 71],
#  '规律': [124, 13],
#  '路径': [125, 11],
#  '最新': [126, 26],
#  '认识': [127, 12],
#  '推荐': [128, 25],
#  '所有': [129, 39],
#  '工作者': [130, 11],
#  '本文': [131, 23],
#  '节选自': [132, 2],
#  '原书': [133, 2],
#  '第': [134, 6],
#  '18': [135, 4],
#  '章': [136, 3],
#  '同时': [137, 42],
#  '集智': [138, 66],
#  '俱乐部': [139, 20],
#  '组织': [140, 42],
#  '计算': [141, 99],
#  '社群': [142, 13],
#  '集思广益': [143, 1],
#  '用': [144, 25],
#  '新': [145, 70],
#  'idea': [146, 1],
#  '技术': [147, 44],
#  '探讨': [148, 8],
#  '科学技术': [149, 3],
#  '并': [150, 119],
#  '以': [151, 78],
#  '专栏': [152, 2],
#  '项目': [153, 12],
#  '形式': [154, 15],
#  '呈现': [155, 5],
#  '详情': [156, 4],
#  '见': [157, 4],
#  '文末': [158, 8],
#  'AL': [159, 2],
#  'nbsp': [160, 265],
#  ';': [161, 354],
#  '|': [162, 49],
#  '作者': [163, 29],
#  '译者': [164, 6],
#  '邓一雪': [165, 12],
#  '编辑': [166, 16],
#  '如果': [167, 41],
#  '假定': [168, 2],
#  '一篇': [169, 13],
#  '论文': [170, 250],
#  '影响力': [171, 33],
#  '大致': [172, 5],
#  '可': [173, 38],
#  '通过': [174, 114],
#  '它': [175, 57],
#  '引用': [176, 57],
#  '量': [177, 13],
#  '体现': [178, 1],
#  '那么': [179, 13],
#  '分布': [180, 15],
#  '肥尾': [181, 1],
#  '形态': [182, 3],
#  '遗憾': [183, 2],
#  '地': [184, 46],
#  '表明': [185, 33],
#  '大多数': [186, 10],
#  '几乎': [187, 9],
#  '没有': [188, 21],
#  '任何': [189, 15],
#  '实际上': [190, 7],
#  '仅': [191, 11],
#  '极小': [192, 1],
#  '部分': [193, 21],
#  '文献会': [194, 1],
#  '影响': [195, 55],
#  '某一': [196, 2],
#  '正如': [197, 3],
#  '前': [198, 16],
#  '一章': [199, 1],
#  '适应度': [200, 5],
#  '最终': [201, 11],
#  '决定': [202, 6],
#  '高低': [203, 1],
#  '所': [204, 55],
#  '某些': [205, 3],
#  '创意': [206, 11],
#  '能': [207, 34],
#  '产生': [208, 48],
#  '重大': [209, 9],
#  '高': [210, 30],
#  '在': [211, 595],
#  '其中': [212, 29],
#  '起到': [213, 3],
#  '关键作用': [214, 2],
#  '但': [215, 78],
#  '因素': [216, 14],
#  '预测': [217, 72],
#  '呢': [218, 19],
#  '怎样才能': [219, 2],
#  '科研成果': [220, 1],
#  '发挥': [221, 6],
#  '到': [222, 93],
#  '极致': [223, 1],
#  '本章': [224, 2],
#  '关注': [225, 22],
#  '两个': [226, 38],
#  '不同': [227, 85],
#  '作用': [228, 16],
#  '它们': [229, 54],
#  '分别': [230, 13],
#  '内部': [231, 15],
#  '外部': [232, 15],
#  '即': [233, 42],
#  '宣传': [234, 2],
#  '涌现': [235, 67],
#  '关系': [236, 29],
#  '虽然': [237, 13],
#  '某篇': [238, 3],
#  '很多': [239, 15],
#  '然而': [240, 37],
#  '尤为': [241, 3],
#  '受': [242, 7],
#  '那': [243, 4],
#  '就是': [244, 16],
#  '究竟': [245, 3],
#  '怎样': [246, 9],
#  '衡量': [247, 10],
#  '增强': [248, 17],
#  '或者': [249, 21],
#  '损害': [250, 1],
#  '吗': [251, 12],
#  '3': [252, 93],
#  '孕育': [253, 1],
#  '声誉': [254, 1],
#  '马太效应': [255, 1],
#  '所述': [256, 3],
#  '通常': [257, 33],
#  '综合': [258, 4],
#  '现有': [259, 11],
#  '知识': [260, 30],
#  '例如': [261, 44],
#  '发明': [262, 8],
#  '往往': [263, 24],
#  '整合': [264, 8],
#  '已': [265, 16],
#  '或': [266, 106],
#  '过程': [267, 67],
#  '进而': [268, 4],
#  '创造': [269, 2],
#  '出': [270, 17],
#  '具有': [271, 64],
#  '原创性': [272, 2],
#  '东西': [273, 2],
#  '见图': [274, 4],
#  '1': [275, 115],
#  '汽船': [276, 2],
#  '帆船': [277, 1],
#  '蒸汽机': [278, 2],
#  '相结合': [279, 8],
#  '产物': [280, 3],
#  '而': [281, 97],
#  '世界': [282, 31],
#  '上': [283, 125],
#  '第一辆': [284, 2],
#  '汽车': [285, 3],
#  '奔驰': [286, 3],
#  '专利': [287, 15],
#  '号': [288, 20],
#  '则': [289, 19],
#  '一辆': [290, 1],
#  '自行车': [291, 2],
#  '马车': [292, 2],
#  '车厢': [293, 2],
#  '以及': [294, 64],
#  '内燃机': [295, 2],
#  '组成': [296, 15],
#  '即使': [297, 11],
#  '你': [298, 20],
#  '口袋': [299, 1],
#  '里': [300, 10],
#  '智能手机': [301, 1],
#  '也': [302, 151],
#  '只是': [303, 7],
#  '组合': [304, 27],
#  '许多': [305, 39],
#  '先前': [306, 8],
#  '部件': [307, 1],
#  '特征': [308, 43],
#  '内存': [309, 1],
#  '数字': [310, 9],
#  '音乐': [311, 2],
#  '移动电话': [312, 1],
#  '互联网': [313, 7],
#  '接入': [314, 1],
#  '轻量': [315, 1],
#  '型': [316, 4],
#  '电池': [317, 1],
#  '图': [318, 153],
#  '建造': [319, 1],
#  '1885': [320, 1],
#  '年': [321, 132],
#  '号车': [322, 2],
#  '被': [323, 101],
#  '生产': [324, 4],
#  '出来': [325, 9],
#  '卡尔': [326, 1],
#  '·': [327, 28],
#  '本茨': [328, 1],
#  'KarlBenz': [329, 1],
#  '1886': [330, 1],
#  '月': [331, 31],
#  '29': [332, 4],
#  '日为': [333, 1],
#  '该车': [334, 1],
#  '申请': [335, 20],
#  '德国': [336, 3],
#  '专利号': [337, 1],
#  '37435': [338, 1],
#  '三项': [339, 1],
#  '已经': [340, 24],
#  '新发明': [341, 1],
#  '重新': [342, 12],
#  '组合而成': [343, 1],
#  '这一': [344, 28],
#  '理论': [345, 82],
#  '分析': [346, 59],
#  '得以': [347, 6],
#  '证实': [348, 8],
#  '美国专利局': [349, 1],
#  '使用': [350, 50],
#  '统一': [351, 11],
#  '编码方案': [352, 1],
#  '按照': [353, 4],
#  '类': [354, 12],
#  '子类': [355, 3],
#  '每一项': [356, 1],
#  '进行': [357, 80],
#  '分类': [358, 13],
#  '比如': [359, 19],
#  '苹果公司': [360, 1],
#  '产品': [361, 3],
#  'iPod': [362, 1],
#  '曾': [363, 3],
#  '取得': [364, 7],
#  '一项': [365, 15],
#  '原创': [366, 2],
#  '[': [367, 105],
#  'US20030095096A1': [368, 1],
#  ']': [369, 106],
#  '史蒂夫': [370, 1],
#  '乔布斯': [371, 1],
#  '为': [372, 149],
#  '其': [373, 70],
#  '发明者': [374, 2],
#  '之一': [375, 7],
#  '编码': [376, 13],
#  '345': [377, 2],
#  '156': [378, 2],
#  '这': [379, 106],
#  '表示': [380, 33],
#  '图像处理': [381, 1],
#  '选择性': [382, 1],
#  '视觉': [383, 8],
#  '显示': [384, 24],
#  '外设': [385, 1],
#  '接口': [386, 3],
#  '输入': [387, 17],
#  '设备': [388, 2],
#  '人员': [389, 37],
#  '1790': [390, 1],
#  '2010': [391, 3],
#  '发现': [392, 86],
#  '19': [393, 10],
#  '世纪': [394, 9],
#  '颁发': [395, 2],
#  '近一半': [396, 1],
#  '属于': [397, 5],
#  '单': [398, 5],
#  '应用': [399, 74],
#  '单一': [400, 5],
#  '不是': [401, 25],
#  '多': [402, 55],
#  '此': [403, 11],
#  '相对': [404, 15],
#  '当前': [405, 14],
#  '90': [406, 4],
#  '至少': [407, 5],
#  '现在': [408, 18],
#  '越来越': [409, 19],
#  '成为': [410, 30],
#  '发明创造': [411, 1],
#  '性': [412, 23],
#  '视角': [413, 15],
#  '提供': [414, 48],
#  '一种': [415, 60],
#  '量化': [416, 5],
#  '方式': [417, 28],
#  '的确': [418, 2],
#  '科学论文': [419, 10],
#  '从': [420, 105],
#  '众多': [421, 8],
#  '期刊': [422, 37],
#  '选择': [423, 35],
#  '参考文献': [424, 18],
#  '指明': [425, 2],
#  '源自': [426, 4],
#  '哪一': [427, 1],
#  '有些': [428, 2],
#  '意料之中': [429, 1],
#  '另外': [430, 7],
#  '一些则': [431, 2],
#  '很': [432, 25],
#  '新颖': [433, 11],
#  '偏离': [434, 5],
#  '常规': [435, 6],
#  '思路': [436, 4],
#  '两种': [437, 23],
#  '很少': [438, 5],
#  '可能': [439, 85],
#  '意味着': [440, 19],
#  '该': [441, 52],
#  '基于': [442, 48],
#  '已有': [443, 8],
#  '生物化学': [444, 5],
#  '杂志': [445, 11],
#  'Journal': [446, 5],
#  'Biological': [447, 1],
#  'Chemistry': [448, 1],
#  '刊载': [449, 1],
#  '2001': [450, 4],
#  '为例': [451, 2],
#  '确认': [452, 1],
#  '已知': [453, 4],
#  '抗': [454, 3],
#  '精神疾病': [455, 1],
#  '药物': [456, 10],
#  '相互作用': [457, 39],
#  '蛋白质': [458, 31],
#  '利用': [459, 26],
#  '确定': [460, 17],
#  '其他': [461, 23],
#  '生物': [462, 39],
#  '效应': [463, 11],
#  '文献': [464, 29],
#  '列表': [465, 5],
#  '首次': [466, 5],
#  '囊括': [467, 1],
#  '基因': [468, 9],
#  '表达': [469, 10],
#  'Gene': [470, 1],
#  'Expression': [471, 1],
#  '临床': [472, 1],
#  '精神': [473, 3],
#  '医学杂志': [474, 2],
#  'Clinical': [475, 1],
#  'Psychiatry': [476, 1],
#  '表现': [477, 26],
#  '创新性': [478, 7],
#  '与此同时': [479, 4],
#  '这篇': [480, 6],
#  '频繁': [481, 2],
#  '如': [482, 34],
#  '生化': [483, 2],
#  'Biochemical': [484, 2],
#  '这种': [485, 50],
#  '传统': [486, 19],
#  '搭配': [487, 1],
#  '反映': [488, 3],
#  '内': [489, 21],
#  '主流': [490, 9],
#  '思想': [491, 8],
#  '悖论': [492, 9],
#  '一系列': [493, 9],
#  '广泛': [494, 23],
#  '调查': [495, 7],
#  '获得': [496, 49],
#  '证据': [497, 9],
#  '一致': [498, 12],
#  '出版物': [499, 2],
#  '专利发明': [500, 1],
#  '不': [501, 87],
#  '常见': [502, 5],
#  '更': [503, 76],
#  '换句话说': [504, 3],
#  '伴随': [505, 3],
#  '而来': [506, 1],
#  '还有': [507, 4],
#  '不断': [508, 20],
#  '增加': [509, 47],
#  '一举': [510, 1],
#  '机会': [511, 6],
#  '这个': [512, 43],
#  '跨学科': [513, 48],
#  '关键': [514, 17],
#  '前提': [515, 1],
#  '毫无': [516, 1],
#  '关联': [517, 17],
#  '构想': [518, 6],
#  '资源': [519, 12],
#  '交互作用': [520, 2],
#  '形成': [521, 47],
#  '富有成果': [522, 1],
#  '常常': [523, 2],
#  '成果': [524, 10],
#  '同样': [525, 17],
#  '导致': [526, 37],
#  '较': [527, 17],
#  '不确定性': [528, 9],
#  '事实上': [529, 3],
#  '极其': [530, 2],
#  '既': [531, 7],
#  '失败': [532, 7],
#  '超过': [533, 15],
#  '17000': [534, 1],
#  '项': [535, 1],
#  '后': [536, 34],
#  '合作者': [537, 1],
#  '专业': [538, 5],
#  '之间': [539, 65],
#  '差异': [540, 13],
#  '越大': [541, 5],
#  '结果': [542, 54],
#  '波动性': [543, 1],
#  '；': [544, 82],
#  '巨大': [545, 7],
#  '比': [546, 30],
#  '普通': [547, 2],
#  '突破': [548, 4],
#  '2': [549, 111],
#  '学科': [550, 42],
#  '更具': [551, 3],
#  '特点': [552, 10],
#  '他们': [553, 35],
#  '整体': [554, 20],
#  '质量': [555, 9],
#  '有所': [556, 5],
#  '下降': [557, 24],
#  '包含': [558, 27],
#  '就': [559, 43],
#  '排名': [560, 1],
#  '承担': [561, 2],
#  '更大': [562, 5],
#  '风险': [563, 8],
#  '要花': [564, 1],
#  '更长': [565, 6],
#  '时间': [566, 82],
#  '才能': [567, 2],
#  '开始': [568, 27],
#  '累积': [569, 1],
#  '学术界': [570, 4],
#  '无法': [571, 11],
#  '何种': [572, 3],
#  '方面': [573, 28],
#  '固有': [574, 5],
#  '高风险': [575, 2],
#  '起着': [576, 1],
#  '无人': [577, 2],
#  '涉足': [578, 1],
#  '一对': [579, 1],
#  '化合物': [580, 3],
#  '化学': [581, 20],
#  '比起': [582, 1],
#  '得': [583, 3],
#  '透彻': [584, 2],
#  '而且': [585, 12],
#  '这样': [586, 18],
#  '策略': [587, 11],
#  '但是': [588, 16],
#  '以前': [589, 2],
#  '尝试': [590, 5],
#  '非常': [591, 15],
#  '评估': [592, 5],
#  '那样': [593, 2],
#  '额外': [594, 4],
#  '奖励': [595, 3],
#  '似乎': [596, 13],
#  '不足以': [597, 1],
#  '冒险': [598, 1],
#  '理由': [599, 1],
#  '变数': [600, 1],
#  '人类': [601, 54],
#  '偏见': [602, 4],
#  '基金': [603, 7],
#  '工作': [604, 40],
#  '真正': [605, 8],
#  '实现': [606, 15],
#  '之前': [607, 17],
#  '们': [608, 7],
#  '概念': [609, 27],
#  '持有偏见': [610, 1],
#  '一所': [611, 1],
#  '一流': [612, 1],
#  '医学院': [613, 1],
#  '随机': [614, 19],
#  '指定': [615, 2],
#  '142': [616, 1],
#  '名': [617, 6],
#  '世界级': [618, 1],
#  '评审': [619, 2],
#  '15': [620, 8],
#  '份': [621, 3],
#  '申请书': [622, 3],
#  '每份': [623, 3],
#  '罕见': [624, 1],
#  '关键字': [625, 2],
#  '次数': [626, 2],
#  'Ⅰ': [627, 2],
#  '糖尿病': [628, 2],
#  '胰岛素': [629, 1],
#  '较为': [630, 3],
#  '斑马鱼': [631, 2],
#  '少见': [632, 1],
#  '时': [633, 51],
#  '或多或少': [634, 1],
#  '更受': [635, 1],
#  '青睐': [636, 2],
#  '相比': [637, 12],
#  '分数': [638, 3],
#  '偏低': [639, 1],
#  '名义': [640, 1],
#  '避免': [641, 7],
#  '不了': [642, 1],
#  '类似': [643, 7],
#  '澳大利亚': [644, 3],
#  '基金项目': [645, 1],
#  '收到': [646, 2],
#  '全部': [647, 5],
#  '18476': [648, 1],
#  '包括': [649, 48],
#  '查找': [650, 1],
#  '界定': [651, 2],
#  '具体': [652, 13],
#  '数量': [653, 36],
#  '距离': [654, 10],
#  '加权': [655, 2],
#  '结果显示': [656, 4],
#  '计划': [657, 8],
#  '性越': [658, 1],
#  '强': [659, 4],
#  '资助': [660, 21],
#  '可能性': [661, 10],
#  '越低': [662, 1],
#  '使': [663, 33],
#  '处于': [664, 11],
#  '矛盾': [665, 4],
#  '境地': [666, 1],
#  '显然': [667, 6],
#  '来说': [668, 12],
#  '必不可少': [669, 1],
#  '理应': [670, 1],
#  '高分': [671, 1],
#  '观察': [672, 26],
#  '一': [673, 19],
#  '难以获得': [674, 1],
#  '验证': [675, 6],
#  '必需': [676, 2],
#  '他': [677, 20],
#  '平庸': [678, 1],
#  '改善': [679, 5],
#  '最近': [680, 17],
#  '重要': [681, 58],
#  '见解': [682, 1],
#  '平衡': [683, 14],
#  '好': [684, 11],
#  '想想': [685, 1],
#  '达尔文': [686, 2],
#  '专门': [687, 4],
#  '物种': [688, 7],
#  '起源': [689, 13],
#  '第一': [690, 4],
#  '叙述': [691, 1],
#  '有关': [692, 14],
#  '狗': [693, 1],
#  '牛': [694, 1],
#  '鸟': [695, 2],
#  '选育': [696, 1],
#  '接受': [697, 1],
#  '揭示': [698, 20],
#  '拥有': [699, 7],
#  '基本特征': [700, 1],
#  '立足于': [701, 1],
#  '研究成果': [702, 7],
#  '融入': [703, 1],
#  '迄今为止': [704, 1],
#  '还': [705, 36],
#  '未': [706, 15],
#  '非典型': [707, 1],
#  '790': [708, 1],
#  '万篇': [709, 1],
#  '那些': [710, 9],
#  '推出': [711, 8],
#  '又': [712, 16],
#  '继承': [713, 3],
#  '高出': [714, 2],
#  '两倍': [715, 2],
#  '结果表明': [716, 7],
#  '熟悉': [717, 1],
#  '起来': [718, 8],
#  '特别': [719, 12],
#  '报道': [720, 15],
#  '可以': [721, 162],
#  '提升': [722, 11],
#  '能见度': [723, 1],
#  '媒体报道': [724, 6],
#  '扩大': [725, 4],
#  '大众': [726, 4],
#  '过': [727, 19],
#  '为了': [728, 23],
#  '回答': [729, 7],
#  '来看': [730, 8],
#  '一家': [731, 1],
#  '新闻媒体': [732, 1],
#  '纽约时报': [733, 9],
#  '由于': [734, 27],
#  '涉及': [735, 16],
#  '健康': [736, 5],
#  '引起': [737, 6],
#  '兴趣': [738, 7],
#  '新英格兰': [739, 3],
#  'New': [740, 2],
#  'England': [741, 1],
#  'Medicine': [742, 1],
#  '发表': [743, 33],
#  '比较': [744, 8],
#  '两者': [745, 5],
#  '总体': [746, 8],
#  '第一年': [747, 1],
#  '没': [748, 2],
#  '那组': [749, 1],
#  '728': [750, 1],
#  '归结为': [751, 1],
#  '有没有': [752, 1],
#  '只': [753, 13],
#  '一些': [754, 31],
#  '优秀': [755, 2],
#  '获取': [756, 12],
#  '自然实验': [757, 3],
#  '帮助': [758, 15],
#  '找到': [759, 9],
#  '更加': [760, 13],
#  '明确': [761, 8],
#  '答案': [762, 3],
#  '员工': [763, 1],
#  '1978': [764, 1],
#  '8': [765, 25],
#  '10': [766, 21],
#  '日至': [767, 1],
#  '11': [768, 13],
#  '5': [769, 45],
#  '日': [770, 19],
#  '经历': [771, 13],
#  '12': [772, 21],
#  '周': [773, 3],
#  '罢工': [774, 2],
#  '在此期间': [775, 3],
#  '该报': [776, 1],
#  '继续': [777, 11],
#  '刊印': [778, 1],
#  '缩减': [779, 2],
#  '版面': [780, 1],
#  '作为': [781, 44],
#  '记录': [782, 14],
#  '版本': [783, 6],
#  '留存': [784, 1],
#  '并未': [785, 1],
#  '公开': [786, 1],
#  '发行': [787, 2],
#  '也就是说': [788, 5],
#  '期间': [789, 14],
#  '报社': [790, 1],
#  '安排': [791, 2],
#  '认为': [792, 33],
#  '值得': [793, 3],
#  '文章': [794, 16],
#  '读者': [795, 3],
#  '却': [796, 17],
#  '并不知道': [797, 1],
#  '信息': [798, 76],
#  '优势': [799, 11],
#  '完全': [800, 13],
#  '消失': [801, 7],
#  '挑选': [802, 4],
#  '准备': [803, 3],
#  '并不比': [804, 1],
#  '更好': [805, 13],
#  '因此': [806, 49],
#  '吸引': [807, 9],
#  '眼球': [808, 2],
#  '不能': [809, 13],
#  '仅仅': [810, 2],
#  '解释': [811, 30],
#  '新颖性': [812, 4],
#  '吸引力': [813, 2],
#  '本身': [814, 9],
#  '原因': [815, 5],
#  '要': [816, 20],
#  '理解': [817, 38],
#  '为何': [818, 4],
#  '有助于': [819, 9],
#  '不难': [820, 1],
#  '受众': [821, 2],
#  '对于': [822, 38],
#  '接触': [823, 10],
#  '范围': [824, 19],
#  '潜在地': [825, 1],
#  '获知': [826, 1],
#  '相关': [827, 67],
#  '充当': [828, 2],
#  '认证标志': [829, 1],
#  '学术': [830, 12],
#  '群体': [831, 24],
#  '可信度': [832, 1],
#  '也许': [833, 4],
#  '最': [834, 32],
#  '根本': [835, 2],
#  '在于': [836, 1],
#  '消息': [837, 1],
#  '确实': [838, 3],
#  '电视台': [839, 1],
#  '报刊': [840, 1],
#  '无意': [841, 2],
#  '查证': [842, 1],
#  '保持平衡': [843, 2],
#  '态度': [844, 2],
#  '媒体': [845, 8],
#  '有限': [846, 15],
#  '播出': [847, 1],
#  '笔墨': [848, 1],
#  '某项': [849, 1],
#  '科学研究': [850, 15],
#  '视作': [851, 1],
#  '真实': [852, 17],
#  '有趣': [853, 3],
#  '毕竟': [854, 3],
#  '具备': [855, 3],
#  '为什么': [856, 7],
#  '还要': [857, 4],
#  '浪费': [858, 1],
#  '观众': [859, 1],
#  '正面': [860, 1],
#  '这会': [861, 1],
#  '严重': [862, 4],
#  '公众': [863, 8],
#  '认知': [864, 13],
#  '用于': [865, 36],
#  '确保': [866, 5],
#  '准确': [867, 6],
#  '诚实': [868, 1],
#  '制衡': [869, 1],
#  '机制': [870, 28],
#  '维护': [871, 2],
#  '批评': [872, 4],
#  '反驳': [873, 4],
#  '多种形式': [874, 1],
#  '原始': [875, 1],
#  '结论': [876, 5],
#  '另': [877, 20],
#  '多数': [878, 3],
#  '情况': [879, 39],
#  '下': [880, 80],
#  '旨在': [881, 5],
#  '凸显': [882, 1],
#  '实质性': [883, 1],
#  '缺陷': [884, 3],
#  '同行': [885, 8],
#  '之后': [886, 23],
#  '第一道': [887, 1],
#  '保险': [888, 3],
#  '一点': [889, 12],
#  '终于': [890, 2],
#  '负面': [891, 11],
#  '降低': [892, 13],
#  '的话': [893, 1],
#  '有效性': [894, 8],
#  '质疑': [895, 3],
#  '评论': [896, 9],
#  '表面': [897, 13],
#  '好像': [898, 1],
#  '使原': [899, 1],
#  '眼中': [900, 1],
#  '变得': [901, 21],
#  '可信': [902, 1],
#  '觉得': [903, 1],
#  '恰恰相反': [904, 1],
#  '受到': [905, 7],
#  '不仅': [906, 12],
#  '比未受': [907, 1],
#  '明显': [908, 9],
#  '最高': [909, 3],
#  '指': [910, 6],
#  '明确提出': [911, 2],
#  '局限': [912, 1],
#  '参考': [913, 9],
#  '免疫学': [914, 2],
#  'Immunology': [915, 1],
#  '提取': [916, 6],
#  '000': [917, 9],
#  '条': [918, 1],
#  '制作': [919, 4],
#  '训练': [920, 37],
#  '集': [921, 11],
#  '并且': [922, 18],
#  '位': [923, 4],
#  '专家': [924, 2],
#  '加以': [925, 4],
#  '客观': [926, 3],
#  '标注': [927, 2],
#  '运用': [928, 4],
#  '自然语言': [929, 2],
#  '处理': [930, 23],
#  '识别': [931, 23],
#  '15731': [932, 1],
#  '篇': [933, 7],
#  '长期': [934, 16],
#  '积累': [935, 5],
#  '总': [936, 1],
#  '造成': [937, 1],
#  '轻微': [938, 1],
#  '随着': [939, 24],
#  '推移': [940, 3],
#  '最后': [941, 11],
#  '默默无闻': [942, 1],
#  '好得多': [943, 1],
#  '总之': [944, 3],
#  '本意': [945, 1],
#  '相反': [946, 13],
#  '成': [947, 10],
#  '早期': [948, 12],
#  '信号': [949, 26],
#  '反而': [950, 2],
#  '主要': [951, 43],
#  '不怎么': [952, 1],
#  '愿意': [953, 3],
#  '花': [954, 3],
#  '说服力': [955, 1],
#  '不强': [956, 2],
#  '无关紧要': [957, 1],
#  '撰写': [958, 1],
#  '只有': [959, 5],
#  '潜在': [960, 11],
#  '重要性': [961, 10],
#  '才': [962, 5],
#  '首先': [963, 13],
#  '足够': [964, 7],
#  '从而': [965, 23],
#  '批评性': [966, 1],
#  '细致': [967, 1],
#  '更进一步': [968, 1],
#  '观点': [969, 20],
#  '简单': [970, 14],
#  '否定': [971, 1],
#  '再者': [972, 1],
#  '还会': [973, 4],
#  '进一步提高': [974, 1],
#  '知名度': [975, 1],
#  '看起来': [976, 5],
#  '科学界': [977, 2],
#  '负面新闻': [978, 1],
#  '新闻': [979, 1],
#  '欢迎': [980, 19],
#  '加入': [981, 18],
#  '算法': [982, 54],
#  '组': [983, 6],
#  '集智斑': [984, 20],
#  '学园': [985, 5],
#  '百科': [986, 9],
#  '支撑': [987, 5],
#  '服务': [988, 16],
#  '目前': [989, 8],
#  '开发': [990, 6],
#  '限于': [991, 1],
#  '文本': [992, 5],
#  '术语': [993, 6],
#  '挖掘': [994, 3],
#  '引文': [995, 1],
#  '网络分析': [996, 1],
#  '评价': [997, 3],
#  '神经网络': [998, 17],
#  '科技': [999, 6],
#  ...}

# %% [markdown]
# ### 2、构造模型并训练

# %% [markdown]
# #### 1). 构造NGram神经网络模型
#
# 我们构造了一个三层的网络：
#
# 1、输入层：embedding层，这一层的作用是：先将输入单词的编号映射为一个one hot编码的向量，形如：001000，维度为单词表大小。
# 然后，embedding会通过一个线性的神经网络层映射到这个词的向量表示，输出为embedding_dim
#
# 2、线性层，从embedding_dim维度到128维度，然后经过非线性ReLU函数
#
# 3、线性层：从128维度到单词表大小维度，然后log softmax函数，给出预测每个单词的概率

# %%
class NGram(nn.Module):

    def __init__(self, vocab_size, embedding_dim, context_size):
        super(NGram, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)  #嵌入层
        self.linear1 = nn.Linear(context_size * embedding_dim, 128) #线性层
        self.linear2 = nn.Linear(128, vocab_size) #线性层

    def forward(self, inputs):
        #嵌入运算，嵌入运算在内部分为两步：将输入的单词编码映射为one hot向量表示，然后经过一个线性层得到单词的词向量
        #inputs的尺寸为：1*context_size
        embeds = self.embeddings(inputs)
        #embeds的尺寸为: context_size*embedding_dim
        embeds = embeds.view(1, -1)
        #此时embeds的尺寸为：1*embedding_dim
        # 线性层加ReLU
        out = self.linear1(embeds)
        out = F.relu(out)
        #此时out的尺寸为1*128
        
        # 线性层加Softmax
        out = self.linear2(out)
        #此时out的尺寸为：1*vocab_size
        log_probs = F.log_softmax(out, dim = 1)
        return log_probs
    def extract(self, inputs):
        embeds = self.embeddings(inputs)
        return embeds

# %% [markdown]
# #### 2). 开始训练模型

# %%
losses = [] #纪录每一步的损失函数
criterion = nn.NLLLoss() #运用负对数似然函数作为目标函数（常用于多分类问题的目标函数）
model = NGram(len(vocab), 10, 2) #定义NGram模型，向量嵌入维数为10维，N（窗口大小）为2
optimizer = optim.SGD(model.parameters(), lr=0.001) #使用随机梯度下降算法作为优化器

#循环100个周期
for epoch in range(20):
    total_loss = torch.Tensor([0])
    for context, target in trigrams:

        # 准备好输入模型的数据，将词汇映射为编码
        context_idxs = [word_to_idx[w][0] for w in context]
        
        context_var = torch.tensor(context_idxs, dtype = torch.long)

        # 清空梯度：注意PyTorch会在调用backward的时候自动积累梯度信息，故而每隔周期要清空梯度信息一次。
        optimizer.zero_grad()

        # 用神经网络做计算，计算得到输出的每个单词的可能概率对数值
        log_probs = model(context_var)

        loss = criterion(log_probs, torch.tensor([word_to_idx[target][0]], dtype = torch.long))

        # 梯度反传
        loss.backward()
        
        # 对网络进行优化
        optimizer.step()
        
        # 累加损失函数值
        total_loss += loss.data
    losses.append(total_loss)
    print('第{}轮，损失函数为：{:.2f}'.format(epoch, total_loss.numpy()[0]))
# Out:
# 第0轮，损失函数为：373671.47
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-36299acb35f8> in <module>
#      26
#      27         # 对网络进行优化
# ---> 28         optimizer.step()
#      29
#      30         # 累加损失函数值
#
# /opt/anaconda3/envs/wchfting/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /opt/anaconda3/envs/wchfting/lib/python3.7/site-packages/torch/optim/sgd.py in step(self, closure)
#     110                         d_p = buf
#     111
# --> 112                 p.add_(d_p, alpha=-group['lr'])
#     113
#     114         return loss
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3. 结果展示
# #### 1). 将向量投影到二维平面进行可视化

# %%
# 从训练好的模型中提取每个单词的向量
vec = model.extract(torch.tensor([v[0] for v in word_to_idx.values()], dtype = torch.long))
vec = vec.data.numpy()

# 利用PCA算法进行降维
X_reduced = PCA(n_components=2).fit_transform(vec)


# 绘制所有单词向量的二维空间投影
fig = plt.figure(figsize = (30, 20))
ax = fig.gca()
ax.set_facecolor('white')
ax.plot(X_reduced[:, 0], X_reduced[:, 1], '.', markersize = 1, alpha = 0.4, color = 'black')


# 绘制几个特殊单词的向量
words = ['科学家','计算','因果','地球','复杂','临界','集智','百科','俱乐部','涌现']
# 设置中文字体，否则无法在图形上显示中文
zhfont1 = matplotlib.font_manager.FontProperties(fname='./HuaWenFangSong-1.ttf', size=16)
for w in words:
    if w in word_to_idx:
        ind = word_to_idx[w][0]
        xy = X_reduced[ind]
        plt.plot(xy[0], xy[1], '.', alpha =1, color = 'red')
        plt.text(xy[0], xy[1], w, fontproperties = zhfont1, alpha = 1, color = 'black')
        
plt.savefig('cloud.png')

# %% [markdown]
# #### 2). 临近词向量

# %%
# 定义计算cosine相似度的函数
def cos_similarity(vec1, vec2):
    
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    norm = norm1 * norm2
    dot = np.dot(vec1, vec2)
    result = dot / norm if norm > 0 else 0
    return result
    
# 在所有的词向量中寻找到与目标词（word）相近的向量，并按相似度进行排列
def find_most_similar(word, vectors, word_idx):
    vector = vectors[word_to_idx[word][0]]
    simi = [[cos_similarity(vector, vectors[num]), key] for num, key in enumerate(word_idx.keys())]
    sort = sorted(simi)[::-1]
    words = [i[1] for i in sort]
    return words

# 与物理靠近的词汇
find_most_similar('物理', vec, word_to_idx)
# Out:
# ['物理',
#  '根据',
#  '强',
#  '用作',
#  '超出',
#  '查证',
#  '交互式',
#  '层次结构',
#  'Life',
#  'gas',
#  'CalTrans',
#  '肩膀',
#  '可逆性',
#  '此时',
#  '不必要',
#  'scale',
#  '策略',
#  'end',
#  '递归',
#  '造成',
#  '145',
#  '老师',
#  '2247590536',
#  '从菌',
#  '赤道',
#  '时空图',
#  '损害',
#  '正式',
#  'Big',
#  '报告',
#  '1949',
#  '对角线',
#  '另一方面',
#  'max',
#  '望',
#  '少数',
#  'CRISPR',
#  'Internal',
#  'testing',
#  '收到',
#  '升高',
#  '000',
#  '尚未',
#  '氧化作用',
#  '面',
#  '等待',
#  '板块',
#  'human',
#  '福之所',
#  'offline',
#  '意味着',
#  '学术年会',
#  '见解',
#  '简明扼要',
#  '一幕',
#  'Albert',
#  '领域',
#  'activity',
#  '生态',
#  '洛杉矶国际机场',
#  'Transactions',
#  '文章',
#  'Mach',
#  '2000',
#  '摘录',
#  '门槛',
#  '旨在',
#  '试醒',
#  '制',
#  '1C',
#  '刻画',
#  'London',
#  '光',
#  '01442',
#  '设备',
#  '用户界面',
#  '耗尽',
#  '保持一致',
#  '致敬',
#  'General',
#  '节日',
#  '西班牙语',
#  '阴影',
#  '该车',
#  '是因为',
#  '率先',
#  '定论',
#  '是否',
#  '北京航空航天大学',
#  'Los',
#  '混合体',
#  'intergroup',
#  '苹果公司',
#  '申请书',
#  '转换率',
#  'Adaptive',
#  '修改',
#  '颁发',
#  '诞生',
#  '略有',
#  '群聊',
#  '349',
#  '技术奖',
#  '该报',
#  '孤独',
#  '汪',
#  'Lessons',
#  '焦点',
#  '干预',
#  '传入',
#  'μ',
#  '并不知道',
#  'Gene',
#  'Description',
#  'most',
#  'changing',
#  '兴衰',
#  '遇到',
#  '变成',
#  '透明度',
#  '城市',
#  '什么',
#  '科学基金',
#  '电商',
#  'Giampietro',
#  '端倪',
#  '出该',
#  '上海市',
#  '印本',
#  '万物',
#  'al',
#  '齐夫',
#  'Greener',
#  '吴令',
#  '临界点',
#  '从事',
#  '机械',
#  '电解质',
#  '模仿',
#  '01444',
#  '格点',
#  'leads',
#  '规则',
#  '某',
#  'justify',
#  'Gabriel',
#  'Stosszahlansatz',
#  '终将',
#  'continuous',
#  '人工',
#  '副校长',
#  '点击',
#  '较次',
#  'V',
#  '困扰',
#  '副',
#  '打算',
#  '外延',
#  '雪崩',
#  '流',
#  '审视',
#  '报社',
#  '神经',
#  '蚂蚁',
#  '电磁场',
#  '安排',
#  '录像',
#  '讲座',
#  '岳玉涛',
#  '联网',
#  '从中',
#  '课已',
#  'allocentric',
#  '飞翔',
#  '阐明',
#  'overall',
#  'NOx',
#  'Test',
#  '558',
#  'effective',
#  '代偿',
#  '参考资料',
#  '激发',
#  '每',
#  '成果',
#  '输入',
#  '可压缩',
#  '思维',
#  'Levitt',
#  '地址',
#  '无效',
#  '当今世界',
#  '发表',
#  '玻色子',
#  '以此',
#  '詹姆斯',
#  '智能手机',
#  '适用',
#  '干扰',
#  '郭瑞东',
#  'highly',
#  'Efficiency',
#  '易',
#  '跨部门',
#  'ground',
#  '称作',
#  'sleep',
#  'reconstruction',
#  '财团',
#  '传染',
#  'imgdata',
#  '只是',
#  '更大',
#  '满足',
#  '特征',
#  '学科前沿',
#  '框架',
#  'auto',
#  '操作',
#  '·',
#  'propose',
#  'Li',
#  '1940',
#  '原有',
#  '提供',
#  '反而',
#  'Whiten',
#  '上半年',
#  '不断涌现',
#  '期望',
#  '动能',
#  'to',
#  'Express',
#  '过大',
#  '评议',
#  '苏黎世',
#  'Waals',
#  '依据',
#  '是从',
#  '稳定性',
#  '可达',
#  '偏低',
#  '测序',
#  '职业生涯',
#  '第一年',
#  '角速度',
#  '几乎',
#  '竞争',
#  '缓慢',
#  '罢工',
#  '答案',
#  '两个',
#  '编辑',
#  '第二章',
#  'Meaning',
#  '降水量',
#  'that',
#  'Gap',
#  '神秘莫测',
#  '被',
#  '引发',
#  '位置',
#  '显著',
#  'patterns',
#  '斯密',
#  '1d',
#  '有则改之',
#  'Transformer',
#  '430',
#  '通讯',
#  '参与者',
#  '瓶颈',
#  '小到',
#  'v14',
#  'intrinsic',
#  '一般性',
#  'systems',
#  'biz',
#  '可定义',
#  '听音',
#  '关系',
#  'null',
#  'Sandra',
#  '功能',
#  '能够',
#  'PLOS',
#  '近亲',
#  '175ZB',
#  'Prospects',
#  'state',
#  '观察',
#  'Niklas',
#  '操作系统',
#  '15731',
#  '历史',
#  '遗址',
#  '里面',
#  '第一章',
#  'MacOS',
#  '年间',
#  '千米',
#  '加州大学',
#  'Causal',
#  '世纪末',
#  '一员',
#  'complexity',
#  '本',
#  '存在',
#  '科研项目',
#  '目的',
#  '3141',
#  '注意',
#  '总之',
#  'nine',
#  '尤为',
#  '编码',
#  '大雁',
#  'ac',
#  '智能化',
#  '界面',
#  '莫衷一是',
#  '映体',
#  '灰暗',
#  '隔离器',
#  '始自',
#  '和硕',
#  'e2107848118',
#  '化合物',
#  'API',
#  'globally',
#  '气相',
#  '天眼',
#  '双重',
#  'work',
#  '印发',
#  '熟悉',
#  '机场',
#  'qu',
#  '以圈',
#  '幅度',
#  '一无所知',
#  '语义',
#  '依次',
#  '集体',
#  '最新',
#  '熟知',
#  '描绘',
#  '界限',
#  '下',
#  'Neue',
#  '大量',
#  '表征',
#  '负',
#  '若',
#  'political',
#  '学科',
#  '同时',
#  'materials',
#  '最',
#  '归因',
#  '经济',
#  'white',
#  'climate',
#  '哥白尼',
#  '多样性',
#  '远离',
#  '第八',
#  '坐标',
#  '认识',
#  '资料',
#  '植物',
#  '遍读',
#  '生态环境',
#  '人文',
#  '获得',
#  '网站',
#  '荣幸',
#  '提醒',
#  '更具',
#  '实例',
#  '表示',
#  '起始',
#  '成员',
#  'Stephan',
#  '性态',
#  '繁复',
#  'Data',
#  '排斥',
#  '诱导',
#  '看',
#  '迄今为止',
#  '未有',
#  '4G',
#  '2005',
#  '增加',
#  '单排',
#  '热衷于',
#  'Ziyan',
#  '短',
#  '船',
#  '最后',
#  'a',
#  '259Adit',
#  '留言',
#  '停止',
#  '趋势',
#  'recommendation',
#  '回报',
#  'Gisbert',
#  '得',
#  '大幅',
#  '综合利用',
#  'widt',
#  'amp',
#  '胰岛素',
#  'Real',
#  '跟进',
#  '步骤',
#  '损失',
#  '立场',
#  '启示',
#  'Fred',
#  '分类器',
#  '生产力',
#  '日为',
#  'signals',
#  '编码表示',
#  '通过',
#  '只能',
#  '传播',
#  '渠道',
#  '15px',
#  '声音',
#  '16670783',
#  '爱好者',
#  '理所当然',
#  '活性',
#  'sec',
#  '最终',
#  '扮演着',
#  '抽象思维',
#  '世界',
#  '告知',
#  '涡旋',
#  '大桥',
#  '综合性',
#  '建立',
#  '预测',
#  '决策问题',
#  'P',
#  '首先',
#  'Hans',
#  'changes',
#  '阿',
#  '元',
#  '失去',
#  'methods',
#  '预示',
#  '系列',
#  'scheme',
#  '吉布斯',
#  '偏向',
#  '帖子',
#  'Consequence',
#  '就是',
#  '匿名',
#  'Ising',
#  '含量',
#  '一成不变',
#  'qq',
#  '1885',
#  '50',
#  '总结',
#  '2010',
#  'Ali',
#  '他于',
#  'Wolfgang',
#  '之一',
#  '因果',
#  '代表',
#  '偏离',
#  '字符',
#  '论文集',
#  '竞赛',
#  'World',
#  '迈步',
#  '使',
#  'Communications',
#  '出生',
#  '预',
#  'Werner',
#  '271',
#  '一句',
#  'Fire',
#  '促成',
#  '理应',
#  'VIP',
#  '揭示',
#  '激励',
#  '人工智能',
#  '该类',
#  '一新',
#  '不仅仅',
#  '文档',
#  'X',
#  'breeds',
#  '分化',
#  '这次',
#  'RT',
#  'Joslyn',
#  '睡前服',
#  '熟练',
#  '篇',
#  '高频',
#  '区域性',
#  '平衡态',
#  '出',
#  '类似',
#  '某一',
#  '树形',
#  'supervised',
#  '土地',
#  '体量',
#  'Wiswesser',
#  'criticality',
#  '介电常数',
#  'Experimental',
#  '有',
#  '随意',
#  '过滤器',
#  '作用',
#  '取值',
#  '总理',
#  '价值观',
#  '角落',
#  '博士学位',
#  '应该',
#  '34000',
#  'training',
#  'p',
#  '理论',
#  '．',
#  '二维码',
#  '以便',
#  '隐隐',
#  '或膜',
#  '实践',
#  '凝练',
#  '成绩',
#  'Distance',
#  'Non',
#  '亮眼',
#  '负面影响',
#  '湖泊',
#  '阱',
#  '58',
#  '黄金时代',
#  'Simple',
#  'Shochet',
#  '流行病学',
#  '几十年',
#  '会',
#  '挑战',
#  'ONE',
#  'Separating',
#  '公众',
#  '特点',
#  '定理',
#  '稀树草原',
#  '各个',
#  '铺平道路',
#  '仇玮',
#  '2012',
#  '1860',
#  '低噪声',
#  '非常低',
#  '花',
#  '尺寸',
#  '氨基酸',
#  'during',
#  '打包',
#  '69',
#  '系统管理',
#  '19',
#  'working',
#  '原料',
#  '感应器',
#  '排名',
#  '无',
#  '如何',
#  '平移',
#  '多样',
#  '甲烷',
#  '出发',
#  '发明',
#  '权衡',
#  '2141',
#  '癫痫',
#  'principles',
#  'Inf',
#  '退费',
#  '释放',
#  'mid',
#  '你',
#  '湖水',
#  'variable',
#  'entropy',
#  'zh',
#  '140',
#  '165',
#  'adaptation',
#  '78J',
#  '电子',
#  '教育界',
#  '时间跨度',
#  '长远',
#  '密度',
#  '反复',
#  'AL',
#  '1241',
#  '累积',
#  '倍',
#  '概括',
#  '有效',
#  '答记者问',
#  '标准差',
#  'structures',
#  '横向',
#  '大暴雨',
#  'APP',
#  'Yeast',
#  'α',
#  '多退少补',
#  '上空',
#  '由',
#  '希捷',
#  '参数设置',
#  '远程',
#  '谢绝',
#  '大大减少',
#  'Z',
#  '营养物质',
#  '路径',
#  '流感',
#  'FT8',
#  '微信',
#  '计算机科学',
#  'Rowan',
#  '无处不在',
#  '代码',
#  '此刻',
#  '降低',
#  '45',
#  '相等',
#  '附近',
#  '将近',
#  'Jiang',
#  '酶',
#  'FT7',
#  '保证',
#  '理性',
#  '又',
#  '碳汇',
#  '逐年',
#  'Analysis',
#  'ratio',
#  '帕多瓦',
#  '吕琳媛',
#  'drawing',
#  '执行',
#  '完全',
#  '含望',
#  'Jaegwon',
#  '学术界',
#  '分别',
#  '除了',
#  '蒸汽机',
#  '办',
#  '这摞',
#  '小',
#  'LiEmpirical',
#  'untranslated',
#  '很多',
#  'sol',
#  '科研成果',
#  '跨度',
#  '自行车',
#  '的话',
#  'Kandathil',
#  '专业性',
#  '纺锤',
#  '单',
#  '组和',
#  '顶刊',
#  '两相区',
#  '帕里',
#  '回顾',
#  '依赖性',
#  '最初',
#  '自',
#  'dengqimin',
#  '不利',
#  '需要',
#  '计划',
#  '成',
#  '失败',
#  '覆盖',
#  '如前所述',
#  '较长时间',
#  '学习指南',
#  'Ansgar',
#  '亦庄',
#  '那句',
#  'Dilemmas',
#  '请教',
#  '干旱',
#  '内容简介',
#  '商业软件',
#  'Interdisciplinary',
#  'e1007124',
#  'iPod',
#  '共识',
#  'cropsely2',
#  '好消息',
#  '博士论文',
#  '大都',
#  'Interactions',
#  'group',
#  '性能',
#  '大西洋',
#  '授予',
#  '孤立',
#  'Brian',
#  '为抗',
#  '集合',
#  '超',
#  'asymmetries',
#  'CO2',
#  '绝大多数',
#  'Acad',
#  '时所要',
#  '编译',
#  '通信',
#  '储碳',
#  '区域',
#  '分项',
#  'org',
#  '保真度',
#  '图是',
#  '30',
#  '构型',
#  '建模',
#  '1982',
#  '抗',
#  'Dom',
#  '贸易',
#  '第七章',
#  '吴令飞',
#  '速率',
#  '反之亦然',
#  '的',
#  '处于',
#  '共同完成',
#  'basin',
#  '学院',
#  '合集',
#  'macroscopic',
#  '团队',
#  '太少',
#  '页',
#  '287',
#  'Making',
#  '137J',
#  '不仅如此',
#  '<',
#  '不高',
#  '工人',
#  '导航',
#  '符号',
#  'token',
#  '指导',
#  '34',
#  '多',
#  '包围',
#  '初始值',
#  '信息论',
#  '接受程度',
#  '培根',
#  'International',
#  '狄增',
#  't1',
#  '信息',
#  '宽容',
#  '高层次',
#  'AGI',
#  '无人',
#  '对角',
#  'Color',
#  '爆炸',
#  'Spatial',
#  '13',
#  'Resnick',
#  '碱基配对',
#  '稳态',
#  '正确',
#  '交叉',
#  '复合物',
#  '构造程序',
#  '注释',
#  '相互影响',
#  '多次',
#  '想想',
#  '统计',
#  '号',
#  'Characterizing',
#  '时代',
#  '常规',
#  'sn',
#  '164',
#  '交流',
#  '举国体制',
#  '过程',
#  '输出',
#  '此文',
#  '患者',
#  '很难',
#  'abs',
#  '香农',
#  'Josef',
#  'Middleware',
#  '便是',
#  '估计值',
#  'Immunology',
#  '促',
#  'points',
#  '关切',
#  'scaling',
#  '吕鹏',
#  'Java',
#  '强调',
#  '战略规划',
#  '点位',
#  '抉择',
#  'Andrews',
#  '非常简单',
#  'effect',
#  'crosslinking',
#  '请参阅',
#  '付费',
#  '反馈作用',
#  '之势',
#  '基础',
#  '尺度',
#  '深化改革',
#  '结构',
#  '筹备',
#  '对于',
#  'Rapid',
#  '宽',
#  '三个',
#  'ri',
#  '50000',
#  '添砖加瓦',
#  '本次',
#  '恶意',
#  'Aksoy',
#  '孙烨',
#  '投机',
#  '走出',
#  'issues',
#  '认证标志',
#  '抛球',
#  '发出',
#  '联邦',
#  '更改',
#  'Zhou',
#  'apple',
#  'PSTA',
#  '前进',
#  '空间组织',
#  '治理',
#  'scitation',
#  '前往',
#  '流程图',
#  '翻',
#  '场景',
#  '不到',
#  '沿着',
#  '带',
#  '具有',
#  '更新世',
#  '越高',
#  '染色体',
#  '采取',
#  '足以',
#  '2c',
#  'cropsely1',
#  '相结合',
#  '另外',
#  '以上',
#  '空气污染',
#  'arrow',
#  '端点',
#  'Caskey',
#  '标准化',
#  '发展中国家',
#  '资源',
#  'Matching',
#  '晚上',
#  'causal',
#  'star',
#  'Stock',
#  '大变局',
#  '相当',
#  '冷',
#  '以较',
#  '环境',
#  'index',
#  '以下',
#  '诸多',
#  '301Fromm',
#  '变革',
#  '试',
#  '分隔',
#  'physics',
#  '57',
#  '舆论',
#  '移动电话',
#  '分析方法',
#  '评论',
#  '近期',
#  '潜在地',
#  'fileid',
#  'e2111456118',
#  '一般来说',
#  'zolpidem',
#  '大多数',
#  '临床',
#  '真相',
#  '生成器',
#  '感谢',
#  '甚至',
#  '不强',
#  '讨论组',
#  '用电',
#  '探索者',
#  '迅速',
#  'it',
#  '扩张',
#  '多边形',
#  '几年',
#  '意义',
#  '张江',
#  '灰黑色',
#  '专家',
#  '情况',
#  '识别模式',
#  't2',
#  '27',
#  'assembled',
#  'Lattice',
#  '收费',
#  '创建',
#  'v',
#  '相匹配',
#  'Nature',
#  'attraction',
#  '前沿科学',
#  'ó',
#  'RennerOn',
#  '结果',
#  '毛皮',
#  '模型库',
#  '脆弱性',
#  '终点',
#  '两座',
#  'Ketterle',
#  '主任',
#  'improvements',
#  'y',
#  '让',
#  '预约',
#  '适当',
#  '便',
#  '系统地',
#  '作出',
#  '偏差',
#  'GUI',
#  '一年',
#  '股票市场',
#  '冒险',
#  '聚类',
#  '安全',
#  '以及',
#  '关注',
#  '涉及',
#  'Wooyeong',
#  '新一轮',
#  '91',
#  '毕竟',
#  ...]

# %% [markdown]
# ## 二、Word2Vec

# %% [markdown]
# Word2Vec是Google推出的一个开源的词向量计算工具，它被内嵌到了gensim软件包里。
# 在本课程中，我们主要展示了自己调用Word2Vec训练词向量和读取已经训练好的词向量两种方法，并展示了如何利用词向量来进行一些简单的推理

# %% [markdown]
# ### 1. 自己训练一个小语料

# %%
# 读入文件、分词，形成一句一句的语料
# 注意跟前面处理不一样的地方在于，我们一行一行地读入文件，从而自然利用行将文章分开成“句子”

f = open("swarma_article.txt", 'r', encoding='utf-8')

lines = []
all_words = []
for line in f:
    temp = jieba.lcut(line)
    words = []
    for i in temp:
        # 过滤掉所有的标点符号
        i = re.sub("[\s+\.\!\/_,$%^*(+\"\'“”《%》]+|[+——！，。？、~@#￥%……&*（）：；‘]+", "", i)
        if len(i) > 0:
            words.append(i)
    if len(words)> 0:
        lines.append(words)
        for w in words:
            all_words.append(w)

# %%
# 得到词汇表
vocab = set(all_words)
print(len(vocab))
# 两个字典，一个根据单词索引其编号，一个根据编号索引单词
#word_to_idx中的值包含两部分，一部分为id，另一部分为单词出现的次数
#word_to_idx中的每一个元素形如：{w:[id, count]}，其中w为一个词，id为该词的编号，count为该单词在words全文中出现的次数
word_to_idx = {} 
idx_to_word = {}
ids = 0

#对全文循环，构建这两个字典
for w in words:
    cnt = word_to_idx.get(w, [ids, 0])
    if cnt[1] == 0:
        ids += 1
    cnt[1] += 1
    word_to_idx[w] = cnt
    idx_to_word[ids] = w

model = Word2Vec(lines, vector_size = 20, window = 2, min_count = 0)
# Out:
# 37886

# %%
model.wv.most_similar('物理', topn = 20)
# Out:
# [('仅次于', 0.7844539880752563),
#  ('完全正确', 0.7839490175247192),
#  ('依下式', 0.7599362134933472),
#  ('hangout', 0.7450236082077026),
#  ('0052', 0.7371149659156799),
#  ('ucsd', 0.7341702580451965),
#  ('节点均', 0.7329597473144531),
#  ('Krueger', 0.7306650280952454),
#  ('诸光路', 0.7237188816070557),
#  ('DeepXDE', 0.7203203439712524),
#  ('提供线索', 0.7092453837394714),
#  ('每家', 0.7022910118103027),
#  ('常识推理', 0.6989938616752625),
#  ('AI', 0.6989487409591675),
#  ('cdtB', 0.6972692608833313),
#  ('取得胜利', 0.6960746645927429),
#  ('审计', 0.6899946331977844),
#  ('椭圆函数', 0.6840448379516602),
#  ('凋亡', 0.6813806891441345),
#  ('亲缘', 0.6748836040496826)]

# %%
print(model.wv[all_words[0]])
vec = []
for i,w in enumerate(all_words):
	if i % 1000 == 0:
		print(i,'/',len(all_words))
	vec.append(model.wv[w])
vec = np.array(vec)
# # 从训练好的模型中提取每个单词的向量
# vec = model.extract(torch.tensor([v[0] for v in word_to_idx.values()], dtype = torch.long))
# vec = vec.data.numpy()

# 利用PCA算法进行降维
X_reduced = PCA(n_components=2).fit_transform(vec)
# Out:
# [ 0.01934894 -0.015249    0.02863818 -0.03608414  0.04775406  0.00227904
#   0.01243473  0.0245316   0.00144144  0.01277712  0.00805746 -0.04965058
#  -0.01543857 -0.01310385 -0.04611888  0.01757716  0.02544228 -0.01204241
#   0.03571843 -0.00867512]
# 0 / 683185
# 1000 / 683185
# 2000 / 683185
# 3000 / 683185
# 4000 / 683185
# 5000 / 683185
# 6000 / 683185
# 7000 / 683185
# 8000 / 683185
# 9000 / 683185
# 10000 / 683185
# 11000 / 683185
# 12000 / 683185
# 13000 / 683185
# 14000 / 683185
# 15000 / 683185
# 16000 / 683185
# 17000 / 683185
# 18000 / 683185
# 19000 / 683185
# 20000 / 683185
# 21000 / 683185
# 22000 / 683185
# 23000 / 683185
# 24000 / 683185
# 25000 / 683185
# 26000 / 683185
# 27000 / 683185
# 28000 / 683185
# 29000 / 683185
# 30000 / 683185
# 31000 / 683185
# 32000 / 683185
# 33000 / 683185
# 34000 / 683185
# 35000 / 683185
# 36000 / 683185
# 37000 / 683185
# 38000 / 683185
# 39000 / 683185
# 40000 / 683185
# 41000 / 683185
# 42000 / 683185
# 43000 / 683185
# 44000 / 683185
# 45000 / 683185
# 46000 / 683185
# 47000 / 683185
# 48000 / 683185
# 49000 / 683185
# 50000 / 683185
# 51000 / 683185
# 52000 / 683185
# 53000 / 683185
# 54000 / 683185
# 55000 / 683185
# 56000 / 683185
# 57000 / 683185
# 58000 / 683185
# 59000 / 683185
# 60000 / 683185
# 61000 / 683185
# 62000 / 683185
# 63000 / 683185
# 64000 / 683185
# 65000 / 683185
# 66000 / 683185
# 67000 / 683185
# 68000 / 683185
# 69000 / 683185
# 70000 / 683185
# 71000 / 683185
# 72000 / 683185
# 73000 / 683185
# 74000 / 683185
# 75000 / 683185
# 76000 / 683185
# 77000 / 683185
# 78000 / 683185
# 79000 / 683185
# 80000 / 683185
# 81000 / 683185
# 82000 / 683185
# 83000 / 683185
# 84000 / 683185
# 85000 / 683185
# 86000 / 683185
# 87000 / 683185
# 88000 / 683185
# 89000 / 683185
# 90000 / 683185
# 91000 / 683185
# 92000 / 683185
# 93000 / 683185
# 94000 / 683185
# 95000 / 683185
# 96000 / 683185
# 97000 / 683185
# 98000 / 683185
# 99000 / 683185
# 100000 / 683185
# 101000 / 683185
# 102000 / 683185
# 103000 / 683185
# 104000 / 683185
# 105000 / 683185
# 106000 / 683185
# 107000 / 683185
# 108000 / 683185
# 109000 / 683185
# 110000 / 683185
# 111000 / 683185
# 112000 / 683185
# 113000 / 683185
# 114000 / 683185
# 115000 / 683185
# 116000 / 683185
# 117000 / 683185
# 118000 / 683185
# 119000 / 683185
# 120000 / 683185
# 121000 / 683185
# 122000 / 683185
# 123000 / 683185
# 124000 / 683185
# 125000 / 683185
# 126000 / 683185
# 127000 / 683185
# 128000 / 683185
# 129000 / 683185
# 130000 / 683185
# 131000 / 683185
# 132000 / 683185
# 133000 / 683185
# 134000 / 683185
# 135000 / 683185
# 136000 / 683185
# 137000 / 683185
# 138000 / 683185
# 139000 / 683185
# 140000 / 683185
# 141000 / 683185
# 142000 / 683185
# 143000 / 683185
# 144000 / 683185
# 145000 / 683185
# 146000 / 683185
# 147000 / 683185
# 148000 / 683185
# 149000 / 683185
# 150000 / 683185
# 151000 / 683185
# 152000 / 683185
# 153000 / 683185
# 154000 / 683185
# 155000 / 683185
# 156000 / 683185
# 157000 / 683185
# 158000 / 683185
# 159000 / 683185
# 160000 / 683185
# 161000 / 683185
# 162000 / 683185
# 163000 / 683185
# 164000 / 683185
# 165000 / 683185
# 166000 / 683185
# 167000 / 683185
# 168000 / 683185
# 169000 / 683185
# 170000 / 683185
# 171000 / 683185
# 172000 / 683185
# 173000 / 683185
# 174000 / 683185
# 175000 / 683185
# 176000 / 683185
# 177000 / 683185
# 178000 / 683185
# 179000 / 683185
# 180000 / 683185
# 181000 / 683185
# 182000 / 683185
# 183000 / 683185
# 184000 / 683185
# 185000 / 683185
# 186000 / 683185
# 187000 / 683185
# 188000 / 683185
# 189000 / 683185
# 190000 / 683185
# 191000 / 683185
# 192000 / 683185
# 193000 / 683185
# 194000 / 683185
# 195000 / 683185
# 196000 / 683185
# 197000 / 683185
# 198000 / 683185
# 199000 / 683185
# 200000 / 683185
# 201000 / 683185
# 202000 / 683185
# 203000 / 683185
# 204000 / 683185
# 205000 / 683185
# 206000 / 683185
# 207000 / 683185
# 208000 / 683185
# 209000 / 683185
# 210000 / 683185
# 211000 / 683185
# 212000 / 683185
# 213000 / 683185
# 214000 / 683185
# 215000 / 683185
# 216000 / 683185
# 217000 / 683185
# 218000 / 683185
# 219000 / 683185
# 220000 / 683185
# 221000 / 683185
# 222000 / 683185
# 223000 / 683185
# 224000 / 683185
# 225000 / 683185
# 226000 / 683185
# 227000 / 683185
# 228000 / 683185
# 229000 / 683185
# 230000 / 683185
# 231000 / 683185
# 232000 / 683185
# 233000 / 683185
# 234000 / 683185
# 235000 / 683185
# 236000 / 683185
# 237000 / 683185
# 238000 / 683185
# 239000 / 683185
# 240000 / 683185
# 241000 / 683185
# 242000 / 683185
# 243000 / 683185
# 244000 / 683185
# 245000 / 683185
# 246000 / 683185
# 247000 / 683185
# 248000 / 683185
# 249000 / 683185
# 250000 / 683185
# 251000 / 683185
# 252000 / 683185
# 253000 / 683185
# 254000 / 683185
# 255000 / 683185
# 256000 / 683185
# 257000 / 683185
# 258000 / 683185
# 259000 / 683185
# 260000 / 683185
# 261000 / 683185
# 262000 / 683185
# 263000 / 683185
# 264000 / 683185
# 265000 / 683185
# 266000 / 683185
# 267000 / 683185
# 268000 / 683185
# 269000 / 683185
# 270000 / 683185
# 271000 / 683185
# 272000 / 683185
# 273000 / 683185
# 274000 / 683185
# 275000 / 683185
# 276000 / 683185
# 277000 / 683185
# 278000 / 683185
# 279000 / 683185
# 280000 / 683185
# 281000 / 683185
# 282000 / 683185
# 283000 / 683185
# 284000 / 683185
# 285000 / 683185
# 286000 / 683185
# 287000 / 683185
# 288000 / 683185
# 289000 / 683185
# 290000 / 683185
# 291000 / 683185
# 292000 / 683185
# 293000 / 683185
# 294000 / 683185
# 295000 / 683185
# 296000 / 683185
# 297000 / 683185
# 298000 / 683185
# 299000 / 683185
# 300000 / 683185
# 301000 / 683185
# 302000 / 683185
# 303000 / 683185
# 304000 / 683185
# 305000 / 683185
# 306000 / 683185
# 307000 / 683185
# 308000 / 683185
# 309000 / 683185
# 310000 / 683185
# 311000 / 683185
# 312000 / 683185
# 313000 / 683185
# 314000 / 683185
# 315000 / 683185
# 316000 / 683185
# 317000 / 683185
# 318000 / 683185
# 319000 / 683185
# 320000 / 683185
# 321000 / 683185
# 322000 / 683185
# 323000 / 683185
# 324000 / 683185
# 325000 / 683185
# 326000 / 683185
# 327000 / 683185
# 328000 / 683185
# 329000 / 683185
# 330000 / 683185
# 331000 / 683185
# 332000 / 683185
# 333000 / 683185
# 334000 / 683185
# 335000 / 683185
# 336000 / 683185
# 337000 / 683185
# 338000 / 683185
# 339000 / 683185
# 340000 / 683185
# 341000 / 683185
# 342000 / 683185
# 343000 / 683185
# 344000 / 683185
# 345000 / 683185
# 346000 / 683185
# 347000 / 683185
# 348000 / 683185
# 349000 / 683185
# 350000 / 683185
# 351000 / 683185
# 352000 / 683185
# 353000 / 683185
# 354000 / 683185
# 355000 / 683185
# 356000 / 683185
# 357000 / 683185
# 358000 / 683185
# 359000 / 683185
# 360000 / 683185
# 361000 / 683185
# 362000 / 683185
# 363000 / 683185
# 364000 / 683185
# 365000 / 683185
# 366000 / 683185
# 367000 / 683185
# 368000 / 683185
# 369000 / 683185
# 370000 / 683185
# 371000 / 683185
# 372000 / 683185
# 373000 / 683185
# 374000 / 683185
# 375000 / 683185
# 376000 / 683185
# 377000 / 683185
# 378000 / 683185
# 379000 / 683185
# 380000 / 683185
# 381000 / 683185
# 382000 / 683185
# 383000 / 683185
# 384000 / 683185
# 385000 / 683185
# 386000 / 683185
# 387000 / 683185
# 388000 / 683185
# 389000 / 683185
# 390000 / 683185
# 391000 / 683185
# 392000 / 683185
# 393000 / 683185
# 394000 / 683185
# 395000 / 683185
# 396000 / 683185
# 397000 / 683185
# 398000 / 683185
# 399000 / 683185
# 400000 / 683185
# 401000 / 683185
# 402000 / 683185
# 403000 / 683185
# 404000 / 683185
# 405000 / 683185
# 406000 / 683185
# 407000 / 683185
# 408000 / 683185
# 409000 / 683185
# 410000 / 683185
# 411000 / 683185
# 412000 / 683185
# 413000 / 683185
# 414000 / 683185
# 415000 / 683185
# 416000 / 683185
# 417000 / 683185
# 418000 / 683185
# 419000 / 683185
# 420000 / 683185
# 421000 / 683185
# 422000 / 683185
# 423000 / 683185
# 424000 / 683185
# 425000 / 683185
# 426000 / 683185
# 427000 / 683185
# 428000 / 683185
# 429000 / 683185
# 430000 / 683185
# 431000 / 683185
# 432000 / 683185
# 433000 / 683185
# 434000 / 683185
# 435000 / 683185
# 436000 / 683185
# 437000 / 683185
# 438000 / 683185
# 439000 / 683185
# 440000 / 683185
# 441000 / 683185
# 442000 / 683185
# 443000 / 683185
# 444000 / 683185
# 445000 / 683185
# 446000 / 683185
# 447000 / 683185
# 448000 / 683185
# 449000 / 683185
# 450000 / 683185
# 451000 / 683185
# 452000 / 683185
# 453000 / 683185
# 454000 / 683185
# 455000 / 683185
# 456000 / 683185
# 457000 / 683185
# 458000 / 683185
# 459000 / 683185
# 460000 / 683185
# 461000 / 683185
# 462000 / 683185
# 463000 / 683185
# 464000 / 683185
# 465000 / 683185
# 466000 / 683185
# 467000 / 683185
# 468000 / 683185
# 469000 / 683185
# 470000 / 683185
# 471000 / 683185
# 472000 / 683185
# 473000 / 683185
# 474000 / 683185
# 475000 / 683185
# 476000 / 683185
# 477000 / 683185
# 478000 / 683185
# 479000 / 683185
# 480000 / 683185
# 481000 / 683185
# 482000 / 683185
# 483000 / 683185
# 484000 / 683185
# 485000 / 683185
# 486000 / 683185
# 487000 / 683185
# 488000 / 683185
# 489000 / 683185
# 490000 / 683185
# 491000 / 683185
# 492000 / 683185
# 493000 / 683185
# 494000 / 683185
# 495000 / 683185
# 496000 / 683185
# 497000 / 683185
# 498000 / 683185
# 499000 / 683185
# 500000 / 683185
# 501000 / 683185
# 502000 / 683185
# 503000 / 683185
# 504000 / 683185
# 505000 / 683185
# 506000 / 683185
# 507000 / 683185
# 508000 / 683185
# 509000 / 683185
# 510000 / 683185
# 511000 / 683185
# 512000 / 683185
# 513000 / 683185
# 514000 / 683185
# 515000 / 683185
# 516000 / 683185
# 517000 / 683185
# 518000 / 683185
# 519000 / 683185
# 520000 / 683185
# 521000 / 683185
# 522000 / 683185
# 523000 / 683185
# 524000 / 683185
# 525000 / 683185
# 526000 / 683185
# 527000 / 683185
# 528000 / 683185
# 529000 / 683185
# 530000 / 683185
# 531000 / 683185
# 532000 / 683185
# 533000 / 683185
# 534000 / 683185
# 535000 / 683185
# 536000 / 683185
# 537000 / 683185
# 538000 / 683185
# 539000 / 683185
# 540000 / 683185
# 541000 / 683185
# 542000 / 683185
# 543000 / 683185
# 544000 / 683185
# 545000 / 683185
# 546000 / 683185
# 547000 / 683185
# 548000 / 683185
# 549000 / 683185
# 550000 / 683185
# 551000 / 683185
# 552000 / 683185
# 553000 / 683185
# 554000 / 683185
# 555000 / 683185
# 556000 / 683185
# 557000 / 683185
# 558000 / 683185
# 559000 / 683185
# 560000 / 683185
# 561000 / 683185
# 562000 / 683185
# 563000 / 683185
# 564000 / 683185
# 565000 / 683185
# 566000 / 683185
# 567000 / 683185
# 568000 / 683185
# 569000 / 683185
# 570000 / 683185
# 571000 / 683185
# 572000 / 683185
# 573000 / 683185
# 574000 / 683185
# 575000 / 683185
# 576000 / 683185
# 577000 / 683185
# 578000 / 683185
# 579000 / 683185
# 580000 / 683185
# 581000 / 683185
# 582000 / 683185
# 583000 / 683185
# 584000 / 683185
# 585000 / 683185
# 586000 / 683185
# 587000 / 683185
# 588000 / 683185
# 589000 / 683185
# 590000 / 683185
# 591000 / 683185
# 592000 / 683185
# 593000 / 683185
# 594000 / 683185
# 595000 / 683185
# 596000 / 683185
# 597000 / 683185
# 598000 / 683185
# 599000 / 683185
# 600000 / 683185
# 601000 / 683185
# 602000 / 683185
# 603000 / 683185
# 604000 / 683185
# 605000 / 683185
# 606000 / 683185
# 607000 / 683185
# 608000 / 683185
# 609000 / 683185
# 610000 / 683185
# 611000 / 683185
# 612000 / 683185
# 613000 / 683185
# 614000 / 683185
# 615000 / 683185
# 616000 / 683185
# 617000 / 683185
# 618000 / 683185
# 619000 / 683185
# 620000 / 683185
# 621000 / 683185
# 622000 / 683185
# 623000 / 683185
# 624000 / 683185
# 625000 / 683185
# 626000 / 683185
# 627000 / 683185
# 628000 / 683185
# 629000 / 683185
# 630000 / 683185
# 631000 / 683185
# 632000 / 683185
# 633000 / 683185
# 634000 / 683185
# 635000 / 683185
# 636000 / 683185
# 637000 / 683185
# 638000 / 683185
# 639000 / 683185
# 640000 / 683185
# 641000 / 683185
# 642000 / 683185
# 643000 / 683185
# 644000 / 683185
# 645000 / 683185
# 646000 / 683185
# 647000 / 683185
# 648000 / 683185
# 649000 / 683185
# 650000 / 683185
# 651000 / 683185
# 652000 / 683185
# 653000 / 683185
# 654000 / 683185
# 655000 / 683185
# 656000 / 683185
# 657000 / 683185
# 658000 / 683185
# 659000 / 683185
# 660000 / 683185
# 661000 / 683185
# 662000 / 683185
# 663000 / 683185
# 664000 / 683185
# 665000 / 683185
# 666000 / 683185
# 667000 / 683185
# 668000 / 683185
# 669000 / 683185
# 670000 / 683185
# 671000 / 683185
# 672000 / 683185
# 673000 / 683185
# 674000 / 683185
# 675000 / 683185
# 676000 / 683185
# 677000 / 683185
# 678000 / 683185
# 679000 / 683185
# 680000 / 683185
# 681000 / 683185
# 682000 / 683185
# 683000 / 683185

# %%
# 绘制所有单词向量的二维空间投影
fig = plt.figure(figsize = (30, 20))
ax = fig.gca()
ax.set_facecolor('white')
ax.plot(X_reduced[:, 0], X_reduced[:, 1], '.', markersize = 1, alpha = 0.1, color = 'gray')


# 绘制几个特殊单词的向量
# words = ['', '', '三体', '质子', '科学', '世界', '文明', '太空', '加速器', '平面', '宇宙', '信息']
words = ['临界','相变','网络','科学家','海洋','气候','温度','湿度','生物圈','社会','涌现']

# 设置中文字体，否则无法在图形上显示中文
zhfont1 = matplotlib.font_manager.FontProperties(fname='./HuaWenFangSong-1.ttf', size=26)
for w in words:
    if w in word_to_idx:
        ind = word_to_idx[w][0]
        xy = X_reduced[ind]
        plt.plot(xy[0], xy[1], '.', alpha =1, color = 'red')
        plt.text(xy[0], xy[1], w, fontproperties = zhfont1, alpha = 1, color = 'black')
plt.xlim(-0.13,0.05)
plt.ylim(-0.08,0.08)
plt.savefig('cloud-1.png')

# %% [markdown]
# ### 2、调用一个现成的词向量

# %% [markdown]
# 1). 大规模词向量可视化
#
# 该中文词向量库是由尹相志提供，训练语料来源为：微博、人民日报、上海热线、汽车之家等，包含1366130个词向量，
# 下载地址为：链接：http://pan.baidu.com/s/1gePQAun 密码：kvtg
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第VI课的配套源代码

# %%
# 加载词向量
word_vectors = KeyedVectors.load_word2vec_format('./vectors.bin', binary=True, unicode_errors='ignore')

# len(word_vectors.vocab)

# %%
len(word_vectors)
# Out:
# 1366130

# %%
# PCA降维
rawWordVec = []
word2ind = {}
for i, w in enumerate(word_vectors.key_to_index):
#     print(i)
#     print(w)
#     print(word_vectors[w])
    rawWordVec.append(word_vectors[w])
    word2ind[w] = i
rawWordVec = np.array(rawWordVec)
X_reduced = PCA(n_components=2).fit_transform(rawWordVec)

# %%
# 查看相似词
word_vectors.most_similar('物理', topn = 20)
# Out:
# [('化学', 0.7124662399291992),
#  ('物理化学', 0.6906830072402954),
#  ('物理学', 0.6732755303382874),
#  ('力学', 0.6633583903312683),
#  ('数学', 0.6431227326393127),
#  ('电学', 0.6256975531578064),
#  ('原理', 0.6226458549499512),
#  ('生物学', 0.6126975417137146),
#  ('数学物理', 0.6115936040878296),
#  ('电化学', 0.6058179140090942),
#  ('非线性', 0.595616340637207),
#  ('量子力学', 0.5924553871154785),
#  ('热学', 0.5854000449180603),
#  ('电磁场', 0.5820313096046448),
#  ('物理现象', 0.581839919090271),
#  ('凝聚态', 0.5746456384658813),
#  ('计算机', 0.5690045356750488),
#  ('流体力学', 0.5671141147613525),
#  ('化学性', 0.563992440700531),
#  ('微积分', 0.5628953576087952)]

# %%
# 绘制星空图
# 绘制所有的词汇
fig = plt.figure(figsize = (30, 15))
ax = fig.gca()
ax.set_facecolor('black')
ax.plot(X_reduced[:, 0], X_reduced[:, 1], '.', markersize = 1, alpha = 0.1, color = 'white')

ax.set_xlim([-12,12])
ax.set_ylim([-10,20])


# 选择几个特殊词汇，不仅画它们的位置，而且把它们的临近词也画出来
words = {'自行车','岛屿','物理','红楼梦','量子'}
all_words = []
for w in words:
    lst = word_vectors.most_similar(w)
    wds = [i[0] for i in lst]
    metrics = [i[1] for i in lst]
    wds = np.append(wds, w)
    all_words.append(wds)


zhfont1 = matplotlib.font_manager.FontProperties(fname='./HuaWenFangSong-1.ttf', size=16)
colors = ['red', 'yellow', 'orange', 'green', 'cyan', 'cyan']
for num, wds in enumerate(all_words):
    for w in wds:
        if w in word2ind:
            ind = word2ind[w]
            xy = X_reduced[ind]
            plt.plot(xy[0], xy[1], '.', alpha =1, color = colors[num])
            plt.text(xy[0], xy[1], w, fontproperties = zhfont1, alpha = 1, color = colors[num])
plt.savefig('88.png',dpi =600)

# %% [markdown]
# #### 2). 类比关系实验

# %%
# 女人－男人＝？－国王
words = word_vectors.most_similar(positive=['女人', '国王'], negative=['男人'])
words

# %%
# 北京－中国＝？－俄罗斯
words = word_vectors.most_similar(positive=['北京', '俄罗斯'], negative=['中国'])
words

# %%
# 自然科学－物理学＝？－政治学
words = word_vectors.most_similar(positive=['自然科学', '政治学'], negative=['物理学'])
words

# %%
# 王菲－章子怡＝？－汪峰
words = word_vectors.most_similar(positive=['王菲', '汪峰'], negative=['章子怡'])
words

# %%
# 尽可能多地选出所有的货币
words = word_vectors.most_similar(positive=['美元', '英镑'], topn = 100)
words = word_vectors.most_similar(positive=['美元', '英镑', '日元'], topn = 100)
#words = word_vectors.most_similar(positive=['美元', '英镑', '日元'], negative = ['原油价格', '7800万'], topn = 100)
words

# %% [markdown]
# 本文件是集智学园http://campus.swarma.org 出品的“火炬上的深度学习”第III课的配套源代码
